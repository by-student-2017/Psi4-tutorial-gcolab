# %%
# set conda
# !wget -c https://repo.continuum.io/miniconda/Miniconda3-latest-Linux-x86_64.sh
# !chmod +x Miniconda3-latest-Linux-x86_64.sh
# !bash ./Miniconda3-latest-Linux-x86_64.sh -b -f -p /usr/local

# install psi4
# !conda install -y psi4 python=3.7 -c psi4

# set path
import sys
sys.path.append("/usr/local/lib/python3.7/site-packages/")
# Out:
# --2022-04-19 04:15:42--  https://repo.continuum.io/miniconda/Miniconda3-latest-Linux-x86_64.sh
# Resolving repo.continuum.io (repo.continuum.io)... 104.18.200.79, 104.18.201.79, 2606:4700::6812:c84f, ...
# Connecting to repo.continuum.io (repo.continuum.io)|104.18.200.79|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: https://repo.anaconda.com/miniconda/Miniconda3-latest-Linux-x86_64.sh [following]
# --2022-04-19 04:15:42--  https://repo.anaconda.com/miniconda/Miniconda3-latest-Linux-x86_64.sh
# Resolving repo.anaconda.com (repo.anaconda.com)... 104.16.131.3, 104.16.130.3, 2606:4700::6810:8303, ...
# Connecting to repo.anaconda.com (repo.anaconda.com)|104.16.131.3|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 75660608 (72M) [application/x-sh]
# Saving to: ‘Miniconda3-latest-Linux-x86_64.sh’
#
# Miniconda3-latest-L 100%[===================>]  72.16M   244MB/s    in 0.3s
#
# 2022-04-19 04:15:42 (244 MB/s) - ‘Miniconda3-latest-Linux-x86_64.sh’ saved [75660608/75660608]
#
# PREFIX=/usr/local
# Unpacking payload ...
# done
# done
#
# ## Package Plan ##
#
#   environment location: /usr/local
#
#   added / updated specs:
#     - _libgcc_mutex==0.1=main
#     - _openmp_mutex==4.5=1_gnu
#     - brotlipy==0.7.0=py39h27cfd23_1003
#     - ca-certificates==2021.10.26=h06a4308_2
#     - certifi==2021.10.8=py39h06a4308_2
#     - cffi==1.15.0=py39hd667e15_1
#     - charset-normalizer==2.0.4=pyhd3eb1b0_0
#     - conda-content-trust==0.1.1=pyhd3eb1b0_0
#     - conda-package-handling==1.7.3=py39h27cfd23_1
#     - conda==4.11.0=py39h06a4308_0
#     - cryptography==36.0.0=py39h9ce1e76_0
#     - idna==3.3=pyhd3eb1b0_0
#     - ld_impl_linux-64==2.35.1=h7274673_9
#     - libffi==3.3=he6710b0_2
#     - libgcc-ng==9.3.0=h5101ec6_17
#     - libgomp==9.3.0=h5101ec6_17
#     - libstdcxx-ng==9.3.0=hd4cf53a_17
#     - ncurses==6.3=h7f8727e_2
#     - openssl==1.1.1m=h7f8727e_0
#     - pip==21.2.4=py39h06a4308_0
#     - pycosat==0.6.3=py39h27cfd23_0
#     - pycparser==2.21=pyhd3eb1b0_0
#     - pyopenssl==21.0.0=pyhd3eb1b0_1
#     - pysocks==1.7.1=py39h06a4308_0
#     - python==3.9.7=h12debd9_1
#     - readline==8.1.2=h7f8727e_1
#     - requests==2.27.1=pyhd3eb1b0_0
#     - ruamel_yaml==0.15.100=py39h27cfd23_0
#     - setuptools==58.0.4=py39h06a4308_0
#     - six==1.16.0=pyhd3eb1b0_0
#     - sqlite==3.37.0=hc218d9a_0
#     - tk==8.6.11=h1ccaba5_0
#     - tqdm==4.62.3=pyhd3eb1b0_1
#     - tzdata==2021e=hda174b7_0
#     - urllib3==1.26.7=pyhd3eb1b0_0
#     - wheel==0.37.1=pyhd3eb1b0_0
#     - xz==5.2.5=h7b6447c_0
#     - yaml==0.2.5=h7b6447c_0
#     - zlib==1.2.11=h7f8727e_4
#
#
# The following NEW packages will be INSTALLED:
#
#   _libgcc_mutex      pkgs/main/linux-64::_libgcc_mutex-0.1-main
#   _openmp_mutex      pkgs/main/linux-64::_openmp_mutex-4.5-1_gnu
#   brotlipy           pkgs/main/linux-64::brotlipy-0.7.0-py39h27cfd23_1003
#   ca-certificates    pkgs/main/linux-64::ca-certificates-2021.10.26-h06a4308_2
#   certifi            pkgs/main/linux-64::certifi-2021.10.8-py39h06a4308_2
#   cffi               pkgs/main/linux-64::cffi-1.15.0-py39hd667e15_1
#   charset-normalizer pkgs/main/noarch::charset-normalizer-2.0.4-pyhd3eb1b0_0
#   conda              pkgs/main/linux-64::conda-4.11.0-py39h06a4308_0
#   conda-content-tru~ pkgs/main/noarch::conda-content-trust-0.1.1-pyhd3eb1b0_0
#   conda-package-han~ pkgs/main/linux-64::conda-package-handling-1.7.3-py39h27cfd23_1
#   cryptography       pkgs/main/linux-64::cryptography-36.0.0-py39h9ce1e76_0
#   idna               pkgs/main/noarch::idna-3.3-pyhd3eb1b0_0
#   ld_impl_linux-64   pkgs/main/linux-64::ld_impl_linux-64-2.35.1-h7274673_9
#   libffi             pkgs/main/linux-64::libffi-3.3-he6710b0_2
#   libgcc-ng          pkgs/main/linux-64::libgcc-ng-9.3.0-h5101ec6_17
#   libgomp            pkgs/main/linux-64::libgomp-9.3.0-h5101ec6_17
#   libstdcxx-ng       pkgs/main/linux-64::libstdcxx-ng-9.3.0-hd4cf53a_17
#   ncurses            pkgs/main/linux-64::ncurses-6.3-h7f8727e_2
#   openssl            pkgs/main/linux-64::openssl-1.1.1m-h7f8727e_0
#   pip                pkgs/main/linux-64::pip-21.2.4-py39h06a4308_0
#   pycosat            pkgs/main/linux-64::pycosat-0.6.3-py39h27cfd23_0
#   pycparser          pkgs/main/noarch::pycparser-2.21-pyhd3eb1b0_0
#   pyopenssl          pkgs/main/noarch::pyopenssl-21.0.0-pyhd3eb1b0_1
#   pysocks            pkgs/main/linux-64::pysocks-1.7.1-py39h06a4308_0
#   python             pkgs/main/linux-64::python-3.9.7-h12debd9_1
#   readline           pkgs/main/linux-64::readline-8.1.2-h7f8727e_1
#   requests           pkgs/main/noarch::requests-2.27.1-pyhd3eb1b0_0
#   ruamel_yaml        pkgs/main/linux-64::ruamel_yaml-0.15.100-py39h27cfd23_0
#   setuptools         pkgs/main/linux-64::setuptools-58.0.4-py39h06a4308_0
#   six                pkgs/main/noarch::six-1.16.0-pyhd3eb1b0_0
#   sqlite             pkgs/main/linux-64::sqlite-3.37.0-hc218d9a_0
#   tk                 pkgs/main/linux-64::tk-8.6.11-h1ccaba5_0
#   tqdm               pkgs/main/noarch::tqdm-4.62.3-pyhd3eb1b0_1
#   tzdata             pkgs/main/noarch::tzdata-2021e-hda174b7_0
#   urllib3            pkgs/main/noarch::urllib3-1.26.7-pyhd3eb1b0_0
#   wheel              pkgs/main/noarch::wheel-0.37.1-pyhd3eb1b0_0
#   xz                 pkgs/main/linux-64::xz-5.2.5-h7b6447c_0
#   yaml               pkgs/main/linux-64::yaml-0.2.5-h7b6447c_0
#   zlib               pkgs/main/linux-64::zlib-1.2.11-h7f8727e_4
#
#
# done
# done
# installation finished.
# WARNING:
#     You currently have a PYTHONPATH environment variable set. This may cause
#     unexpected behavior when running the Python interpreter in Miniconda3.
#     For best results, please verify that your PYTHONPATH only points to
#     directories of packages that are compatible with the Python interpreter
#     in Miniconda3: /usr/local
# done
# done
#
# ## Package Plan ##
#
#   environment location: /usr/local
#
#   added / updated specs:
#     - psi4
#     - python=3.7
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     ambit-0.5.1                |       hbe8a562_1         488 KB  psi4
#     attrs-21.4.0               |     pyhd3eb1b0_0          51 KB
#     blas-1.0                   |              mkl           6 KB
#     brotlipy-0.7.0             |py37h27cfd23_1003         320 KB
#     ca-certificates-2022.3.29  |       h06a4308_0         117 KB
#     certifi-2021.10.8          |   py37h06a4308_2         151 KB
#     cffi-1.15.0                |   py37hd667e15_1         222 KB
#     chemps2-1.8.10             |       hbe8a562_0         2.4 MB  psi4
#     conda-4.12.0               |   py37h06a4308_0        14.5 MB
#     conda-package-handling-1.8.1|   py37h7f8727e_0         889 KB
#     cryptography-36.0.0        |   py37h9ce1e76_0         1.3 MB
#     decorator-5.1.1            |     pyhd3eb1b0_0          12 KB
#     dftd3-3.2.1                |       h84218bc_2         2.0 MB  psi4
#     dkh-1.2                    |       h173d85e_2         407 KB  psi4
#     gau2grid-2.0.7             |       hd18ef5c_0         1.2 MB  psi4
#     gcp-2.0.2                  |       he991be0_2         605 KB  psi4
#     gdma-2.2.6                 |       h0e1e685_6         762 KB  psi4
#     hdf5-1.10.6                |       hb1b8bf9_0         3.7 MB
#     importlib-metadata-4.11.3  |   py37h06a4308_0          40 KB
#     importlib_metadata-4.11.3  |       hd3eb1b0_0          12 KB
#     importlib_resources-5.2.0  |     pyhd3eb1b0_1          21 KB
#     iniconfig-1.1.1            |     pyhd3eb1b0_0           8 KB
#     intel-openmp-2021.4.0      |    h06a4308_3561         4.2 MB
#     libgfortran-ng-7.5.0       |      ha8ba4b0_17          22 KB
#     libgfortran4-7.5.0         |      ha8ba4b0_17         995 KB
#     libint2-2.6.0              |       hc9558a2_9       361.9 MB  psi4
#     libxc-5.1.5                |       h84b9e52_1         7.1 MB  psi4
#     mkl-2021.4.0               |     h06a4308_640       142.6 MB
#     mkl-service-2.4.0          |   py37h7f8727e_0          56 KB
#     mkl_fft-1.3.1              |   py37hd3c417c_0         172 KB
#     mkl_random-1.2.2           |   py37h51133e4_0         287 KB
#     networkx-2.2               |           py37_1         1.6 MB
#     numpy-1.21.5               |   py37he7a7128_1          24 KB
#     numpy-base-1.21.5          |   py37hf524024_1         4.8 MB
#     openssl-1.1.1n             |       h7f8727e_0         2.5 MB
#     packaging-21.3             |     pyhd3eb1b0_0          36 KB
#     pcmsolver-1.2.1.1          |   py37h6d17ec8_2         2.3 MB  psi4
#     pint-0.17                  |     pyhd8ed1ab_0         168 KB  psi4
#     pip-21.2.2                 |   py37h06a4308_0         1.8 MB
#     pluggy-1.0.0               |   py37h06a4308_1          29 KB
#     psi4-1.5+e9f4d6d           |   py37hbf93d9d_0        37.7 MB  psi4
#     psutil-5.8.0               |   py37h27cfd23_1         329 KB
#     py-1.11.0                  |     pyhd3eb1b0_0          76 KB
#     py-cpuinfo-8.0.0           |     pyhd3eb1b0_1          23 KB
#     pycosat-0.6.3              |   py37h27cfd23_0          81 KB
#     pydantic-1.9.0             |   py37h7f8727e_0         1.8 MB
#     pyparsing-3.0.4            |     pyhd3eb1b0_0          81 KB
#     pysocks-1.7.1              |           py37_1          27 KB
#     pytest-7.1.1               |   py37h06a4308_0         454 KB
#     python-3.7.11              |       h12debd9_0        45.3 MB
#     pyyaml-6.0                 |   py37h7f8727e_1         168 KB
#     qcelemental-0.24.0         |     pyhd8ed1ab_0         240 KB  psi4
#     qcengine-0.23.0            |     pyhd8ed1ab_0         195 KB  psi4
#     ruamel_yaml-0.15.100       |   py37h27cfd23_0         253 KB
#     setuptools-61.2.0          |   py37h06a4308_0        1007 KB
#     simint-0.7                 |       h642920c_1         9.6 MB  psi4
#     tomli-1.2.2                |     pyhd3eb1b0_0          17 KB
#     typing-extensions-4.1.1    |       hd3eb1b0_0           8 KB
#     typing_extensions-4.1.1    |     pyh06a4308_0          28 KB
#     zipp-3.7.0                 |     pyhd3eb1b0_0          12 KB
#     ------------------------------------------------------------
#                                            Total:       657.0 MB
#
# The following NEW packages will be INSTALLED:
#
#   ambit              psi4/linux-64::ambit-0.5.1-hbe8a562_1
#   attrs              pkgs/main/noarch::attrs-21.4.0-pyhd3eb1b0_0
#   blas               pkgs/main/linux-64::blas-1.0-mkl
#   chemps2            psi4/linux-64::chemps2-1.8.10-hbe8a562_0
#   decorator          pkgs/main/noarch::decorator-5.1.1-pyhd3eb1b0_0
#   dftd3              psi4/linux-64::dftd3-3.2.1-h84218bc_2
#   dkh                psi4/linux-64::dkh-1.2-h173d85e_2
#   gau2grid           psi4/linux-64::gau2grid-2.0.7-hd18ef5c_0
#   gcp                psi4/linux-64::gcp-2.0.2-he991be0_2
#   gdma               psi4/linux-64::gdma-2.2.6-h0e1e685_6
#   hdf5               pkgs/main/linux-64::hdf5-1.10.6-hb1b8bf9_0
#   importlib-metadata pkgs/main/linux-64::importlib-metadata-4.11.3-py37h06a4308_0
#   importlib_metadata pkgs/main/noarch::importlib_metadata-4.11.3-hd3eb1b0_0
#   importlib_resourc~ pkgs/main/noarch::importlib_resources-5.2.0-pyhd3eb1b0_1
#   iniconfig          pkgs/main/noarch::iniconfig-1.1.1-pyhd3eb1b0_0
#   intel-openmp       pkgs/main/linux-64::intel-openmp-2021.4.0-h06a4308_3561
#   libgfortran-ng     pkgs/main/linux-64::libgfortran-ng-7.5.0-ha8ba4b0_17
#   libgfortran4       pkgs/main/linux-64::libgfortran4-7.5.0-ha8ba4b0_17
#   libint2            psi4/linux-64::libint2-2.6.0-hc9558a2_9
#   libxc              psi4/linux-64::libxc-5.1.5-h84b9e52_1
#   mkl                pkgs/main/linux-64::mkl-2021.4.0-h06a4308_640
#   mkl-service        pkgs/main/linux-64::mkl-service-2.4.0-py37h7f8727e_0
#   mkl_fft            pkgs/main/linux-64::mkl_fft-1.3.1-py37hd3c417c_0
#   mkl_random         pkgs/main/linux-64::mkl_random-1.2.2-py37h51133e4_0
#   networkx           pkgs/main/linux-64::networkx-2.2-py37_1
#   numpy              pkgs/main/linux-64::numpy-1.21.5-py37he7a7128_1
#   numpy-base         pkgs/main/linux-64::numpy-base-1.21.5-py37hf524024_1
#   packaging          pkgs/main/noarch::packaging-21.3-pyhd3eb1b0_0
#   pcmsolver          psi4/linux-64::pcmsolver-1.2.1.1-py37h6d17ec8_2
#   pint               psi4/noarch::pint-0.17-pyhd8ed1ab_0
#   pluggy             pkgs/main/linux-64::pluggy-1.0.0-py37h06a4308_1
#   psi4               psi4/linux-64::psi4-1.5+e9f4d6d-py37hbf93d9d_0
#   psutil             pkgs/main/linux-64::psutil-5.8.0-py37h27cfd23_1
#   py                 pkgs/main/noarch::py-1.11.0-pyhd3eb1b0_0
#   py-cpuinfo         pkgs/main/noarch::py-cpuinfo-8.0.0-pyhd3eb1b0_1
#   pydantic           pkgs/main/linux-64::pydantic-1.9.0-py37h7f8727e_0
#   pyparsing          pkgs/main/noarch::pyparsing-3.0.4-pyhd3eb1b0_0
#   pytest             pkgs/main/linux-64::pytest-7.1.1-py37h06a4308_0
#   pyyaml             pkgs/main/linux-64::pyyaml-6.0-py37h7f8727e_1
#   qcelemental        psi4/noarch::qcelemental-0.24.0-pyhd8ed1ab_0
#   qcengine           psi4/noarch::qcengine-0.23.0-pyhd8ed1ab_0
#   simint             psi4/linux-64::simint-0.7-h642920c_1
#   tomli              pkgs/main/noarch::tomli-1.2.2-pyhd3eb1b0_0
#   typing-extensions  pkgs/main/noarch::typing-extensions-4.1.1-hd3eb1b0_0
#   typing_extensions  pkgs/main/noarch::typing_extensions-4.1.1-pyh06a4308_0
#   zipp               pkgs/main/noarch::zipp-3.7.0-pyhd3eb1b0_0
#
# The following packages will be UPDATED:
#
#   ca-certificates                     2021.10.26-h06a4308_2 --> 2022.3.29-h06a4308_0
#   conda                               4.11.0-py39h06a4308_0 --> 4.12.0-py37h06a4308_0
#   conda-package-han~                   1.7.3-py39h27cfd23_1 --> 1.8.1-py37h7f8727e_0
#   openssl                                 1.1.1m-h7f8727e_0 --> 1.1.1n-h7f8727e_0
#   pysocks                              1.7.1-py39h06a4308_0 --> 1.7.1-py37_1
#   setuptools                          58.0.4-py39h06a4308_0 --> 61.2.0-py37h06a4308_0
#
# The following packages will be DOWNGRADED:
#
#   brotlipy                          0.7.0-py39h27cfd23_1003 --> 0.7.0-py37h27cfd23_1003
#   certifi                          2021.10.8-py39h06a4308_2 --> 2021.10.8-py37h06a4308_2
#   cffi                                1.15.0-py39hd667e15_1 --> 1.15.0-py37hd667e15_1
#   cryptography                        36.0.0-py39h9ce1e76_0 --> 36.0.0-py37h9ce1e76_0
#   pip                                 21.2.4-py39h06a4308_0 --> 21.2.2-py37h06a4308_0
#   pycosat                              0.6.3-py39h27cfd23_0 --> 0.6.3-py37h27cfd23_0
#   python                                   3.9.7-h12debd9_1 --> 3.7.11-h12debd9_0
#   ruamel_yaml                       0.15.100-py39h27cfd23_0 --> 0.15.100-py37h27cfd23_0
#
#
#
# Downloading and Extracting Packages
# pint-0.17            | 168 KB    | : 100% 1.0/1 [00:00<00:00,  1.11it/s]
# psi4-1.5+e9f4d6d     | 37.7 MB   | : 100% 1.0/1 [00:21<00:00, 21.92s/it]
# importlib-metadata-4 | 40 KB     | : 100% 1.0/1 [00:00<00:00, 15.52it/s]
# libxc-5.1.5          | 7.1 MB    | : 100% 1.0/1 [00:02<00:00,  2.32s/it]
# gdma-2.2.6           | 762 KB    | : 100% 1.0/1 [00:01<00:00,  1.14s/it]
# typing-extensions-4. | 8 KB      | : 100% 1.0/1 [00:00<00:00, 28.31it/s]
# ruamel_yaml-0.15.100 | 253 KB    | : 100% 1.0/1 [00:00<00:00, 15.68it/s]
# numpy-1.21.5         | 24 KB     | : 100% 1.0/1 [00:00<00:00, 27.13it/s]
# simint-0.7           | 9.6 MB    | : 100% 1.0/1 [00:03<00:00,  3.04s/it]
# dftd3-3.2.1          | 2.0 MB    | : 100% 1.0/1 [00:01<00:00,  1.65s/it]
# pyyaml-6.0           | 168 KB    | : 100% 1.0/1 [00:00<00:00, 23.88it/s]
# libint2-2.6.0        | 361.9 MB  | : 100% 1.0/1 [01:11<00:00, 71.72s/it]
# gau2grid-2.0.7       | 1.2 MB    | : 100% 1.0/1 [00:01<00:00,  1.99s/it]
# gcp-2.0.2            | 605 KB    | : 100% 1.0/1 [00:01<00:00,  1.64s/it]
# packaging-21.3       | 36 KB     | : 100% 1.0/1 [00:00<00:00, 23.57it/s]
# cryptography-36.0.0  | 1.3 MB    | : 100% 1.0/1 [00:00<00:00,  7.36it/s]
# qcengine-0.23.0      | 195 KB    | : 100% 1.0/1 [00:00<00:00,  1.18it/s]
# dkh-1.2              | 407 KB    | : 100% 1.0/1 [00:01<00:00,  1.21s/it]
# hdf5-1.10.6          | 3.7 MB    | : 100% 1.0/1 [00:00<00:00,  8.59it/s]
# conda-package-handli | 889 KB    | : 100% 1.0/1 [00:00<00:00, 18.90it/s]
# typing_extensions-4. | 28 KB     | : 100% 1.0/1 [00:00<00:00, 24.35it/s]
# importlib_metadata-4 | 12 KB     | : 100% 1.0/1 [00:00<00:00, 18.66it/s]
# mkl-2021.4.0         | 142.6 MB  | : 100% 1.0/1 [00:04<00:00,  4.73s/it]
# iniconfig-1.1.1      | 8 KB      | : 100% 1.0/1 [00:00<00:00, 36.95it/s]
# cffi-1.15.0          | 222 KB    | : 100% 1.0/1 [00:00<00:00, 19.56it/s]
# ambit-0.5.1          | 488 KB    | : 100% 1.0/1 [00:01<00:00,  1.28s/it]
# libgfortran-ng-7.5.0 | 22 KB     | : 100% 1.0/1 [00:00<00:00, 24.20it/s]
# decorator-5.1.1      | 12 KB     | : 100% 1.0/1 [00:00<00:00, 25.12it/s]
# pytest-7.1.1         | 454 KB    | : 100% 1.0/1 [00:00<00:00, 16.25it/s]
# ca-certificates-2022 | 117 KB    | : 100% 1.0/1 [00:00<00:00, 21.99it/s]
# pcmsolver-1.2.1.1    | 2.3 MB    | : 100% 1.0/1 [00:01<00:00,  1.79s/it]
# mkl_random-1.2.2     | 287 KB    | : 100% 1.0/1 [00:00<00:00, 22.88it/s]
# zipp-3.7.0           | 12 KB     | : 100% 1.0/1 [00:00<00:00, 26.33it/s]
# mkl_fft-1.3.1        | 172 KB    | : 100% 1.0/1 [00:00<00:00, 23.51it/s]
# libgfortran4-7.5.0   | 995 KB    | : 100% 1.0/1 [00:00<00:00, 14.48it/s]
# attrs-21.4.0         | 51 KB     | : 100% 1.0/1 [00:00<00:00, 22.89it/s]
# mkl-service-2.4.0    | 56 KB     | : 100% 1.0/1 [00:00<00:00, 20.25it/s]
# numpy-base-1.21.5    | 4.8 MB    | : 100% 1.0/1 [00:00<00:00,  4.33it/s]
# openssl-1.1.1n       | 2.5 MB    | : 100% 1.0/1 [00:00<00:00,  8.47it/s]
# brotlipy-0.7.0       | 320 KB    | : 100% 1.0/1 [00:00<00:00, 18.60it/s]
# intel-openmp-2021.4. | 4.2 MB    | : 100% 1.0/1 [00:00<00:00,  6.87it/s]
# pluggy-1.0.0         | 29 KB     | : 100% 1.0/1 [00:00<00:00, 14.94it/s]
# tomli-1.2.2          | 17 KB     | : 100% 1.0/1 [00:00<00:00, 19.53it/s]
# pip-21.2.2           | 1.8 MB    | : 100% 1.0/1 [00:00<00:00,  6.08it/s]
# importlib_resources- | 21 KB     | : 100% 1.0/1 [00:00<00:00, 19.46it/s]
# chemps2-1.8.10       | 2.4 MB    | : 100% 1.0/1 [00:02<00:00,  2.31s/it]
# networkx-2.2         | 1.6 MB    | : 100% 1.0/1 [00:00<00:00,  2.21it/s]
# conda-4.12.0         | 14.5 MB   | : 100% 1.0/1 [00:00<00:00,  1.70it/s]
# python-3.7.11        | 45.3 MB   | : 100% 1.0/1 [00:00<00:00,  1.12it/s]
# py-1.11.0            | 76 KB     | : 100% 1.0/1 [00:00<00:00, 18.87it/s]
# pyparsing-3.0.4      | 81 KB     | : 100% 1.0/1 [00:00<00:00, 21.56it/s]
# pysocks-1.7.1        | 27 KB     | : 100% 1.0/1 [00:00<00:00, 23.37it/s]
# setuptools-61.2.0    | 1007 KB   | : 100% 1.0/1 [00:00<00:00,  8.94it/s]
# certifi-2021.10.8    | 151 KB    | : 100% 1.0/1 [00:00<00:00, 21.43it/s]
# pycosat-0.6.3        | 81 KB     | : 100% 1.0/1 [00:00<00:00, 21.56it/s]
# blas-1.0             | 6 KB      | : 100% 1.0/1 [00:00<00:00, 26.79it/s]
# psutil-5.8.0         | 329 KB    | : 100% 1.0/1 [00:00<00:00, 17.38it/s]
# pydantic-1.9.0       | 1.8 MB    | : 100% 1.0/1 [00:01<00:00,  1.26s/it]
# qcelemental-0.24.0   | 240 KB    | : 100% 1.0/1 [00:01<00:00,  1.14s/it]
# py-cpuinfo-8.0.0     | 23 KB     | : 100% 1.0/1 [00:00<00:00, 23.31it/s]
# done
# done
# done

# %%
# import Psi4
import psi4
# check Psi4 version
print(psi4.__version__)
# Out:
# 1.5

# %%
psi4.core.set_output_file("log.txt")

mol = psi4.geometry("""
0 1
O  -1.551007  -0.114520   0.000000
H  -1.934259   0.762503   0.000000
H  -0.599677   0.040712   0.000000
--
0 1
O   1.350625   0.111469   0.000000
H   1.680398  -0.373741  -0.758561
H   1.680398  -0.373741   0.758561            
""")

scf_e, wfn = psi4.energy("SAPT0/jun-cc-pVDZ", return_wfn = True)
#scf_e, wfn = psi4.energy("SAPT2/jun-cc-pVDZ", return_wfn = True)
#scf_e, wfn = psi4.energy("SAPT2+/jun-cc-pVDZ", return_wfn = True)
#scf_e, wfn = psi4.energy("SAPT2+3/jun-cc-pVDZ", return_wfn = True)

# !cat log.txt
# Out:
# Scratch directory: /tmp/
#
# Scratch directory: /tmp/
#   SAPT does not make use of molecular symmetry, further calculations in C1 point group.
#    => Loading Basis Set <=
#
#     Name: JUN-CC-PVDZ
#     Role: ORBITAL
#     Keyword: BASIS
#     atoms 1, 4     entry O          line   232 file /usr/local/share/psi4/basis/jun-cc-pvdz.gbs
#     atoms 2-3, 5-6 entry H          line    36 file /usr/local/share/psi4/basis/jun-cc-pvdz.gbs
#
#    => Loading Basis Set <=
#
#     Name: JUN-CC-PVDZ
#     Role: ORBITAL
#     Keyword: BASIS
#     atoms 1, 4     entry O          line   232 file /usr/local/share/psi4/basis/jun-cc-pvdz.gbs
#     atoms 2-3, 5-6 entry H          line    36 file /usr/local/share/psi4/basis/jun-cc-pvdz.gbs
#
#
#   //>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>//
#   //              Dimer HF             //
#   //<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<//
#
#
# *** tstart() called on 7a7b43dc6779
# *** at Tue Apr 19 04:23:41 2022
#
#    => Loading Basis Set <=
#
#     Name: JUN-CC-PVDZ
#     Role: ORBITAL
#     Keyword: BASIS
#     atoms 1, 4     entry O          line   232 file /usr/local/share/psi4/basis/jun-cc-pvdz.gbs
#     atoms 2-3, 5-6 entry H          line    36 file /usr/local/share/psi4/basis/jun-cc-pvdz.gbs
#
#
#          ---------------------------------------------------------
#                                    SCF
#                by Justin Turney, Rob Parrish, Andy Simmonett
#                           and Daniel G. A. Smith
#                               RHF Reference
#                         1 Threads,    500 MiB Core
#          ---------------------------------------------------------
#
#   ==> Geometry <==
#
#     Molecular point group: c1
#     Full point group: Cs
#
#     Geometry (in Angstrom), charge = 0, multiplicity = 1:
#
#        Center              X                  Y                   Z               Mass
#     ------------   -----------------  -----------------  -----------------  -----------------
#          O           -1.485163346101    -0.114724564047     0.000000000000    15.994914619570
#          H           -1.868415346101     0.762298435953     0.000000000000     1.007825032230
#          H           -0.533833346101     0.040507435953     0.000000000000     1.007825032230
#          O            1.416468653899     0.111264435953     0.000000000000    15.994914619570
#          H            1.746241653899    -0.373945564047    -0.758561000000     1.007825032230
#          H            1.746241653899    -0.373945564047     0.758561000000     1.007825032230
#
#   Running in c1 symmetry.
#
#   Rotational constants: A =      7.15151  B =      0.21457  C =      0.21447 [cm^-1]
#   Rotational constants: A = 214396.91837  B =   6432.69061  C =   6429.61818 [MHz]
#   Nuclear repulsion =   36.662847996863405
#
#   Charge       = 0
#   Multiplicity = 1
#   Electrons    = 20
#   Nalpha       = 10
#   Nbeta        = 10
#
#   ==> Algorithm <==
#
#   SCF Algorithm Type is DF.
#   DIIS enabled.
#   MOM disabled.
#   Fractional occupation disabled.
#   Guess Type is SAD.
#   Energy threshold   = 1.00e-08
#   Density threshold  = 1.00e-08
#   Integral threshold = 1.00e-12
#
#   ==> Primary Basis <==
#
#   Basis Set: JUN-CC-PVDZ
#     Blend: JUN-CC-PVDZ
#     Number of shells: 28
#     Number of basis functions: 56
#     Number of Cartesian functions: 58
#     Spherical Harmonics?: true
#     Max angular momentum: 2
#
#    => Loading Basis Set <=
#
#     Name: (JUN-CC-PVDZ AUX)
#     Role: JKFIT
#     Keyword: DF_BASIS_SCF
#     atoms 1, 4     entry O          line   258 file /usr/local/share/psi4/basis/jun-cc-pvdz-jkfit.gbs
#     atoms 2-3, 5-6 entry H          line    70 file /usr/local/share/psi4/basis/jun-cc-pvdz-jkfit.gbs
#
#   ==> Integral Setup <==
#
#   ==> DiskDFJK: Density-Fitted J/K Matrices <==
#
#     J tasked:                  Yes
#     K tasked:                  Yes
#     wK tasked:                  No
#     OpenMP threads:              1
#     Integrals threads:           1
#     Memory [MiB]:              375
#     Algorithm:                Core
#     Integral Cache:           SAVE
#     Schwarz Cutoff:          1E-12
#     Fitting Condition:       1E-10
#
#    => Auxiliary Basis Set <=
#
#   Basis Set: (JUN-CC-PVDZ AUX)
#     Blend: JUN-CC-PVDZ-JKFIT
#     Number of shells: 90
#     Number of basis functions: 250
#     Number of Cartesian functions: 282
#     Spherical Harmonics?: true
#     Max angular momentum: 3
#
#   Minimum eigenvalue in the overlap matrix is 6.7798161243E-03.
#   Reciprocal condition number of the overlap matrix is 1.2988827670E-03.
#     Using symmetric orthogonalization.
#
#   ==> Pre-Iterations <==
#
#   SCF Guess: Superposition of Atomic Densities via on-the-fly atomic UHF (no occupation information).
#
#    -------------------------
#     Irrep   Nso     Nmo
#    -------------------------
#      A         56      56
#    -------------------------
#     Total      56      56
#    -------------------------
#
#   ==> Iterations <==
#
#                            Total Energy        Delta E     RMS |[F,P]|
#
#    @DF-RHF iter SAD:  -151.09310473785007   -1.51093e+02   0.00000e+00
#    @DF-RHF iter   1:  -151.93926611004514   -8.46161e-01   1.05004e-02 DIIS
#    @DF-RHF iter   2:  -152.03648307622080   -9.72170e-02   6.37142e-03 DIIS
#    @DF-RHF iter   3:  -152.08063040868143   -4.41473e-02   5.54464e-04 DIIS
#    @DF-RHF iter   4:  -152.08137708319393   -7.46675e-04   1.17554e-04 DIIS
#    @DF-RHF iter   5:  -152.08141415980435   -3.70766e-05   3.07758e-05 DIIS
#    @DF-RHF iter   6:  -152.08141699306265   -2.83326e-06   1.42712e-05 DIIS
#    @DF-RHF iter   7:  -152.08141741771692   -4.24654e-07   3.05114e-06 DIIS
#    @DF-RHF iter   8:  -152.08141745596930   -3.82524e-08   3.63822e-07 DIIS
#    @DF-RHF iter   9:  -152.08141745651344   -5.44134e-10   6.95690e-08 DIIS
#    @DF-RHF iter  10:  -152.08141745653319   -1.97531e-11   1.70802e-08 DIIS
#    @DF-RHF iter  11:  -152.08141745653447   -1.27898e-12   2.67142e-09 DIIS
#   Energy and wave function converged.
#
#
#   ==> Post-Iterations <==
#
#     Orbital Energies [Eh]
#     ---------------------
#
#     Doubly Occupied:
#
#        1A    -20.603072     2A    -20.545973     3A     -1.383875
#        4A     -1.326428     5A     -0.744433     6A     -0.696440
#        7A     -0.615347     8A     -0.560467     9A     -0.530147
#       10A     -0.480576
#
#     Virtual:
#
#       11A      0.113581    12A      0.155789    13A      0.165407
#       14A      0.183489    15A      0.205833    16A      0.240287
#       17A      0.241145    18A      0.301123    19A      0.303773
#       20A      0.365976    21A      0.409056    22A      0.447116
#       23A      0.915134    24A      0.966320    25A      1.020877
#       26A      1.057960    27A      1.209584    28A      1.249694
#       29A      1.288333    30A      1.364093    31A      1.391455
#       32A      1.396747    33A      1.445048    34A      1.477761
#       35A      1.506342    36A      1.578446    37A      1.702296
#       38A      1.717813    39A      1.867806    40A      1.916214
#       41A      1.990184    42A      2.100324    43A      2.450741
#       44A      2.472218    45A      2.517666    46A      2.722116
#       47A      3.237332    48A      3.280534    49A      3.301573
#       50A      3.346789    51A      3.474364    52A      3.530470
#       53A      3.849394    54A      3.943139    55A      4.116244
#       56A      4.198709
#
#     Final Occupation by Irrep:
#               A
#     DOCC [    10 ]
#
#   @DF-RHF Final Energy:  -152.08141745653447
#
#    => Energetics <=
#
#     Nuclear Repulsion Energy =             36.6628479968634053
#     One-Electron Energy =                -282.5150121744855483
#     Two-Electron Energy =                  93.7707467210876757
#     Total Energy =                       -152.0814174565344672
#
# Computation Completed
#
#
# Properties will be evaluated at   0.000000,   0.000000,   0.000000 [a0]
#
# Properties computed using the SCF density matrix
#
#   Nuclear Dipole Moment: [e a0]
#      X:     1.0217      Y:     0.0515      Z:     0.0000
#
#   Electronic Dipole Moment: [e a0]
#      X:     0.0535      Y:    -0.0042      Z:    -0.0000
#
#   Dipole Moment: [e a0]
#      X:     1.0753      Y:     0.0472      Z:    -0.0000     Total:     1.0763
#
#   Dipole Moment: [D]
#      X:     2.7331      Y:     0.1200      Z:    -0.0000     Total:     2.7357
#
#
# *** tstop() called on 7a7b43dc6779 at Tue Apr 19 04:23:41 2022
# Module time:
# 	user time   =       0.41 seconds =       0.01 minutes
# 	system time =       0.02 seconds =       0.00 minutes
# 	total time  =          0 seconds =       0.00 minutes
# Total time:
# 	user time   =       8.29 seconds =       0.14 minutes
# 	system time =       0.80 seconds =       0.01 minutes
# 	total time  =        320 seconds =       5.33 minutes
#
#   //>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>//
#   //            Monomer A HF           //
#   //<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<//
#
#
# *** tstart() called on 7a7b43dc6779
# *** at Tue Apr 19 04:23:41 2022
#
#    => Loading Basis Set <=
#
#     Name: JUN-CC-PVDZ
#     Role: ORBITAL
#     Keyword: BASIS
#     atoms 1, 4     entry O          line   232 file /usr/local/share/psi4/basis/jun-cc-pvdz.gbs
#     atoms 2-3, 5-6 entry H          line    36 file /usr/local/share/psi4/basis/jun-cc-pvdz.gbs
#
#
#          ---------------------------------------------------------
#                                    SCF
#                by Justin Turney, Rob Parrish, Andy Simmonett
#                           and Daniel G. A. Smith
#                               RHF Reference
#                         1 Threads,    500 MiB Core
#          ---------------------------------------------------------
#
#   ==> Geometry <==
#
#     Molecular point group: c1
#     Full point group: Cs
#
#     Geometry (in Angstrom), charge = 0, multiplicity = 1:
#
#        Center              X                  Y                   Z               Mass
#     ------------   -----------------  -----------------  -----------------  -----------------
#          O           -1.485163346101    -0.114724564047     0.000000000000    15.994914619570
#          H           -1.868415346101     0.762298435953     0.000000000000     1.007825032230
#          H           -0.533833346101     0.040507435953     0.000000000000     1.007825032230
#       Gh(O)           1.416468653899     0.111264435953     0.000000000000    15.994914619570
#       Gh(H)           1.746241653899    -0.373945564047    -0.758561000000     1.007825032230
#       Gh(H)           1.746241653899    -0.373945564047     0.758561000000     1.007825032230
#
#   Running in c1 symmetry.
#
#   Rotational constants: A =      7.15151  B =      0.21457  C =      0.21447 [cm^-1]
#   Rotational constants: A = 214396.91837  B =   6432.69061  C =   6429.61818 [MHz]
#   Nuclear repulsion =    9.163830181985562
#
#   Charge       = 0
#   Multiplicity = 1
#   Electrons    = 10
#   Nalpha       = 5
#   Nbeta        = 5
#
#   ==> Algorithm <==
#
#   SCF Algorithm Type is DF.
#   DIIS enabled.
#   MOM disabled.
#   Fractional occupation disabled.
#   Guess Type is SAD.
#   Energy threshold   = 1.00e-08
#   Density threshold  = 1.00e-08
#   Integral threshold = 1.00e-12
#
#   ==> Primary Basis <==
#
#   Basis Set: JUN-CC-PVDZ
#     Blend: JUN-CC-PVDZ
#     Number of shells: 28
#     Number of basis functions: 56
#     Number of Cartesian functions: 58
#     Spherical Harmonics?: true
#     Max angular momentum: 2
#
#    => Loading Basis Set <=
#
#     Name: (JUN-CC-PVDZ AUX)
#     Role: JKFIT
#     Keyword: DF_BASIS_SCF
#     atoms 1, 4     entry O          line   258 file /usr/local/share/psi4/basis/jun-cc-pvdz-jkfit.gbs
#     atoms 2-3, 5-6 entry H          line    70 file /usr/local/share/psi4/basis/jun-cc-pvdz-jkfit.gbs
#
#   ==> Integral Setup <==
#
#   ==> DiskDFJK: Density-Fitted J/K Matrices <==
#
#     J tasked:                  Yes
#     K tasked:                  Yes
#     wK tasked:                  No
#     OpenMP threads:              1
#     Integrals threads:           1
#     Memory [MiB]:              375
#     Algorithm:                Core
#     Integral Cache:           LOAD
#     Schwarz Cutoff:          1E-12
#     Fitting Condition:       1E-10
#
#    => Auxiliary Basis Set <=
#
#   Basis Set: (JUN-CC-PVDZ AUX)
#     Blend: JUN-CC-PVDZ-JKFIT
#     Number of shells: 90
#     Number of basis functions: 250
#     Number of Cartesian functions: 282
#     Spherical Harmonics?: true
#     Max angular momentum: 3
#
#   Minimum eigenvalue in the overlap matrix is 6.7798161243E-03.
#   Reciprocal condition number of the overlap matrix is 1.2988827670E-03.
#     Using symmetric orthogonalization.
#
#   ==> Pre-Iterations <==
#
#   SCF Guess: Superposition of Atomic Densities via on-the-fly atomic UHF (no occupation information).
#
#    -------------------------
#     Irrep   Nso     Nmo
#    -------------------------
#      A         56      56
#    -------------------------
#     Total      56      56
#    -------------------------
#
#   ==> Iterations <==
#
#                            Total Energy        Delta E     RMS |[F,P]|
#
#    @DF-RHF iter SAD:   -75.51096488684065   -7.55110e+01   0.00000e+00
#    @DF-RHF iter   1:   -75.95999919423083   -4.49034e-01   7.72507e-03 DIIS
#    @DF-RHF iter   2:   -76.01115415088174   -5.11550e-02   4.86932e-03 DIIS
#    @DF-RHF iter   3:   -76.03698983000425   -2.58357e-02   3.94482e-04 DIIS
#    @DF-RHF iter   4:   -76.03735854299234   -3.68713e-04   8.75969e-05 DIIS
#    @DF-RHF iter   5:   -76.03737808882325   -1.95458e-05   1.68568e-05 DIIS
#    @DF-RHF iter   6:   -76.03737926992106   -1.18110e-06   3.67624e-06 DIIS
#    @DF-RHF iter   7:   -76.03737933648858   -6.65675e-08   4.74173e-07 DIIS
#    @DF-RHF iter   8:   -76.03737933744841   -9.59830e-10   8.20560e-08 DIIS
#    @DF-RHF iter   9:   -76.03737933747601   -2.75975e-11   2.17718e-08 DIIS
#    @DF-RHF iter  10:   -76.03737933747763   -1.62004e-12   2.37346e-09 DIIS
#   Energy and wave function converged.
#
#
#   ==> Post-Iterations <==
#
#     Orbital Energies [Eh]
#     ---------------------
#
#     Doubly Occupied:
#
#        1A    -20.577348     2A     -1.354910     3A     -0.717035
#        4A     -0.583890     5A     -0.508542
#
#     Virtual:
#
#        6A      0.077058     7A      0.131148     8A      0.141446
#        9A      0.150454    10A      0.191039    11A      0.217979
#       12A      0.231385    13A      0.274707    14A      0.342650
#       15A      0.385551    16A      0.396892    17A      0.430286
#       18A      0.688314    19A      0.823400    20A      0.843642
#       21A      0.916089    22A      0.950468    23A      1.037700
#       24A      1.261430    25A      1.359314    26A      1.368625
#       27A      1.472178    28A      1.523556    29A      1.672495
#       30A      1.785360    31A      1.817804    32A      1.915855
#       33A      1.919362    34A      1.991314    35A      2.037182
#       36A      2.173435    37A      2.336047    38A      2.486060
#       39A      2.541671    40A      2.587023    41A      2.829816
#       42A      3.210315    43A      3.270462    44A      3.320104
#       45A      3.503839    46A      3.910437    47A      4.166983
#       48A      4.418755    49A      4.493515    50A      4.692623
#       51A      4.807062    52A      4.971844    53A      5.537277
#       54A      6.556219    55A      6.988943    56A     33.494131
#
#     Final Occupation by Irrep:
#               A
#     DOCC [     5 ]
#
#   @DF-RHF Final Energy:   -76.03737933747763
#
#    => Energetics <=
#
#     Nuclear Repulsion Energy =              9.1638301819855617
#     One-Electron Energy =                -122.9189705556720753
#     Two-Electron Energy =                  37.7177610362088842
#     Total Energy =                        -76.0373793374776312
#
# Computation Completed
#
#
# Properties will be evaluated at   0.000000,   0.000000,   0.000000 [a0]
#
# Properties computed using the SCF density matrix
#
#   Nuclear Dipole Moment: [e a0]
#      X:   -26.9920      Y:    -0.2173      Z:     0.0000
#
#   Electronic Dipole Moment: [e a0]
#      X:    27.4045      Y:     0.9743      Z:    -0.0000
#
#   Dipole Moment: [e a0]
#      X:     0.4125      Y:     0.7570      Z:    -0.0000     Total:     0.8621
#
#   Dipole Moment: [D]
#      X:     1.0484      Y:     1.9242      Z:    -0.0000     Total:     2.1913
#
#
# *** tstop() called on 7a7b43dc6779 at Tue Apr 19 04:23:41 2022
# Module time:
# 	user time   =       0.33 seconds =       0.01 minutes
# 	system time =       0.01 seconds =       0.00 minutes
# 	total time  =          0 seconds =       0.00 minutes
# Total time:
# 	user time   =       8.63 seconds =       0.14 minutes
# 	system time =       0.81 seconds =       0.01 minutes
# 	total time  =        320 seconds =       5.33 minutes
#
#   //>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>//
#   //            Monomer B HF           //
#   //<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<//
#
#
# *** tstart() called on 7a7b43dc6779
# *** at Tue Apr 19 04:23:41 2022
#
#    => Loading Basis Set <=
#
#     Name: JUN-CC-PVDZ
#     Role: ORBITAL
#     Keyword: BASIS
#     atoms 1, 4     entry O          line   232 file /usr/local/share/psi4/basis/jun-cc-pvdz.gbs
#     atoms 2-3, 5-6 entry H          line    36 file /usr/local/share/psi4/basis/jun-cc-pvdz.gbs
#
#
#          ---------------------------------------------------------
#                                    SCF
#                by Justin Turney, Rob Parrish, Andy Simmonett
#                           and Daniel G. A. Smith
#                               RHF Reference
#                         1 Threads,    500 MiB Core
#          ---------------------------------------------------------
#
#   ==> Geometry <==
#
#     Molecular point group: c1
#     Full point group: Cs
#
#     Geometry (in Angstrom), charge = 0, multiplicity = 1:
#
#        Center              X                  Y                   Z               Mass
#     ------------   -----------------  -----------------  -----------------  -----------------
#       Gh(O)          -1.485163346101    -0.114724564047     0.000000000000    15.994914619570
#       Gh(H)          -1.868415346101     0.762298435953     0.000000000000     1.007825032230
#       Gh(H)          -0.533833346101     0.040507435953     0.000000000000     1.007825032230
#          O            1.416468653899     0.111264435953     0.000000000000    15.994914619570
#          H            1.746241653899    -0.373945564047    -0.758561000000     1.007825032230
#          H            1.746241653899    -0.373945564047     0.758561000000     1.007825032230
#
#   Running in c1 symmetry.
#
#   Rotational constants: A =      7.15151  B =      0.21457  C =      0.21447 [cm^-1]
#   Rotational constants: A = 214396.91837  B =   6432.69061  C =   6429.61818 [MHz]
#   Nuclear repulsion =    9.178038940979064
#
#   Charge       = 0
#   Multiplicity = 1
#   Electrons    = 10
#   Nalpha       = 5
#   Nbeta        = 5
#
#   ==> Algorithm <==
#
#   SCF Algorithm Type is DF.
#   DIIS enabled.
#   MOM disabled.
#   Fractional occupation disabled.
#   Guess Type is SAD.
#   Energy threshold   = 1.00e-08
#   Density threshold  = 1.00e-08
#   Integral threshold = 1.00e-12
#
#   ==> Primary Basis <==
#
#   Basis Set: JUN-CC-PVDZ
#     Blend: JUN-CC-PVDZ
#     Number of shells: 28
#     Number of basis functions: 56
#     Number of Cartesian functions: 58
#     Spherical Harmonics?: true
#     Max angular momentum: 2
#
#    => Loading Basis Set <=
#
#     Name: (JUN-CC-PVDZ AUX)
#     Role: JKFIT
#     Keyword: DF_BASIS_SCF
#     atoms 1, 4     entry O          line   258 file /usr/local/share/psi4/basis/jun-cc-pvdz-jkfit.gbs
#     atoms 2-3, 5-6 entry H          line    70 file /usr/local/share/psi4/basis/jun-cc-pvdz-jkfit.gbs
#
#   ==> Integral Setup <==
#
#   ==> DiskDFJK: Density-Fitted J/K Matrices <==
#
#     J tasked:                  Yes
#     K tasked:                  Yes
#     wK tasked:                  No
#     OpenMP threads:              1
#     Integrals threads:           1
#     Memory [MiB]:              375
#     Algorithm:                Core
#     Integral Cache:           LOAD
#     Schwarz Cutoff:          1E-12
#     Fitting Condition:       1E-10
#
#    => Auxiliary Basis Set <=
#
#   Basis Set: (JUN-CC-PVDZ AUX)
#     Blend: JUN-CC-PVDZ-JKFIT
#     Number of shells: 90
#     Number of basis functions: 250
#     Number of Cartesian functions: 282
#     Spherical Harmonics?: true
#     Max angular momentum: 3
#
#   Minimum eigenvalue in the overlap matrix is 6.7798161243E-03.
#   Reciprocal condition number of the overlap matrix is 1.2988827670E-03.
#     Using symmetric orthogonalization.
#
#   ==> Pre-Iterations <==
#
#   SCF Guess: Superposition of Atomic Densities via on-the-fly atomic UHF (no occupation information).
#
#    -------------------------
#     Irrep   Nso     Nmo
#    -------------------------
#      A         56      56
#    -------------------------
#     Total      56      56
#    -------------------------
#
#   ==> Iterations <==
#
#                            Total Energy        Delta E     RMS |[F,P]|
#
#    @DF-RHF iter SAD:   -75.51277955558405   -7.55128e+01   0.00000e+00
#    @DF-RHF iter   1:   -75.96079401527663   -4.48014e-01   7.72045e-03 DIIS
#    @DF-RHF iter   2:   -76.01163690574980   -5.08429e-02   4.87843e-03 DIIS
#    @DF-RHF iter   3:   -76.03757934861535   -2.59424e-02   3.91447e-04 DIIS
#    @DF-RHF iter   4:   -76.03794366866791   -3.64320e-04   8.64713e-05 DIIS
#    @DF-RHF iter   5:   -76.03796291604066   -1.92474e-05   1.69824e-05 DIIS
#    @DF-RHF iter   6:   -76.03796413504945   -1.21901e-06   3.74671e-06 DIIS
#    @DF-RHF iter   7:   -76.03796420447676   -6.94273e-08   4.93119e-07 DIIS
#    @DF-RHF iter   8:   -76.03796420552185   -1.04508e-09   8.43391e-08 DIIS
#    @DF-RHF iter   9:   -76.03796420555074   -2.88907e-11   2.24029e-08 DIIS
#    @DF-RHF iter  10:   -76.03796420555258   -1.84741e-12   2.47929e-09 DIIS
#   Energy and wave function converged.
#
#
#   ==> Post-Iterations <==
#
#     Orbital Energies [Eh]
#     ---------------------
#
#     Doubly Occupied:
#
#        1A    -20.577371     2A     -1.355542     3A     -0.718341
#        4A     -0.584096     5A     -0.508822
#
#     Virtual:
#
#        6A      0.104692     7A      0.133848     8A      0.161668
#        9A      0.163041    10A      0.193248    11A      0.207790
#       12A      0.223033    13A      0.301069    14A      0.319108
#       15A      0.383388    16A      0.411747    17A      0.462121
#       18A      0.748270    19A      0.854155    20A      0.878064
#       21A      0.936052    22A      1.003369    23A      1.044323
#       24A      1.243599    25A      1.284134    26A      1.400378
#       27A      1.465123    28A      1.522489    29A      1.686854
#       30A      1.833816    31A      1.885003    32A      1.894867
#       33A      1.990569    34A      1.990884    35A      2.144410
#       36A      2.145851    37A      2.409502    38A      2.473477
#       39A      2.509548    40A      2.692517    41A      2.877330
#       42A      3.257933    43A      3.278194    44A      3.317372
#       45A      3.505242    46A      3.877590    47A      4.134939
#       48A      4.470618    49A      4.545172    50A      4.738700
#       51A      4.876309    52A      5.069522    53A      5.476797
#       54A      6.583845    55A      7.056009    56A     33.538436
#
#     Final Occupation by Irrep:
#               A
#     DOCC [     5 ]
#
#   @DF-RHF Final Energy:   -76.03796420555258
#
#    => Energetics <=
#
#     Nuclear Repulsion Energy =              9.1780389409790644
#     One-Electron Energy =                -122.9436632328517760
#     Two-Electron Energy =                  37.7276600863201281
#     Total Energy =                        -76.0379642055525835
#
# Computation Completed
#
#
# Properties will be evaluated at   0.000000,   0.000000,   0.000000 [a0]
#
# Properties computed using the SCF density matrix
#
#   Nuclear Dipole Moment: [e a0]
#      X:    28.0137      Y:     0.2688      Z:     0.0000
#
#   Electronic Dipole Moment: [e a0]
#      X:   -27.5492      Y:    -0.9690      Z:    -0.0000
#
#   Dipole Moment: [e a0]
#      X:     0.4646      Y:    -0.7002      Z:    -0.0000     Total:     0.8403
#
#   Dipole Moment: [D]
#      X:     1.1808      Y:    -1.7798      Z:    -0.0000     Total:     2.1359
#
#
# *** tstop() called on 7a7b43dc6779 at Tue Apr 19 04:23:42 2022
# Module time:
# 	user time   =       0.34 seconds =       0.01 minutes
# 	system time =       0.01 seconds =       0.00 minutes
# 	total time  =          1 seconds =       0.02 minutes
# Total time:
# 	user time   =       8.98 seconds =       0.15 minutes
# 	system time =       0.82 seconds =       0.01 minutes
# 	total time  =        321 seconds =       5.35 minutes
#   Constructing Basis Sets for SAPT...
#
#    => Loading Basis Set <=
#
#     Name: (JUN-CC-PVDZ AUX)
#     Role: RIFIT
#     Keyword: DF_BASIS_SAPT
#     atoms 1, 4     entry O          line   188 file /usr/local/share/psi4/basis/jun-cc-pvdz-ri.gbs
#     atoms 2-3, 5-6 entry H          line    30 file /usr/local/share/psi4/basis/jun-cc-pvdz-ri.gbs
#
#
#   //>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>//
#   //               SAPT0               //
#   //<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<//
#
#
# *** tstart() called on 7a7b43dc6779
# *** at Tue Apr 19 04:23:42 2022
#
#         SAPT0
#     Ed Hohenstein
#      6 June 2009
#
#       Orbital Information
#   --------------------------
#     NSO        =        56
#     NMO        =        56
#     NRI        =       186
#     NOCC A     =         5
#     NOCC B     =         5
#     FOCC A     =         0
#     FOCC B     =         0
#     NVIR A     =        51
#     NVIR B     =        51
#
#     Elst10,r            =    -0.014075016516 [Eh]
#     Exch10              =     0.011386840955 [Eh]
#     Exch10 (S^2)        =     0.011304411814 [Eh]
#
#     Iter     Energy [mEh]          dE [mEh]         Residual      Time [s]
#        1      -1.26401286       1.264012860       5.058052193             0
#        2      -1.44613989       0.182127030       1.625376550             0
#        3      -1.46292950       0.016789614       0.488198895             0
#        4      -1.45800604      -0.004923469       0.138946667             0
#        5      -1.45703846      -0.000967574       0.021159013             0
#        6      -1.45738244       0.000343983       0.003814829             0
#        7      -1.45734186      -0.000040588       0.000780425             0
#        8      -1.45734421       0.000002355       0.000147526             0
#        9      -1.45734491       0.000000700       0.000033449             0
#       10      -1.45734470      -0.000000214       0.000004621             0
#       11      -1.45734472       0.000000020       0.000000548             0
#
#     CHF Iterations converged
#
#
#     Iter     Energy [mEh]          dE [mEh]         Residual      Time [s]
#        1      -2.38087305       2.380873050       9.303096538             0
#        2      -3.02765592       0.646782870       3.149895656             0
#        3      -3.06814743       0.040491510       0.884558655             0
#        4      -3.05493273      -0.013214703       0.200833076             0
#        5      -3.05343022      -0.001502508       0.039807873             0
#        6      -3.05416146       0.000731242       0.006768099             0
#        7      -3.05406434      -0.000097123       0.001270022             0
#        8      -3.05407461       0.000010268       0.000208989             0
#        9      -3.05407372      -0.000000887       0.000052143             0
#       10      -3.05407374       0.000000024       0.000013515             0
#       11      -3.05407377       0.000000032       0.000002337             0
#       12      -3.05407377      -0.000000007       0.000000392             0
#
#     CHF Iterations converged
#
#     Ind20,r (A<-B)      =    -0.001457344717 [Eh]
#     Ind20,r (B<-A)      =    -0.003054073767 [Eh]
#     Ind20,r             =    -0.004511418485 [Eh]
#     Exch-Ind20,r (A<-B) =     0.000948220633 [Eh]
#     Exch-Ind20,r (B<-A) =     0.001571916210 [Eh]
#     Exch-Ind20,r        =     0.002520136843 [Eh]
#     Disp20              =    -0.002577749702 [Eh]
#     Disp20 (SS)         =    -0.001288874851 [Eh]
#     Disp20 (OS)         =    -0.001288874851 [Eh]
#     Exch-Disp20         =     0.000548592567 [Eh]
#     Exch-Disp20 (SS)    =     0.000314707103 [Eh]
#     Exch-Disp20 (OS)    =     0.000233885464 [Eh]
#
#     SAPT Results
#   --------------------------------------------------------------------------------------------------------
#     Electrostatics                -14.07501652 [mEh]      -8.83220621 [kcal/mol]     -36.95395077 [kJ/mol]
#       Elst10,r                    -14.07501652 [mEh]      -8.83220621 [kcal/mol]     -36.95395077 [kJ/mol]
#
#     Exchange                       11.38684096 [mEh]       7.14535058 [kcal/mol]      29.89614681 [kJ/mol]
#       Exch10                       11.38684096 [mEh]       7.14535058 [kcal/mol]      29.89614681 [kJ/mol]
#       Exch10(S^2)                  11.30441181 [mEh]       7.09362551 [kcal/mol]      29.67972913 [kJ/mol]
#
#     Induction                      -3.38573794 [mEh]      -2.12458264 [kcal/mol]      -8.88925375 [kJ/mol]
#       Ind20,r                      -4.51141848 [mEh]      -2.83095784 [kcal/mol]     -11.84472760 [kJ/mol]
#       Exch-Ind20,r                  2.52013684 [mEh]       1.58140974 [kcal/mol]       6.61661837 [kJ/mol]
#       delta HF,r (2)               -1.39445630 [mEh]      -0.87503454 [kcal/mol]      -3.66114452 [kJ/mol]
#
#     Dispersion                     -2.02915714 [mEh]      -1.27331533 [kcal/mol]      -5.32755133 [kJ/mol]
#       Disp20                       -2.57774970 [mEh]      -1.61756236 [kcal/mol]      -6.76788091 [kJ/mol]
#       Exch-Disp20                   0.54859257 [mEh]       0.34424703 [kcal/mol]       1.44032959 [kJ/mol]
#       Disp20 (SS)                  -1.28887485 [mEh]      -0.80878118 [kcal/mol]      -3.38394046 [kJ/mol]
#       Disp20 (OS)                  -1.28887485 [mEh]      -0.80878118 [kcal/mol]      -3.38394046 [kJ/mol]
#       Exch-Disp20 (SS)              0.31470710 [mEh]       0.19748169 [kcal/mol]       0.82626338 [kJ/mol]
#       Exch-Disp20 (OS)              0.23388546 [mEh]       0.14676534 [kcal/mol]       0.61406620 [kJ/mol]
#
#   Total HF                         -6.07391350 [mEh]      -3.81143827 [kcal/mol]     -15.94705771 [kJ/mol]
#   Total SAPT0                      -8.10307064 [mEh]      -5.08475359 [kcal/mol]     -21.27460903 [kJ/mol]
#
#   Special recipe for scaled SAPT0 (see Manual):
#     Electrostatics sSAPT0         -14.07501652 [mEh]      -8.83220621 [kcal/mol]     -36.95395077 [kJ/mol]
#     Exchange sSAPT0                11.38684096 [mEh]       7.14535058 [kcal/mol]      29.89614681 [kJ/mol]
#     Induction sSAPT0               -3.33020623 [mEh]      -2.08973596 [kcal/mol]      -8.74345524 [kJ/mol]
#     Dispersion sSAPT0              -2.01706879 [mEh]      -1.26572977 [kcal/mol]      -5.29581338 [kJ/mol]
#   Total sSAPT0                     -8.03545057 [mEh]      -5.04232136 [kcal/mol]     -21.09707258 [kJ/mol]
#   --------------------------------------------------------------------------------------------------------
#
# *** tstop() called on 7a7b43dc6779 at Tue Apr 19 04:23:42 2022
# Module time:
# 	user time   =       0.19 seconds =       0.00 minutes
# 	system time =       0.05 seconds =       0.00 minutes
# 	total time  =          0 seconds =       0.00 minutes
# Total time:
# 	user time   =       9.21 seconds =       0.15 minutes
# 	system time =       0.87 seconds =       0.01 minutes
# 	total time  =        321 seconds =       5.35 minutes
#
#
# Warning! sapt0 does not have an associated derived wavefunction.The returned wavefunction is the dimer SCF wavefunction.
