# %%
# set conda
# !wget -c https://repo.continuum.io/miniconda/Miniconda3-latest-Linux-x86_64.sh
# !chmod +x Miniconda3-latest-Linux-x86_64.sh
# !bash ./Miniconda3-latest-Linux-x86_64.sh -b -f -p /usr/local

# install psi4
# !conda install -y psi4 python=3.7 -c psi4

# set path
import sys
sys.path.append("/usr/local/lib/python3.7/site-packages/")
# Out:
# --2022-04-19 05:39:20--  https://repo.continuum.io/miniconda/Miniconda3-latest-Linux-x86_64.sh
# Resolving repo.continuum.io (repo.continuum.io)... 104.18.200.79, 104.18.201.79, 2606:4700::6812:c94f, ...
# Connecting to repo.continuum.io (repo.continuum.io)|104.18.200.79|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: https://repo.anaconda.com/miniconda/Miniconda3-latest-Linux-x86_64.sh [following]
# --2022-04-19 05:39:20--  https://repo.anaconda.com/miniconda/Miniconda3-latest-Linux-x86_64.sh
# Resolving repo.anaconda.com (repo.anaconda.com)... 104.16.130.3, 104.16.131.3, 2606:4700::6810:8203, ...
# Connecting to repo.anaconda.com (repo.anaconda.com)|104.16.130.3|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 75660608 (72M) [application/x-sh]
# Saving to: ‘Miniconda3-latest-Linux-x86_64.sh’
#
# Miniconda3-latest-L 100%[===================>]  72.16M  57.5MB/s    in 1.3s
#
# ...

# %%
# import Psi4
import psi4
# check Psi4 version
print(psi4.__version__)
# Out:
# 1.5

# %%
psi4.core.set_output_file("log.txt")

# 23b_cyclobutylfuran_dimAC_3B-69.xyz
mol = psi4.geometry("""
0 1
C 4.6315090000 12.9838810000 9.7236230000
C 3.7051610000 13.2808070000 10.6597300000
C 2.8204210000 14.1267870000 11.5665100000
C 2.2363970000 12.7617780000 12.1238960000
C 3.1969160000 12.0598300000 11.1740460000
C 3.8287580000 11.0485510000 10.5407800000
O 4.7205780000 11.6084360000 9.6393230000
H 5.2790900000 13.5271280000 9.0619020000
H 3.3618000000 14.7136480000 12.3078850000
H 2.0982190000 14.7608050000 11.0544200000
H 2.4147590000 12.5950040000 13.1827260000
H 1.1811000000 12.6080980000 11.9094200000
H 3.8105800000 9.9747570000 10.5454260000
--
0 1
C 5.0839140000 6.7061190000 9.6334190000
C 6.0102620000 6.4091930000 8.6973130000
C 6.8950020000 5.5632130000 7.7905320000
C 7.4790250000 6.9282220000 7.2331460000
C 6.5185070000 7.6301700000 8.1829960000
C 5.8866650000 8.6414490000 8.8162620000
O 4.9948440000 8.0815640000 9.7177190000
H 4.4363320000 6.1628720000 10.2951400000
H 6.3536230000 4.9763520000 7.0491570000
H 7.6172040000 4.9291950000 8.3026220000
H 7.3006630000 7.0949960000 6.1743160000
H 8.5343230000 7.0819020000 7.4476220000
H 5.9048430000 9.7152430000 8.8116160000
""")

scf_e, wfn = psi4.optimize("B3LYP-D/6-311G(d)", return_wfn = True)
# Out:
# Optimizer: Optimization complete!

# %%
xyz = mol.save_string_xyz()
print (xyz)
# Out:
# 0 1
#  C   -0.140399361318    3.152853481466    0.187667911559
#  C   -1.163599236781    3.433099582736    1.026922085510
#  C   -2.168271039914    4.259239118762    1.822586696650
#  C   -2.737524020373    2.877422923031    2.367477481804
#  C   -1.671241462228    2.199965781876    1.513652929833
#  C   -0.945141265642    1.202143132872    0.958786178612
#  O    0.002788565421    1.781739374345    0.138515740574
#  H    0.557336786751    3.703390558297   -0.422451567656
#  H   -1.739965064646    4.906934780734    2.592389054079
#  H   -2.879024506314    4.838162855094    1.226599644259
#  H   -2.634362018144    2.740268190739    3.447300755203
#  H   -3.772080259569    2.670476286018    2.080452956672
#  H   -0.914887251898    0.125172909340    0.987427372061
#  C    0.254624797523   -3.151484115280   -0.067921500033
#  C    1.149334814376   -3.433411424166   -1.042526456081
#  C    2.009871757676   -4.261634507216   -1.990401181568
# ...

# %%
fchk_writer = psi4.core.FCHKWriter(wfn)
fchk_writer.write("test.fchk")

# %%
scf_e, wfn = psi4.energy("SAPT0/jun-cc-pVDZ", return_wfn = True)
#scf_e, wfn = psi4.energy("SAPT2/jun-cc-pVDZ", return_wfn = True)
#scf_e, wfn = psi4.energy("SAPT2+/jun-cc-pVDZ", return_wfn = True)
#scf_e, wfn = psi4.energy("SAPT2+3/jun-cc-pVDZ", return_wfn = True)

# !cat log.txt
# Out:
# Scratch directory: /tmp/
#
# Scratch directory: /tmp/
# gradient() will perform analytic gradient computation.
#
# *** tstart() called on 6d112474c659
# *** at Tue Apr 19 06:34:19 2022
#
#    => Loading Basis Set <=
#
#     Name: 6-311G(D)
#     Role: ORBITAL
#     Keyword: BASIS
#     atoms 1-6, 14-19  entry C          line   114 file /usr/local/share/psi4/basis/6-311g_d_.gbs
#     atoms 7, 20       entry O          line   152 file /usr/local/share/psi4/basis/6-311g_d_.gbs
#     atoms 8-13, 21-26 entry H          line    37 file /usr/local/share/psi4/basis/6-311g_d_.gbs
#
#    => B3LYP-D2: Empirical Dispersion <=
#
#     Grimme's -D2 Dispersion Correction
#     Grimme, S. (2006), J. Comp. Chem., 27: 1787-1799
#
#         s6 =       1.050000
#     alpha6 =      20.000000
#        sr6 =       1.100000
#
#
#          ---------------------------------------------------------
#                                    SCF
#                by Justin Turney, Rob Parrish, Andy Simmonett
# ...
