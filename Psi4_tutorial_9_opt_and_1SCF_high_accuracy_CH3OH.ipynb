# %%
# set conda
# !wget -c https://repo.continuum.io/miniconda/Miniconda3-latest-Linux-x86_64.sh
# !chmod +x Miniconda3-latest-Linux-x86_64.sh
# !bash ./Miniconda3-latest-Linux-x86_64.sh -b -f -p /usr/local

# install psi4
# !conda install -y psi4 python=3.7 -c psi4

# set path
import sys
sys.path.append("/usr/local/lib/python3.7/site-packages/")
# Out:
# --2022-04-19 09:43:13--  https://repo.continuum.io/miniconda/Miniconda3-latest-Linux-x86_64.sh
# Resolving repo.continuum.io (repo.continuum.io)... 104.18.200.79, 104.18.201.79, 2606:4700::6812:c84f, ...
# Connecting to repo.continuum.io (repo.continuum.io)|104.18.200.79|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: https://repo.anaconda.com/miniconda/Miniconda3-latest-Linux-x86_64.sh [following]
# --2022-04-19 09:43:13--  https://repo.anaconda.com/miniconda/Miniconda3-latest-Linux-x86_64.sh
# Resolving repo.anaconda.com (repo.anaconda.com)... 104.16.130.3, 104.16.131.3, 2606:4700::6810:8303, ...
# Connecting to repo.anaconda.com (repo.anaconda.com)|104.16.130.3|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 75660608 (72M) [application/x-sh]
# Saving to: ‘Miniconda3-latest-Linux-x86_64.sh’
#
# Miniconda3-latest-L 100%[===================>]  72.16M   184MB/s    in 0.4s
#
# 2022-04-19 09:43:14 (184 MB/s) - ‘Miniconda3-latest-Linux-x86_64.sh’ saved [75660608/75660608]
#
# PREFIX=/usr/local
# Unpacking payload ...
# done
# done
#
# ## Package Plan ##
#
#   environment location: /usr/local
#
#   added / updated specs:
#     - _libgcc_mutex==0.1=main
#     - _openmp_mutex==4.5=1_gnu
#     - brotlipy==0.7.0=py39h27cfd23_1003
#     - ca-certificates==2021.10.26=h06a4308_2
#     - certifi==2021.10.8=py39h06a4308_2
#     - cffi==1.15.0=py39hd667e15_1
#     - charset-normalizer==2.0.4=pyhd3eb1b0_0
#     - conda-content-trust==0.1.1=pyhd3eb1b0_0
#     - conda-package-handling==1.7.3=py39h27cfd23_1
#     - conda==4.11.0=py39h06a4308_0
#     - cryptography==36.0.0=py39h9ce1e76_0
#     - idna==3.3=pyhd3eb1b0_0
#     - ld_impl_linux-64==2.35.1=h7274673_9
#     - libffi==3.3=he6710b0_2
#     - libgcc-ng==9.3.0=h5101ec6_17
#     - libgomp==9.3.0=h5101ec6_17
#     - libstdcxx-ng==9.3.0=hd4cf53a_17
#     - ncurses==6.3=h7f8727e_2
#     - openssl==1.1.1m=h7f8727e_0
#     - pip==21.2.4=py39h06a4308_0
#     - pycosat==0.6.3=py39h27cfd23_0
#     - pycparser==2.21=pyhd3eb1b0_0
#     - pyopenssl==21.0.0=pyhd3eb1b0_1
#     - pysocks==1.7.1=py39h06a4308_0
#     - python==3.9.7=h12debd9_1
#     - readline==8.1.2=h7f8727e_1
#     - requests==2.27.1=pyhd3eb1b0_0
#     - ruamel_yaml==0.15.100=py39h27cfd23_0
#     - setuptools==58.0.4=py39h06a4308_0
#     - six==1.16.0=pyhd3eb1b0_0
#     - sqlite==3.37.0=hc218d9a_0
#     - tk==8.6.11=h1ccaba5_0
#     - tqdm==4.62.3=pyhd3eb1b0_1
#     - tzdata==2021e=hda174b7_0
#     - urllib3==1.26.7=pyhd3eb1b0_0
#     - wheel==0.37.1=pyhd3eb1b0_0
#     - xz==5.2.5=h7b6447c_0
#     - yaml==0.2.5=h7b6447c_0
#     - zlib==1.2.11=h7f8727e_4
#
#
# The following NEW packages will be INSTALLED:
#
#   _libgcc_mutex      pkgs/main/linux-64::_libgcc_mutex-0.1-main
#   _openmp_mutex      pkgs/main/linux-64::_openmp_mutex-4.5-1_gnu
#   brotlipy           pkgs/main/linux-64::brotlipy-0.7.0-py39h27cfd23_1003
#   ca-certificates    pkgs/main/linux-64::ca-certificates-2021.10.26-h06a4308_2
#   certifi            pkgs/main/linux-64::certifi-2021.10.8-py39h06a4308_2
#   cffi               pkgs/main/linux-64::cffi-1.15.0-py39hd667e15_1
#   charset-normalizer pkgs/main/noarch::charset-normalizer-2.0.4-pyhd3eb1b0_0
#   conda              pkgs/main/linux-64::conda-4.11.0-py39h06a4308_0
#   conda-content-tru~ pkgs/main/noarch::conda-content-trust-0.1.1-pyhd3eb1b0_0
#   conda-package-han~ pkgs/main/linux-64::conda-package-handling-1.7.3-py39h27cfd23_1
#   cryptography       pkgs/main/linux-64::cryptography-36.0.0-py39h9ce1e76_0
#   idna               pkgs/main/noarch::idna-3.3-pyhd3eb1b0_0
#   ld_impl_linux-64   pkgs/main/linux-64::ld_impl_linux-64-2.35.1-h7274673_9
#   libffi             pkgs/main/linux-64::libffi-3.3-he6710b0_2
#   libgcc-ng          pkgs/main/linux-64::libgcc-ng-9.3.0-h5101ec6_17
#   libgomp            pkgs/main/linux-64::libgomp-9.3.0-h5101ec6_17
#   libstdcxx-ng       pkgs/main/linux-64::libstdcxx-ng-9.3.0-hd4cf53a_17
#   ncurses            pkgs/main/linux-64::ncurses-6.3-h7f8727e_2
#   openssl            pkgs/main/linux-64::openssl-1.1.1m-h7f8727e_0
#   pip                pkgs/main/linux-64::pip-21.2.4-py39h06a4308_0
#   pycosat            pkgs/main/linux-64::pycosat-0.6.3-py39h27cfd23_0
#   pycparser          pkgs/main/noarch::pycparser-2.21-pyhd3eb1b0_0
#   pyopenssl          pkgs/main/noarch::pyopenssl-21.0.0-pyhd3eb1b0_1
#   pysocks            pkgs/main/linux-64::pysocks-1.7.1-py39h06a4308_0
#   python             pkgs/main/linux-64::python-3.9.7-h12debd9_1
#   readline           pkgs/main/linux-64::readline-8.1.2-h7f8727e_1
#   requests           pkgs/main/noarch::requests-2.27.1-pyhd3eb1b0_0
#   ruamel_yaml        pkgs/main/linux-64::ruamel_yaml-0.15.100-py39h27cfd23_0
#   setuptools         pkgs/main/linux-64::setuptools-58.0.4-py39h06a4308_0
#   six                pkgs/main/noarch::six-1.16.0-pyhd3eb1b0_0
#   sqlite             pkgs/main/linux-64::sqlite-3.37.0-hc218d9a_0
#   tk                 pkgs/main/linux-64::tk-8.6.11-h1ccaba5_0
#   tqdm               pkgs/main/noarch::tqdm-4.62.3-pyhd3eb1b0_1
#   tzdata             pkgs/main/noarch::tzdata-2021e-hda174b7_0
#   urllib3            pkgs/main/noarch::urllib3-1.26.7-pyhd3eb1b0_0
#   wheel              pkgs/main/noarch::wheel-0.37.1-pyhd3eb1b0_0
#   xz                 pkgs/main/linux-64::xz-5.2.5-h7b6447c_0
#   yaml               pkgs/main/linux-64::yaml-0.2.5-h7b6447c_0
#   zlib               pkgs/main/linux-64::zlib-1.2.11-h7f8727e_4
#
#
# done
# done
# installation finished.
# WARNING:
#     You currently have a PYTHONPATH environment variable set. This may cause
#     unexpected behavior when running the Python interpreter in Miniconda3.
#     For best results, please verify that your PYTHONPATH only points to
#     directories of packages that are compatible with the Python interpreter
#     in Miniconda3: /usr/local
# done
# done
#
# ## Package Plan ##
#
#   environment location: /usr/local
#
#   added / updated specs:
#     - psi4
#     - python=3.7
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     ambit-0.5.1                |       hbe8a562_1         488 KB  psi4
#     attrs-21.4.0               |     pyhd3eb1b0_0          51 KB
#     blas-1.0                   |              mkl           6 KB
#     brotlipy-0.7.0             |py37h27cfd23_1003         320 KB
#     ca-certificates-2022.3.29  |       h06a4308_0         117 KB
#     certifi-2021.10.8          |   py37h06a4308_2         151 KB
#     cffi-1.15.0                |   py37hd667e15_1         222 KB
#     chemps2-1.8.10             |       hbe8a562_0         2.4 MB  psi4
#     conda-4.12.0               |   py37h06a4308_0        14.5 MB
#     conda-package-handling-1.8.1|   py37h7f8727e_0         889 KB
#     cryptography-36.0.0        |   py37h9ce1e76_0         1.3 MB
#     decorator-5.1.1            |     pyhd3eb1b0_0          12 KB
#     dftd3-3.2.1                |       h84218bc_2         2.0 MB  psi4
#     dkh-1.2                    |       h173d85e_2         407 KB  psi4
#     gau2grid-2.0.7             |       hd18ef5c_0         1.2 MB  psi4
#     gcp-2.0.2                  |       he991be0_2         605 KB  psi4
#     gdma-2.2.6                 |       h0e1e685_6         762 KB  psi4
#     hdf5-1.10.6                |       hb1b8bf9_0         3.7 MB
#     importlib-metadata-4.11.3  |   py37h06a4308_0          40 KB
#     importlib_metadata-4.11.3  |       hd3eb1b0_0          12 KB
#     importlib_resources-5.2.0  |     pyhd3eb1b0_1          21 KB
#     iniconfig-1.1.1            |     pyhd3eb1b0_0           8 KB
#     intel-openmp-2021.4.0      |    h06a4308_3561         4.2 MB
#     libgfortran-ng-7.5.0       |      ha8ba4b0_17          22 KB
#     libgfortran4-7.5.0         |      ha8ba4b0_17         995 KB
#     libint2-2.6.0              |       hc9558a2_9       361.9 MB  psi4
#     libxc-5.1.5                |       h84b9e52_1         7.1 MB  psi4
#     mkl-2021.4.0               |     h06a4308_640       142.6 MB
#     mkl-service-2.4.0          |   py37h7f8727e_0          56 KB
#     mkl_fft-1.3.1              |   py37hd3c417c_0         172 KB
#     mkl_random-1.2.2           |   py37h51133e4_0         287 KB
#     networkx-2.2               |           py37_1         1.6 MB
#     numpy-1.21.5               |   py37he7a7128_1          24 KB
#     numpy-base-1.21.5          |   py37hf524024_1         4.8 MB
#     openssl-1.1.1n             |       h7f8727e_0         2.5 MB
#     packaging-21.3             |     pyhd3eb1b0_0          36 KB
#     pcmsolver-1.2.1.1          |   py37h6d17ec8_2         2.3 MB  psi4
#     pint-0.17                  |     pyhd8ed1ab_0         168 KB  psi4
#     pip-21.2.2                 |   py37h06a4308_0         1.8 MB
#     pluggy-1.0.0               |   py37h06a4308_1          29 KB
#     psi4-1.5+e9f4d6d           |   py37hbf93d9d_0        37.7 MB  psi4
#     psutil-5.8.0               |   py37h27cfd23_1         329 KB
#     py-1.11.0                  |     pyhd3eb1b0_0          76 KB
#     py-cpuinfo-8.0.0           |     pyhd3eb1b0_1          23 KB
#     pycosat-0.6.3              |   py37h27cfd23_0          81 KB
#     pydantic-1.9.0             |   py37h7f8727e_0         1.8 MB
#     pyparsing-3.0.4            |     pyhd3eb1b0_0          81 KB
#     pysocks-1.7.1              |           py37_1          27 KB
#     pytest-7.1.1               |   py37h06a4308_0         454 KB
#     python-3.7.11              |       h12debd9_0        45.3 MB
#     pyyaml-6.0                 |   py37h7f8727e_1         168 KB
#     qcelemental-0.24.0         |     pyhd8ed1ab_0         240 KB  psi4
#     qcengine-0.23.0            |     pyhd8ed1ab_0         195 KB  psi4
#     ruamel_yaml-0.15.100       |   py37h27cfd23_0         253 KB
#     setuptools-61.2.0          |   py37h06a4308_0        1007 KB
#     simint-0.7                 |       h642920c_1         9.6 MB  psi4
#     tomli-1.2.2                |     pyhd3eb1b0_0          17 KB
#     typing-extensions-4.1.1    |       hd3eb1b0_0           8 KB
#     typing_extensions-4.1.1    |     pyh06a4308_0          28 KB
#     zipp-3.7.0                 |     pyhd3eb1b0_0          12 KB
#     ------------------------------------------------------------
#                                            Total:       657.0 MB
#
# The following NEW packages will be INSTALLED:
#
#   ambit              psi4/linux-64::ambit-0.5.1-hbe8a562_1
#   attrs              pkgs/main/noarch::attrs-21.4.0-pyhd3eb1b0_0
#   blas               pkgs/main/linux-64::blas-1.0-mkl
#   chemps2            psi4/linux-64::chemps2-1.8.10-hbe8a562_0
#   decorator          pkgs/main/noarch::decorator-5.1.1-pyhd3eb1b0_0
#   dftd3              psi4/linux-64::dftd3-3.2.1-h84218bc_2
#   dkh                psi4/linux-64::dkh-1.2-h173d85e_2
#   gau2grid           psi4/linux-64::gau2grid-2.0.7-hd18ef5c_0
#   gcp                psi4/linux-64::gcp-2.0.2-he991be0_2
#   gdma               psi4/linux-64::gdma-2.2.6-h0e1e685_6
#   hdf5               pkgs/main/linux-64::hdf5-1.10.6-hb1b8bf9_0
#   importlib-metadata pkgs/main/linux-64::importlib-metadata-4.11.3-py37h06a4308_0
#   importlib_metadata pkgs/main/noarch::importlib_metadata-4.11.3-hd3eb1b0_0
#   importlib_resourc~ pkgs/main/noarch::importlib_resources-5.2.0-pyhd3eb1b0_1
#   iniconfig          pkgs/main/noarch::iniconfig-1.1.1-pyhd3eb1b0_0
#   intel-openmp       pkgs/main/linux-64::intel-openmp-2021.4.0-h06a4308_3561
#   libgfortran-ng     pkgs/main/linux-64::libgfortran-ng-7.5.0-ha8ba4b0_17
#   libgfortran4       pkgs/main/linux-64::libgfortran4-7.5.0-ha8ba4b0_17
#   libint2            psi4/linux-64::libint2-2.6.0-hc9558a2_9
#   libxc              psi4/linux-64::libxc-5.1.5-h84b9e52_1
#   mkl                pkgs/main/linux-64::mkl-2021.4.0-h06a4308_640
#   mkl-service        pkgs/main/linux-64::mkl-service-2.4.0-py37h7f8727e_0
#   mkl_fft            pkgs/main/linux-64::mkl_fft-1.3.1-py37hd3c417c_0
#   mkl_random         pkgs/main/linux-64::mkl_random-1.2.2-py37h51133e4_0
#   networkx           pkgs/main/linux-64::networkx-2.2-py37_1
#   numpy              pkgs/main/linux-64::numpy-1.21.5-py37he7a7128_1
#   numpy-base         pkgs/main/linux-64::numpy-base-1.21.5-py37hf524024_1
#   packaging          pkgs/main/noarch::packaging-21.3-pyhd3eb1b0_0
#   pcmsolver          psi4/linux-64::pcmsolver-1.2.1.1-py37h6d17ec8_2
#   pint               psi4/noarch::pint-0.17-pyhd8ed1ab_0
#   pluggy             pkgs/main/linux-64::pluggy-1.0.0-py37h06a4308_1
#   psi4               psi4/linux-64::psi4-1.5+e9f4d6d-py37hbf93d9d_0
#   psutil             pkgs/main/linux-64::psutil-5.8.0-py37h27cfd23_1
#   py                 pkgs/main/noarch::py-1.11.0-pyhd3eb1b0_0
#   py-cpuinfo         pkgs/main/noarch::py-cpuinfo-8.0.0-pyhd3eb1b0_1
#   pydantic           pkgs/main/linux-64::pydantic-1.9.0-py37h7f8727e_0
#   pyparsing          pkgs/main/noarch::pyparsing-3.0.4-pyhd3eb1b0_0
#   pytest             pkgs/main/linux-64::pytest-7.1.1-py37h06a4308_0
#   pyyaml             pkgs/main/linux-64::pyyaml-6.0-py37h7f8727e_1
#   qcelemental        psi4/noarch::qcelemental-0.24.0-pyhd8ed1ab_0
#   qcengine           psi4/noarch::qcengine-0.23.0-pyhd8ed1ab_0
#   simint             psi4/linux-64::simint-0.7-h642920c_1
#   tomli              pkgs/main/noarch::tomli-1.2.2-pyhd3eb1b0_0
#   typing-extensions  pkgs/main/noarch::typing-extensions-4.1.1-hd3eb1b0_0
#   typing_extensions  pkgs/main/noarch::typing_extensions-4.1.1-pyh06a4308_0
#   zipp               pkgs/main/noarch::zipp-3.7.0-pyhd3eb1b0_0
#
# The following packages will be UPDATED:
#
#   ca-certificates                     2021.10.26-h06a4308_2 --> 2022.3.29-h06a4308_0
#   conda                               4.11.0-py39h06a4308_0 --> 4.12.0-py37h06a4308_0
#   conda-package-han~                   1.7.3-py39h27cfd23_1 --> 1.8.1-py37h7f8727e_0
#   openssl                                 1.1.1m-h7f8727e_0 --> 1.1.1n-h7f8727e_0
#   pysocks                              1.7.1-py39h06a4308_0 --> 1.7.1-py37_1
#   setuptools                          58.0.4-py39h06a4308_0 --> 61.2.0-py37h06a4308_0
#
# The following packages will be DOWNGRADED:
#
#   brotlipy                          0.7.0-py39h27cfd23_1003 --> 0.7.0-py37h27cfd23_1003
#   certifi                          2021.10.8-py39h06a4308_2 --> 2021.10.8-py37h06a4308_2
#   cffi                                1.15.0-py39hd667e15_1 --> 1.15.0-py37hd667e15_1
#   cryptography                        36.0.0-py39h9ce1e76_0 --> 36.0.0-py37h9ce1e76_0
#   pip                                 21.2.4-py39h06a4308_0 --> 21.2.2-py37h06a4308_0
#   pycosat                              0.6.3-py39h27cfd23_0 --> 0.6.3-py37h27cfd23_0
#   python                                   3.9.7-h12debd9_1 --> 3.7.11-h12debd9_0
#   ruamel_yaml                       0.15.100-py39h27cfd23_0 --> 0.15.100-py37h27cfd23_0
#
#
#
# Downloading and Extracting Packages
# py-cpuinfo-8.0.0     | 23 KB     | : 100% 1.0/1 [00:00<00:00,  9.02it/s]
# pyparsing-3.0.4      | 81 KB     | : 100% 1.0/1 [00:00<00:00, 11.96it/s]
# pip-21.2.2           | 1.8 MB    | : 100% 1.0/1 [00:00<00:00,  4.07it/s]
# dkh-1.2              | 407 KB    | : 100% 1.0/1 [00:00<00:00,  3.90it/s]
# packaging-21.3       | 36 KB     | : 100% 1.0/1 [00:00<00:00, 17.56it/s]
# libint2-2.6.0        | 361.9 MB  | : 100% 1.0/1 [01:55<00:00, 115.07s/it]
# blas-1.0             | 6 KB      | : 100% 1.0/1 [00:00<00:00, 16.57it/s]
# libxc-5.1.5          | 7.1 MB    | : 100% 1.0/1 [00:01<00:00,  1.95s/it]
# hdf5-1.10.6          | 3.7 MB    | : 100% 1.0/1 [00:00<00:00,  5.51it/s]
# zipp-3.7.0           | 12 KB     | : 100% 1.0/1 [00:00<00:00, 15.69it/s]
# brotlipy-0.7.0       | 320 KB    | : 100% 1.0/1 [00:00<00:00, 16.55it/s]
# typing-extensions-4. | 8 KB      | : 100% 1.0/1 [00:00<00:00, 18.88it/s]
# pint-0.17            | 168 KB    | : 100% 1.0/1 [00:00<00:00,  5.17it/s]
# mkl-service-2.4.0    | 56 KB     | : 100% 1.0/1 [00:00<00:00, 16.88it/s]
# mkl_random-1.2.2     | 287 KB    | : 100% 1.0/1 [00:00<00:00,  7.87it/s]
# chemps2-1.8.10       | 2.4 MB    | : 100% 1.0/1 [00:00<00:00,  1.45it/s]
# setuptools-61.2.0    | 1007 KB   | : 100% 1.0/1 [00:00<00:00,  7.69it/s]
# dftd3-3.2.1          | 2.0 MB    | : 100% 1.0/1 [00:00<00:00,  1.95it/s]
# psutil-5.8.0         | 329 KB    | : 100% 1.0/1 [00:00<00:00, 14.64it/s]
# conda-4.12.0         | 14.5 MB   | : 100% 1.0/1 [00:00<00:00,  1.11it/s]
# gau2grid-2.0.7       | 1.2 MB    | : 100% 1.0/1 [00:00<00:00,  2.30it/s]
# numpy-base-1.21.5    | 4.8 MB    | : 100% 1.0/1 [00:00<00:00,  2.87it/s]
# numpy-1.21.5         | 24 KB     | : 100% 1.0/1 [00:00<00:00, 18.24it/s]
# qcengine-0.23.0      | 195 KB    | : 100% 1.0/1 [00:00<00:00,  4.55it/s]
# pyyaml-6.0           | 168 KB    | : 100% 1.0/1 [00:00<00:00, 14.82it/s]
# libgfortran-ng-7.5.0 | 22 KB     | : 100% 1.0/1 [00:00<00:00, 17.43it/s]
# certifi-2021.10.8    | 151 KB    | : 100% 1.0/1 [00:00<00:00, 15.82it/s]
# ruamel_yaml-0.15.100 | 253 KB    | : 100% 1.0/1 [00:00<00:00, 13.05it/s]
# pycosat-0.6.3        | 81 KB     | : 100% 1.0/1 [00:00<00:00, 15.68it/s]
# simint-0.7           | 9.6 MB    | : 100% 1.0/1 [00:03<00:00,  3.31s/it]
# pcmsolver-1.2.1.1    | 2.3 MB    | : 100% 1.0/1 [00:00<00:00,  1.36it/s]
# importlib_resources- | 21 KB     | : 100% 1.0/1 [00:00<00:00, 13.96it/s]
# gcp-2.0.2            | 605 KB    | : 100% 1.0/1 [00:00<00:00,  3.85it/s]
# decorator-5.1.1      | 12 KB     | : 100% 1.0/1 [00:00<00:00, 13.39it/s]
# pluggy-1.0.0         | 29 KB     | : 100% 1.0/1 [00:00<00:00, 15.99it/s]
# mkl-2021.4.0         | 142.6 MB  | : 100% 1.0/1 [00:06<00:00,  6.30s/it]
# attrs-21.4.0         | 51 KB     | : 100% 1.0/1 [00:00<00:00, 14.64it/s]
# ambit-0.5.1          | 488 KB    | : 100% 1.0/1 [00:00<00:00,  5.43it/s]
# python-3.7.11        | 45.3 MB   | : 100% 1.0/1 [00:02<00:00,  2.10s/it]
# cffi-1.15.0          | 222 KB    | : 100% 1.0/1 [00:00<00:00, 12.38it/s]
# cryptography-36.0.0  | 1.3 MB    | : 100% 1.0/1 [00:00<00:00,  7.31it/s]
# py-1.11.0            | 76 KB     | : 100% 1.0/1 [00:00<00:00, 13.65it/s]
# importlib_metadata-4 | 12 KB     | : 100% 1.0/1 [00:00<00:00, 15.79it/s]
# pysocks-1.7.1        | 27 KB     | : 100% 1.0/1 [00:00<00:00, 15.15it/s]
# mkl_fft-1.3.1        | 172 KB    | : 100% 1.0/1 [00:00<00:00, 15.28it/s]
# pytest-7.1.1         | 454 KB    | : 100% 1.0/1 [00:00<00:00, 11.42it/s]
# tomli-1.2.2          | 17 KB     | : 100% 1.0/1 [00:00<00:00, 14.16it/s]
# iniconfig-1.1.1      | 8 KB      | : 100% 1.0/1 [00:00<00:00, 28.05it/s]
# importlib-metadata-4 | 40 KB     | : 100% 1.0/1 [00:00<00:00, 16.54it/s]
# qcelemental-0.24.0   | 240 KB    | : 100% 1.0/1 [00:00<00:00,  4.89it/s]
# libgfortran4-7.5.0   | 995 KB    | : 100% 1.0/1 [00:00<00:00, 10.82it/s]
# intel-openmp-2021.4. | 4.2 MB    | : 100% 1.0/1 [00:00<00:00,  4.62it/s]
# psi4-1.5+e9f4d6d     | 37.7 MB   | : 100% 1.0/1 [00:13<00:00, 13.59s/it]
# ca-certificates-2022 | 117 KB    | : 100% 1.0/1 [00:00<00:00, 14.25it/s]
# conda-package-handli | 889 KB    | : 100% 1.0/1 [00:00<00:00, 11.87it/s]
# networkx-2.2         | 1.6 MB    | : 100% 1.0/1 [00:00<00:00,  4.30it/s]
# openssl-1.1.1n       | 2.5 MB    | : 100% 1.0/1 [00:00<00:00,  6.19it/s]
# gdma-2.2.6           | 762 KB    | : 100% 1.0/1 [00:00<00:00,  2.77it/s]
# pydantic-1.9.0       | 1.8 MB    | : 100% 1.0/1 [00:00<00:00,  7.12it/s]
# typing_extensions-4. | 28 KB     | : 100% 1.0/1 [00:00<00:00, 14.84it/s]
# done
# done
# done

# %%
# import Psi4
import psi4
# check Psi4 version
print(psi4.__version__)
# Out:
# 1.5

# %%
psi4.core.set_output_file("log.txt")
psi4.set_memory('10GB')
psi4.set_num_threads(2)

mol = psi4.geometry("""
0 1
O 7.7765230000 12.0953080000 13.0921980000
H 8.6307260000 12.5925870000 13.0732400000
C 7.9908960000 10.8402260000 13.7515010000
H 8.6188110000 10.1924980000 13.1352470000
H 7.0213810000 10.3634990000 13.8834140000
H 8.4594020000 10.9682940000 14.7292650000               
""")

#scf_e, wfn = psi4.optimize("B97-D/6-31G(d)", return_wfn = True)
#scf_e, wfn = psi4.optimize("wB97X-D/6-31G(d)", return_wfn = True)
#scf_e, wfn = psi4.optimize("B3LYP-D/6-311G(d)", return_wfn = True)
#scf_e, wfn = psi4.optimize("B3LYP-D2/6-311G(d)", return_wfn = True)
#scf_e, wfn = psi4.optimize("M06/6-31G(d)", return_wfn = True) # metal
scf_e, wfn = psi4.optimize("M06-2X/6-31G(d)", return_wfn = True) # non-metal
# Out:
# Optimizer: Optimization complete!

# %%
#scf_e, wfn = psi4.energy("CCSD/6-31G(d)", return_wfn = True)
scf_e, wfn = psi4.energy("CCSD(T)/cc-pVTZ", return_wfn = True)
# !cat log.txt
# Out:
#   Memory set to   9.313 GiB by Python driver.
#   Threads set to 2 by Python driver.
#
# Scratch directory: /tmp/
#
# Scratch directory: /tmp/
# gradient() will perform analytic gradient computation.
#
# *** tstart() called on 62de2050016d
# *** at Tue Apr 19 09:46:31 2022
#
#    => Loading Basis Set <=
#
#     Name: 6-31G(D)
#     Role: ORBITAL
#     Keyword: BASIS
#     atoms 1      entry O          line   145 file /usr/local/share/psi4/basis/6-31g_d_.gbs
#     atoms 2, 4-6 entry H          line    44 file /usr/local/share/psi4/basis/6-31g_d_.gbs
#     atoms 3      entry C          line   111 file /usr/local/share/psi4/basis/6-31g_d_.gbs
#
#
#          ---------------------------------------------------------
#                                    SCF
#                by Justin Turney, Rob Parrish, Andy Simmonett
#                           and Daniel G. A. Smith
#                               RKS Reference
#                         2 Threads,   9536 MiB Core
#          ---------------------------------------------------------
#
#   ==> Geometry <==
#
#     Molecular point group: c1
#     Full point group: C1
#
#     Geometry (in Angstrom), charge = 0, multiplicity = 1:
#
#        Center              X                  Y                   Z               Mass
#     ------------   -----------------  -----------------  -----------------  -----------------
#          O           -0.131436501925     0.604464400789    -0.324209401178    15.994914619570
#          H            0.722766498075     1.101743400789    -0.343167401178     1.007825032230
#          C            0.082936498075    -0.650617599211     0.335093598822    12.000000000000
#          H            0.710851498075    -1.298345599211    -0.281160401178     1.007825032230
#          H           -0.886578501925    -1.127344599211     0.467006598822     1.007825032230
#          H            0.551442498075    -0.522549599211     1.312857598822     1.007825032230
#
#   Running in c1 symmetry.
#
#   Rotational constants: A =      4.23474  B =      0.81462  C =      0.78466 [cm^-1]
#   Rotational constants: A = 126954.40788  B =  24421.68278  C =  23523.60793 [MHz]
#   Nuclear repulsion =   39.970425782429736
#
#   Charge       = 0
#   Multiplicity = 1
#   Electrons    = 18
#   Nalpha       = 9
#   Nbeta        = 9
#
#   ==> Algorithm <==
#
#   SCF Algorithm Type is DF.
#   DIIS enabled.
#   MOM disabled.
#   Fractional occupation disabled.
#   Guess Type is SAD.
#   Energy threshold   = 1.00e-08
#   Density threshold  = 1.00e-08
#   Integral threshold = 1.00e-12
#
#   ==> Primary Basis <==
#
#   Basis Set: 6-31G(D)
#     Blend: 6-31G(D)
#     Number of shells: 20
#     Number of basis functions: 38
#     Number of Cartesian functions: 38
#     Spherical Harmonics?: false
#     Max angular momentum: 2
#
#   ==> DFT Potential <==
#
#    => Composite Functional: M06-2X <=
#
#     Hybrid M06-2X Meta-GGA XC Functional
# (10.1007/s00214-007-0310-x)
#     Y. Zhao and D. G. Truhlar,  Theor. Chem. Acc., 120, 215, 2008
#
#
#     Deriv               =              1
#     GGA                 =           TRUE
#     Meta                =           TRUE
#
#     Exchange Hybrid     =           TRUE
#     MP2 Hybrid          =          FALSE
#
#    => Exchange Functionals <=
#
#     1.0000   XC_HYB_MGGA_X_M06_2X
#
#    => Exact (HF) Exchange <=
#
#     0.5400               HF
#
#    => Correlation Functionals <=
#
#     1.0000   XC_MGGA_C_M06_2X
#
#    => LibXC Density Thresholds  <==
#
#     XC_MGGA_C_M06_2X:  1.00E-12
#     XC_HYB_MGGA_X_M06_2X:  1.00E-15
#
#    => Molecular Quadrature <=
#
#     Radial Scheme          =       TREUTLER
#     Pruning Scheme         =           NONE
#     Nuclear Scheme         =       TREUTLER
#
#     BS radius alpha        =              1
#     Pruning alpha          =              1
#     Radial Points          =             75
#     Spherical Points       =            302
#     Total Points           =         130210
#     Total Blocks           =           1035
#     Max Points             =            256
#     Max Functions          =             38
#     Weights Tolerance      =       1.00E-15
#
#    => Loading Basis Set <=
#
#     Name: (6-31G(D) AUX)
#     Role: JKFIT
#     Keyword: DF_BASIS_SCF
#     atoms 1      entry O          line   221 file /usr/local/share/psi4/basis/cc-pvdz-jkfit.gbs
#     atoms 2, 4-6 entry H          line    51 file /usr/local/share/psi4/basis/cc-pvdz-jkfit.gbs
#     atoms 3      entry C          line   121 file /usr/local/share/psi4/basis/cc-pvdz-jkfit.gbs
#
#   ==> Integral Setup <==
#
#   DFHelper Memory: AOs need 0.004 GiB; user supplied 6.639 GiB. Using in-core AOs.
#
#   ==> MemDFJK: Density-Fitted J/K Matrices <==
#
#     J tasked:                   Yes
#     K tasked:                   Yes
#     wK tasked:                   No
#     OpenMP threads:               2
#     Memory [MiB]:              6798
#     Algorithm:                 Core
#     Schwarz Cutoff:           1E-12
#     Mask sparsity (%):       0.0000
#     Fitting Condition:        1E-10
#
#    => Auxiliary Basis Set <=
#
#   Basis Set: (6-31G(D) AUX)
#     Blend: CC-PVDZ-JKFIT
#     Number of shells: 84
#     Number of basis functions: 262
#     Number of Cartesian functions: 262
#     Spherical Harmonics?: false
#     Max angular momentum: 3
#
#   Cached 100.0% of DFT collocation blocks in 0.346 [GiB].
#
#   Minimum eigenvalue in the overlap matrix is 9.8957955874E-03.
#   Reciprocal condition number of the overlap matrix is 1.6584885063E-03.
#     Using symmetric orthogonalization.
#
#   ==> Pre-Iterations <==
#
#   SCF Guess: Superposition of Atomic Densities via on-the-fly atomic UHF (no occupation information).
#
#    -------------------------
#     Irrep   Nso     Nmo
#    -------------------------
#      A         38      38
#    -------------------------
#     Total      38      38
#    -------------------------
#
#   ==> Iterations <==
#
#                            Total Energy        Delta E     RMS |[F,P]|
#
#    @DF-RKS iter SAD:  -115.13690601825985   -1.15137e+02   0.00000e+00
#    @DF-RKS iter   1:  -115.55258547564131   -4.15679e-01   1.24802e-02 DIIS
#    @DF-RKS iter   2:  -115.57150041171371   -1.89149e-02   1.22284e-02 DIIS
#    @DF-RKS iter   3:  -115.65278219224334   -8.12818e-02   1.18165e-03 DIIS
#    @DF-RKS iter   4:  -115.65351180572620   -7.29613e-04   4.20069e-04 DIIS
#    @DF-RKS iter   5:  -115.65362094616144   -1.09140e-04   6.89826e-05 DIIS
#    @DF-RKS iter   6:  -115.65362452627255   -3.58011e-06   6.18506e-06 DIIS
#    @DF-RKS iter   7:  -115.65362457105765   -4.47851e-08   9.69931e-07 DIIS
#    @DF-RKS iter   8:  -115.65362457253914   -1.48150e-09   2.15744e-07 DIIS
#    @DF-RKS iter   9:  -115.65362457261962   -8.04761e-11   4.91831e-08 DIIS
#    @DF-RKS iter  10:  -115.65362457262313   -3.51008e-12   6.98116e-09 DIIS
#   Energy and wave function converged.
#
#
#   ==> Post-Iterations <==
#
#    Electrons on quadrature grid:
#       Ntotal   =   17.9999939225 ; deviation = -6.078e-06
#
#     Orbital Energies [Eh]
#     ---------------------
#
#     Doubly Occupied:
#
#        1A    -19.629168     2A    -10.582356     3A     -1.119042
#        4A     -0.769454     5A     -0.569556     6A     -0.507494
#        7A     -0.488327     8A     -0.398470     9A     -0.338650
#
#     Virtual:
#
#       10A      0.120036    11A      0.181704    12A      0.218612
#       13A      0.225101    14A      0.251018    15A      0.594941
#       16A      0.613426    17A      0.621936    18A      0.851141
#       19A      0.926649    20A      0.945080    21A      0.975071
#       22A      1.018905    23A      1.052187    24A      1.080373
#       25A      1.189966    26A      1.507126    27A      1.555740
#       28A      1.644781    29A      1.813588    30A      2.100068
#       31A      2.160766    32A      2.213744    33A      2.397623
#       34A      2.429122    35A      2.487659    36A      2.826699
#       37A      3.722027    38A      4.260625
#
#     Final Occupation by Irrep:
#               A
#     DOCC [     9 ]
#
#   @DF-RKS Final Energy:  -115.65362457262313
#
#    => Energetics <=
#
#     Nuclear Repulsion Energy =             39.9704257824297358
#     One-Electron Energy =                -236.3086297776591778
#     Two-Electron Energy =                  88.1224835709805348
#     DFT Exchange-Correlation Energy =      -7.4379041483742352
#     Empirical Dispersion Energy =           0.0000000000000000
#     VV10 Nonlocal Energy =                  0.0000000000000000
#     Total Energy =                       -115.6536245726231300
#
# Computation Completed
#
#
# Properties will be evaluated at   0.000000,   0.000000,   0.000000 [a0]
#
# Properties computed using the SCF density matrix
#
#   Nuclear Dipole Moment: [e a0]
#      X:     1.0292      Y:    -1.7281      Z:     1.0817
#
#   Electronic Dipole Moment: [e a0]
#      X:    -0.4015      Y:     1.5248      Z:    -0.8133
#
#   Dipole Moment: [e a0]
#      X:     0.6277      Y:    -0.2033      Z:     0.2684     Total:     0.7123
#
#   Dipole Moment: [D]
#      X:     1.5955      Y:    -0.5167      Z:     0.6823     Total:     1.8105
#
#
# *** tstop() called on 62de2050016d at Tue Apr 19 09:46:37 2022
# Module time:
# 	user time   =      10.16 seconds =       0.17 minutes
# 	system time =       0.55 seconds =       0.01 minutes
# 	total time  =          6 seconds =       0.10 minutes
# Total time:
# 	user time   =      10.16 seconds =       0.17 minutes
# 	system time =       0.55 seconds =       0.01 minutes
# 	total time  =          6 seconds =       0.10 minutes
#
# *** tstart() called on 62de2050016d
# *** at Tue Apr 19 09:46:37 2022
#
#
#          ------------------------------------------------------------
#                                    SCF GRAD
#                           Rob Parrish, Justin Turney,
#                        Andy Simmonett, and Alex Sokolov
#          ------------------------------------------------------------
#
#   ==> Geometry <==
#
#     Molecular point group: c1
#     Full point group: C1
#
#     Geometry (in Angstrom), charge = 0, multiplicity = 1:
#
#        Center              X                  Y                   Z               Mass
#     ------------   -----------------  -----------------  -----------------  -----------------
#          O           -0.131436501925     0.604464400789    -0.324209401178    15.994914619570
#          H            0.722766498075     1.101743400789    -0.343167401178     1.007825032230
#          C            0.082936498075    -0.650617599211     0.335093598822    12.000000000000
#          H            0.710851498075    -1.298345599211    -0.281160401178     1.007825032230
#          H           -0.886578501925    -1.127344599211     0.467006598822     1.007825032230
#          H            0.551442498075    -0.522549599211     1.312857598822     1.007825032230
#
#   Nuclear repulsion =   39.970425782429736
#
#   ==> Basis Set <==
#
#   Basis Set: 6-31G(D)
#     Blend: 6-31G(D)
#     Number of shells: 20
#     Number of basis functions: 38
#     Number of Cartesian functions: 38
#     Spherical Harmonics?: false
#     Max angular momentum: 2
#
#   ==> DFJKGrad: Density-Fitted SCF Gradients <==
#
#     Gradient:                    1
#     J tasked:                  Yes
#     K tasked:                  Yes
#     wK tasked:                  No
#     OpenMP threads:              2
#     Integrals threads:           2
#     Memory [MiB]:             7152
#     Schwarz Cutoff:          1E-12
#     Fitting Condition:       1E-10
#
#    => Auxiliary Basis Set <=
#
#   Basis Set: (6-31G(D) AUX)
#     Blend: CC-PVDZ-JKFIT
#     Number of shells: 84
#     Number of basis functions: 262
#     Number of Cartesian functions: 262
#     Spherical Harmonics?: false
#     Max angular momentum: 3
#
#   ==> DFT Potential <==
#
#    => Composite Functional: M06-2X <=
#
#     Hybrid M06-2X Meta-GGA XC Functional
# (10.1007/s00214-007-0310-x)
#     Y. Zhao and D. G. Truhlar,  Theor. Chem. Acc., 120, 215, 2008
#
#
#     Deriv               =              1
#     GGA                 =           TRUE
#     Meta                =           TRUE
#
#     Exchange Hybrid     =           TRUE
#     MP2 Hybrid          =          FALSE
#
#    => Exchange Functionals <=
#
#     1.0000   XC_HYB_MGGA_X_M06_2X
#
#    => Exact (HF) Exchange <=
#
#     0.5400               HF
#
#    => Correlation Functionals <=
#
#     1.0000   XC_MGGA_C_M06_2X
#
#    => LibXC Density Thresholds  <==
#
#     XC_MGGA_C_M06_2X:  1.00E-12
#     XC_HYB_MGGA_X_M06_2X:  1.00E-15
#
#    => Molecular Quadrature <=
#
#     Radial Scheme          =       TREUTLER
#     Pruning Scheme         =           NONE
#     Nuclear Scheme         =       TREUTLER
#
#     BS radius alpha        =              1
#     Pruning alpha          =              1
#     Radial Points          =             75
#     Spherical Points       =            302
#     Total Points           =         130210
#     Total Blocks           =           1035
#     Max Points             =            256
#     Max Functions          =             38
#     Weights Tolerance      =       1.00E-15
#
#
#   -Total Gradient:
#      Atom            X                  Y                   Z
#     ------   -----------------  -----------------  -----------------
#        1       -0.013768181705    -0.000976814774    -0.006410861574
#        2        0.017298326665     0.013305879621    -0.001258905792
#        3       -0.003503947679    -0.015236689859     0.010705421479
#        4       -0.001668122544     0.004182164785    -0.000384333739
#        5        0.002214560908    -0.001393066729     0.000595769429
#        6       -0.000537435112     0.000339858512    -0.003410752623
#
#
# *** tstop() called on 62de2050016d at Tue Apr 19 09:46:38 2022
# Module time:
# 	user time   =       1.65 seconds =       0.03 minutes
# 	system time =       0.03 seconds =       0.00 minutes
# 	total time  =          1 seconds =       0.02 minutes
# Total time:
# 	user time   =      11.81 seconds =       0.20 minutes
# 	system time =       0.58 seconds =       0.01 minutes
# 	total time  =          7 seconds =       0.12 minutes
#
# 			-----------------------------------------
# 			 OPTKING 2.0: for geometry optimizations
# 			  - R.A. King,  Bethel University
# 			-----------------------------------------
#
# 	Internal coordinates to be generated automatically.
# 	Detected frag 1 with atoms:  1 2 3 4 5 6
# 	---Fragment 1 Bond Connectivity---
# 	 1 : 2 3
# 	 2 : 1
# 	 3 : 1 4 5 6
# 	 4 : 3
# 	 5 : 3
# 	 6 : 3
#
# 	---Fragment 1 Geometry and Gradient---
# 	 O          -0.2483789915        1.1422721701       -0.6126669755
# 	 H           1.3658307340        2.0819932880       -0.6484924034
# 	 C           0.1567272672       -1.2294890749        0.6332351282
# 	 H           1.3433146472       -2.4535175987       -0.5313161555
# 	 H          -1.6753905574       -2.1303725415        0.8825145706
# 	 H           1.0420752953       -0.9874756295        2.4809413035
# 	            -0.0137681817       -0.0009768148       -0.0064108616
# 	             0.0172983267        0.0133058796       -0.0012589058
# 	            -0.0035039477       -0.0152366899        0.0107054215
# 	            -0.0016681225        0.0041821648       -0.0003843337
# 	             0.0022145609       -0.0013930667        0.0005957694
# 	            -0.0005374351        0.0003398585       -0.0034107526
#
# 	Previous optimization step data not found.  Starting new optimization.
#
# 	---Fragment 1 Intrafragment Coordinates---
# 	 - Coordinate -           - BOHR/RAD -       - ANG/DEG -
# 	 R(1,2)           =         1.868163	       0.988589
# 	 R(1,3)           =         2.709545	       1.433830
# 	 R(3,4)           =         2.064562	       1.092519
# 	 R(3,5)           =         2.056790	       1.088407
# 	 R(3,6)           =         2.063112	       1.091752
# 	 B(1,3,4)         =         1.923596	     110.213909
# 	 B(1,3,5)         =         1.881734	     107.815401
# 	 B(1,3,6)         =         1.953349	     111.918627
# 	 B(2,1,3)         =         1.896464	     108.659386
# 	 B(4,3,5)         =         1.897202	     108.701679
# 	 B(4,3,6)         =         1.905068	     109.152369
# 	 B(5,3,6)         =         1.901906	     108.971164
# 	 D(2,1,3,4)       =        -1.202915	     -68.921966
# 	 D(2,1,3,5)       =         3.011983	     172.573908
# 	 D(2,1,3,6)       =         0.920610	      52.747061
#
# 	Current energy   :      -115.6536245726
#
# 	Generating empirical Hessian (Schlegel '84) for each fragment.
# 	Taking RFO optimization step.
# 	Going to follow RFO solution 1.
# 	Using RFO vector 1.
# 	Norm of target step-size    0.24062
# 	Projected energy change by RFO approximation:         0.0011061252
#
# 	Back-transformation to cartesian coordinates...
# 	Successfully converged to displaced geometry.
#
# 	--- Internal Coordinate Step in ANG or DEG, aJ/ANG or AJ/DEG ---
# 	 ---------------------------------------------------------------------------
# 	   Coordinate                Previous        Force       Change         New
# 	   ----------                --------       ------       ------       ------
# 	    1 R(1,2)          =      0.988589    -0.178091    -0.022888     0.965701
# 	    2 R(1,3)          =      1.433830    -0.113012    -0.017848     1.415981
# 	    3 R(3,4)          =      1.092519     0.026510     0.004900     1.097419
# 	    4 R(3,5)          =      1.088407     0.010474     0.001910     1.090317
# 	    5 R(3,6)          =      1.091752     0.026528     0.004891     1.096643
# 	    6 B(1,3,4)        =    110.213909     0.000434     2.264139   112.478048
# 	    7 B(1,3,5)        =    107.815401    -0.000393    -2.055006   105.760395
# 	    8 B(1,3,6)        =    111.918627     0.000069     0.203621   112.122249
# 	    9 B(2,1,3)        =    108.659386    -0.000405    -2.155756   106.503630
# 	   10 B(4,3,5)        =    108.701679    -0.000018    -0.087221   108.614458
# 	   11 B(4,3,6)        =    109.152369    -0.000084     0.066083   109.218452
# 	   12 B(5,3,6)        =    108.971164    -0.000017    -0.501199   108.469965
# 	   13 D(2,1,3,4)      =    -68.921966    -0.000013     6.732796   -62.189170
# 	   14 D(2,1,3,5)      =    172.573908    -0.000011     6.831218   179.405126
# 	   15 D(2,1,3,6)      =     52.747061     0.000043     8.619251    61.366312
# 	 ---------------------------------------------------------------------------
# 	Successfully symmetrized geometry.
#
#   ==> Convergence Check <==
#
#   Measures of convergence in internal coordinates in au.
#   Criteria marked as inactive (o), active & met (*), and active & unmet ( ).
#   --------------------------------------------------------------------------------------------- ~
#    Step     Total Energy     Delta E     MAX Force     RMS Force      MAX Disp      RMS Disp    ~
#   --------------------------------------------------------------------------------------------- ~
#     Convergence Criteria    1.00e-06 *    3.00e-04 *             o    1.20e-03 *             o  ~
#   --------------------------------------------------------------------------------------------- ~
#       1    -115.65362457   -1.16e+02      2.16e-02      7.19e-03 o    1.50e-01      6.23e-02 o  ~
#   ---------------------------------------------------------------------------------------------
#
# 	Writing optimization data to binary file.
# 	Structure for next step:
# 	Cartesian Geometry (in Angstrom)
# 	    O    -0.1459798821   0.6090379334  -0.2975106069
# 	    H     0.7104917421   1.0486307120  -0.3736256330
# 	    C     0.0952729938  -0.6354028660   0.3334944227
# 	    H     0.7532264121  -1.2850035284  -0.2576442552
# 	    H    -0.8793296774  -1.1159676420   0.4229216555
# 	    H     0.5163003959  -0.5139441968   1.3387850052
# 			--------------------------
# 			 OPTKING Finished Execution
# 			--------------------------
#
#     Structure for next step:
#     Molecular point group: c1
#     Full point group: C1
#
#     Geometry (in Angstrom), charge = 0, multiplicity = 1:
#
#     O           -0.143408300977     0.601675624552    -0.309455784813
#     H            0.713063326546     1.041268404815    -0.385570811196
#     C            0.097844575790    -0.642765179730     0.321549247322
#     H            0.755797996726    -1.292365844707    -0.269589432951
#     H           -0.876758099237    -1.123329957675     0.410976480469
#     H            0.518871979568    -0.521306510131     1.326839833785
#
#
# Scratch directory: /tmp/
#
# Scratch directory: /tmp/
# gradient() will perform analytic gradient computation.
#
# *** tstart() called on 62de2050016d
# *** at Tue Apr 19 09:46:38 2022
#
#    => Loading Basis Set <=
#
#     Name: 6-31G(D)
#     Role: ORBITAL
#     Keyword: BASIS
#     atoms 1      entry O          line   145 file /usr/local/share/psi4/basis/6-31g_d_.gbs
#     atoms 2, 4-6 entry H          line    44 file /usr/local/share/psi4/basis/6-31g_d_.gbs
#     atoms 3      entry C          line   111 file /usr/local/share/psi4/basis/6-31g_d_.gbs
#
#
#          ---------------------------------------------------------
#                                    SCF
#                by Justin Turney, Rob Parrish, Andy Simmonett
#                           and Daniel G. A. Smith
#                               RKS Reference
#                         2 Threads,   9536 MiB Core
#          ---------------------------------------------------------
#
#   ==> Geometry <==
#
#     Molecular point group: c1
#     Full point group: C1
#
#     Geometry (in Angstrom), charge = 0, multiplicity = 1:
#
#        Center              X                  Y                   Z               Mass
#     ------------   -----------------  -----------------  -----------------  -----------------
#          O           -0.143408300977     0.601675624552    -0.309455784813    15.994914619570
#          H            0.713063326546     1.041268404815    -0.385570811196     1.007825032230
#          C            0.097844575790    -0.642765179730     0.321549247322    12.000000000000
#          H            0.755797996726    -1.292365844707    -0.269589432951     1.007825032230
#          H           -0.876758099237    -1.123329957675     0.410976480469     1.007825032230
#          H            0.518871979568    -0.521306510131     1.326839833785     1.007825032230
#
#   Running in c1 symmetry.
#
#   Rotational constants: A =      4.23500  B =      0.83373  C =      0.80368 [cm^-1]
#   Rotational constants: A = 126962.10032  B =  24994.71986  C =  24093.57890 [MHz]
#   Nuclear repulsion =   40.355260328288558
#
#   Charge       = 0
#   Multiplicity = 1
#   Electrons    = 18
#   Nalpha       = 9
#   Nbeta        = 9
#
#   ==> Algorithm <==
#
#   SCF Algorithm Type is DF.
#   DIIS enabled.
#   MOM disabled.
#   Fractional occupation disabled.
#   Guess Type is READ.
#   Energy threshold   = 1.00e-08
#   Density threshold  = 1.00e-08
#   Integral threshold = 1.00e-12
#
#   ==> Primary Basis <==
#
#   Basis Set: 6-31G(D)
#     Blend: 6-31G(D)
#     Number of shells: 20
#     Number of basis functions: 38
#     Number of Cartesian functions: 38
#     Spherical Harmonics?: false
#     Max angular momentum: 2
#
#   ==> DFT Potential <==
#
#    => Composite Functional: M06-2X <=
#
#     Hybrid M06-2X Meta-GGA XC Functional
# (10.1007/s00214-007-0310-x)
#     Y. Zhao and D. G. Truhlar,  Theor. Chem. Acc., 120, 215, 2008
#
#
#     Deriv               =              1
#     GGA                 =           TRUE
#     Meta                =           TRUE
#
#     Exchange Hybrid     =           TRUE
#     MP2 Hybrid          =          FALSE
#
#    => Exchange Functionals <=
#
#     1.0000   XC_HYB_MGGA_X_M06_2X
#
#    => Exact (HF) Exchange <=
#
#     0.5400               HF
#
#    => Correlation Functionals <=
#
#     1.0000   XC_MGGA_C_M06_2X
#
#    => LibXC Density Thresholds  <==
#
#     XC_MGGA_C_M06_2X:  1.00E-12
#     XC_HYB_MGGA_X_M06_2X:  1.00E-15
#
#    => Molecular Quadrature <=
#
#     Radial Scheme          =       TREUTLER
#     Pruning Scheme         =           NONE
#     Nuclear Scheme         =       TREUTLER
#
#     BS radius alpha        =              1
#     Pruning alpha          =              1
#     Radial Points          =             75
#     Spherical Points       =            302
#     Total Points           =         130210
#     Total Blocks           =           1041
#     Max Points             =            256
#     Max Functions          =             38
#     Weights Tolerance      =       1.00E-15
#
#    => Loading Basis Set <=
#
#     Name: (6-31G(D) AUX)
#     Role: JKFIT
#     Keyword: DF_BASIS_SCF
#     atoms 1      entry O          line   221 file /usr/local/share/psi4/basis/cc-pvdz-jkfit.gbs
#     atoms 2, 4-6 entry H          line    51 file /usr/local/share/psi4/basis/cc-pvdz-jkfit.gbs
#     atoms 3      entry C          line   121 file /usr/local/share/psi4/basis/cc-pvdz-jkfit.gbs
#
#    => Loading Basis Set <=
#
#     Name: 6-31G(D)
#     Role: ORBITAL
#     Keyword: BASIS
#     atoms 1      entry O          line   145 file /usr/local/share/psi4/basis/6-31g_d_.gbs
#     atoms 2, 4-6 entry H          line    44 file /usr/local/share/psi4/basis/6-31g_d_.gbs
#     atoms 3      entry C          line   111 file /usr/local/share/psi4/basis/6-31g_d_.gbs
#
#   Reading orbitals from file /tmp/log.default.60.180.npy, no projection.
#
#   ==> Integral Setup <==
#
#   DFHelper Memory: AOs need 0.004 GiB; user supplied 6.639 GiB. Using in-core AOs.
#
#   ==> MemDFJK: Density-Fitted J/K Matrices <==
#
#     J tasked:                   Yes
#     K tasked:                   Yes
#     wK tasked:                   No
#     OpenMP threads:               2
#     Memory [MiB]:              6798
#     Algorithm:                 Core
#     Schwarz Cutoff:           1E-12
#     Mask sparsity (%):       0.0000
#     Fitting Condition:        1E-10
#
#    => Auxiliary Basis Set <=
#
#   Basis Set: (6-31G(D) AUX)
#     Blend: CC-PVDZ-JKFIT
#     Number of shells: 84
#     Number of basis functions: 262
#     Number of Cartesian functions: 262
#     Spherical Harmonics?: false
#     Max angular momentum: 3
#
#   Cached 100.0% of DFT collocation blocks in 0.346 [GiB].
#
#   Minimum eigenvalue in the overlap matrix is 9.6233378263E-03.
#   Reciprocal condition number of the overlap matrix is 1.6007466340E-03.
#     Using symmetric orthogonalization.
#
#   ==> Pre-Iterations <==
#
#   SCF Guess: Orbitals guess was supplied from a previous computation.
#
#    -------------------------------------------------------
#     Irrep   Nso     Nmo     Nalpha   Nbeta   Ndocc  Nsocc
#    -------------------------------------------------------
#      A         38      38       9       9       9       0
#    -------------------------------------------------------
#     Total      38      38       9       9       9       0
#    -------------------------------------------------------
#
#   ==> Iterations <==
#
#                            Total Energy        Delta E     RMS |[F,P]|
#
#    @DF-RKS iter   0:  -115.66595614492665   -1.15666e+02   1.99575e-03
#    @DF-RKS iter   1:  -115.65449578113403    1.14604e-02   2.89667e-04 DIIS
#    @DF-RKS iter   2:  -115.65458706804577   -9.12869e-05   1.51571e-04 DIIS
#    @DF-RKS iter   3:  -115.65460016983960   -1.31018e-05   7.94769e-05 DIIS
#    @DF-RKS iter   4:  -115.65460455034729   -4.38051e-06   1.69180e-05 DIIS
#    @DF-RKS iter   5:  -115.65460493255623   -3.82209e-07   2.27791e-06 DIIS
#    @DF-RKS iter   6:  -115.65460494524207   -1.26858e-08   4.98274e-07 DIIS
#    @DF-RKS iter   7:  -115.65460494569014   -4.48068e-10   1.74938e-07 DIIS
#    @DF-RKS iter   8:  -115.65460494571580   -2.56648e-11   4.63521e-08 DIIS
#    @DF-RKS iter   9:  -115.65460494571775   -1.94689e-12   5.21685e-09 DIIS
#   Energy and wave function converged.
#
#
#   ==> Post-Iterations <==
#
#    Electrons on quadrature grid:
#       Ntotal   =   18.0000008275 ; deviation = 8.275e-07
#
#     Orbital Energies [Eh]
#     ---------------------
#
#     Doubly Occupied:
#
#        1A    -19.629522     2A    -10.582137     3A     -1.131783
#        4A     -0.769235     5A     -0.577145     6A     -0.509731
#        7A     -0.488348     8A     -0.401572     9A     -0.340376
#
#     Virtual:
#
#       10A      0.124317    11A      0.183696    12A      0.216219
#       13A      0.225360    14A      0.257580    15A      0.597409
#       16A      0.617314    17A      0.626054    18A      0.856810
#       19A      0.922088    20A      0.947629    21A      0.974417
#       22A      1.019726    23A      1.054385    24A      1.080133
#       25A      1.181434    26A      1.514011    27A      1.559378
#       28A      1.632723    29A      1.803881    30A      2.113185
#       31A      2.190863    32A      2.197757    33A      2.397794
#       34A      2.456268    35A      2.506743    36A      2.839121
#       37A      3.731063    38A      4.256017
#
#     Final Occupation by Irrep:
#               A
#     DOCC [     9 ]
#
#   @DF-RKS Final Energy:  -115.65460494571775
#
#    => Energetics <=
#
#     Nuclear Repulsion Energy =             40.3552603282885585
#     One-Electron Energy =                -237.0195193687961535
#     Two-Electron Energy =                  88.4541080352768603
#     DFT Exchange-Correlation Energy =      -7.4444539404870129
#     Empirical Dispersion Energy =           0.0000000000000000
#     VV10 Nonlocal Energy =                  0.0000000000000000
#     Total Energy =                       -115.6546049457177503
#
# Computation Completed
#
#
# Properties will be evaluated at   0.000000,   0.000000,   0.000000 [a0]
#
# Properties computed using the SCF density matrix
#
#   Nuclear Dipole Moment: [e a0]
#      X:     1.0408      Y:    -1.7743      Z:     1.0135
#
#   Electronic Dipole Moment: [e a0]
#      X:    -0.4038      Y:     1.5603      Z:    -0.8109
#
#   Dipole Moment: [e a0]
#      X:     0.6371      Y:    -0.2140      Z:     0.2026     Total:     0.7019
#
#   Dipole Moment: [D]
#      X:     1.6193      Y:    -0.5439      Z:     0.5150     Total:     1.7841
#
#
# *** tstop() called on 62de2050016d at Tue Apr 19 09:46:43 2022
# Module time:
# 	user time   =       9.15 seconds =       0.15 minutes
# 	system time =       0.19 seconds =       0.00 minutes
# 	total time  =          5 seconds =       0.08 minutes
# Total time:
# 	user time   =      21.01 seconds =       0.35 minutes
# 	system time =       0.77 seconds =       0.01 minutes
# 	total time  =         12 seconds =       0.20 minutes
#
# *** tstart() called on 62de2050016d
# *** at Tue Apr 19 09:46:43 2022
#
#
#          ------------------------------------------------------------
#                                    SCF GRAD
#                           Rob Parrish, Justin Turney,
#                        Andy Simmonett, and Alex Sokolov
#          ------------------------------------------------------------
#
#   ==> Geometry <==
#
#     Molecular point group: c1
#     Full point group: C1
#
#     Geometry (in Angstrom), charge = 0, multiplicity = 1:
#
#        Center              X                  Y                   Z               Mass
#     ------------   -----------------  -----------------  -----------------  -----------------
#          O           -0.143408300977     0.601675624552    -0.309455784813    15.994914619570
#          H            0.713063326546     1.041268404815    -0.385570811196     1.007825032230
#          C            0.097844575790    -0.642765179730     0.321549247322    12.000000000000
#          H            0.755797996726    -1.292365844707    -0.269589432951     1.007825032230
#          H           -0.876758099237    -1.123329957675     0.410976480469     1.007825032230
#          H            0.518871979568    -0.521306510131     1.326839833785     1.007825032230
#
#   Nuclear repulsion =   40.355260328288558
#
#   ==> Basis Set <==
#
#   Basis Set: 6-31G(D)
#     Blend: 6-31G(D)
#     Number of shells: 20
#     Number of basis functions: 38
#     Number of Cartesian functions: 38
#     Spherical Harmonics?: false
#     Max angular momentum: 2
#
#   ==> DFJKGrad: Density-Fitted SCF Gradients <==
#
#     Gradient:                    1
#     J tasked:                  Yes
#     K tasked:                  Yes
#     wK tasked:                  No
#     OpenMP threads:              2
#     Integrals threads:           2
#     Memory [MiB]:             7152
#     Schwarz Cutoff:          1E-12
#     Fitting Condition:       1E-10
#
#    => Auxiliary Basis Set <=
#
#   Basis Set: (6-31G(D) AUX)
#     Blend: CC-PVDZ-JKFIT
#     Number of shells: 84
#     Number of basis functions: 262
#     Number of Cartesian functions: 262
#     Spherical Harmonics?: false
#     Max angular momentum: 3
#
#   ==> DFT Potential <==
#
#    => Composite Functional: M06-2X <=
#
#     Hybrid M06-2X Meta-GGA XC Functional
# (10.1007/s00214-007-0310-x)
#     Y. Zhao and D. G. Truhlar,  Theor. Chem. Acc., 120, 215, 2008
#
#
#     Deriv               =              1
#     GGA                 =           TRUE
#     Meta                =           TRUE
#
#     Exchange Hybrid     =           TRUE
#     MP2 Hybrid          =          FALSE
#
#    => Exchange Functionals <=
#
#     1.0000   XC_HYB_MGGA_X_M06_2X
#
#    => Exact (HF) Exchange <=
#
#     0.5400               HF
#
#    => Correlation Functionals <=
#
#     1.0000   XC_MGGA_C_M06_2X
#
#    => LibXC Density Thresholds  <==
#
#     XC_MGGA_C_M06_2X:  1.00E-12
#     XC_HYB_MGGA_X_M06_2X:  1.00E-15
#
#    => Molecular Quadrature <=
#
#     Radial Scheme          =       TREUTLER
#     Pruning Scheme         =           NONE
#     Nuclear Scheme         =       TREUTLER
#
#     BS radius alpha        =              1
#     Pruning alpha          =              1
#     Radial Points          =             75
#     Spherical Points       =            302
#     Total Points           =         130210
#     Total Blocks           =           1041
#     Max Points             =            256
#     Max Functions          =             38
#     Weights Tolerance      =       1.00E-15
#
#
#   -Total Gradient:
#      Atom            X                  Y                   Z
#     ------   -----------------  -----------------  -----------------
#        1       -0.004137485560     0.002501432545    -0.001417393632
#        2        0.000733173520    -0.002405578637     0.001323332904
#        3        0.004574583059    -0.003446426034     0.001905709090
#        4       -0.000280283463     0.000211222679    -0.000161782840
#        5       -0.000192026069     0.002280498802    -0.000924726108
#        6       -0.000658986181     0.000688355246    -0.000639153633
#
#
# *** tstop() called on 62de2050016d at Tue Apr 19 09:46:44 2022
# Module time:
# 	user time   =       1.68 seconds =       0.03 minutes
# 	system time =       0.03 seconds =       0.00 minutes
# 	total time  =          1 seconds =       0.02 minutes
# Total time:
# 	user time   =      22.69 seconds =       0.38 minutes
# 	system time =       0.80 seconds =       0.01 minutes
# 	total time  =         13 seconds =       0.22 minutes
#
# 			-----------------------------------------
# 			 OPTKING 2.0: for geometry optimizations
# 			  - R.A. King,  Bethel University
# 			-----------------------------------------
#
# 	Previous internal coordinate definitions found.
# 	---Fragment 1 Geometry and Gradient---
# 	 O          -0.2710024130        1.1370021468       -0.5847866812
# 	 H           1.3474943973        1.9677121082       -0.7286232351
# 	 C           0.1848994511       -1.2146501527        0.6076400133
# 	 H           1.4282512200       -2.4422175004       -0.5094501946
# 	 H          -1.6568326858       -2.1227859685        0.7766329921
# 	 H           0.9805259356       -0.9851265316        2.5073638982
# 	            -0.0041374856        0.0025014325       -0.0014173936
# 	             0.0007331735       -0.0024055786        0.0013233329
# 	             0.0045745831       -0.0034464260        0.0019057091
# 	            -0.0002802835        0.0002112227       -0.0001617828
# 	            -0.0001920261        0.0022804988       -0.0009247261
# 	            -0.0006589862        0.0006883552       -0.0006391536
#
# 	---Fragment 1 Intrafragment Coordinates---
# 	 - Coordinate -           - BOHR/RAD -       - ANG/DEG -
# 	 R(1,2)           =         1.824911	       0.965701
# 	 R(1,3)           =         2.675817	       1.415981
# 	 R(3,4)           =         2.073822	       1.097419
# 	 R(3,5)           =         2.060400	       1.090317
# 	 R(3,6)           =         2.072355	       1.096643
# 	 B(1,3,4)         =         1.963112	     112.478048
# 	 B(1,3,5)         =         1.845867	     105.760395
# 	 B(1,3,6)         =         1.956902	     112.122249
# 	 B(2,1,3)         =         1.858839	     106.503630
# 	 B(4,3,5)         =         1.895680	     108.614458
# 	 B(4,3,6)         =         1.906222	     109.218452
# 	 B(5,3,6)         =         1.893158	     108.469965
# 	 D(2,1,3,4)       =        -1.085406	     -62.189170
# 	 D(2,1,3,5)       =         3.131210	     179.405126
# 	 D(2,1,3,6)       =         1.071044	      61.366312
#
# 	Current energy   :      -115.6546049457
#
# 	Energy change for the previous step:
# 		Projected    :         0.0011061252
# 		Actual       :        -0.0009803731
#
# 	Performing BFGS update.
# 	Previous computed or guess Hessian on step 1.
# 	Steps to be used in Hessian update: 1
# 	Taking RFO optimization step.
# 	Going to follow RFO solution 1.
# 	Using RFO vector 1.
# 	Norm of target step-size    0.16116
# 	Projected energy change by RFO approximation:        -0.0005095167
#
# 	Back-transformation to cartesian coordinates...
# 	Could not converge backtransformation.
# 	Using first guess instead.
#
# 	--- Internal Coordinate Step in ANG or DEG, aJ/ANG or AJ/DEG ---
# 	 ---------------------------------------------------------------------------
# 	   Coordinate                Previous        Force       Change         New
# 	   ----------                --------       ------       ------       ------
# 	    1 R(1,2)          =      0.965701     0.004663     0.002111     0.967812
# 	    2 R(1,3)          =      1.415981    -0.006477    -0.001464     1.414517
# 	    3 R(3,4)          =      1.097419     0.001774     0.000629     1.098048
# 	    4 R(3,5)          =      1.090317     0.007610     0.001527     1.091843
# 	    5 R(3,6)          =      1.096643     0.006340     0.001479     1.098122
# 	    6 B(1,3,4)        =    112.478048    -0.000045    -0.175596   112.302451
# 	    7 B(1,3,5)        =    105.760395     0.000266     1.108945   106.869340
# 	    8 B(1,3,6)        =    112.122249     0.000043     0.179303   112.301552
# 	    9 B(2,1,3)        =    106.503630     0.000379     1.383718   107.887348
# 	   10 B(4,3,5)        =    108.614458    -0.000095    -0.355275   108.259183
# 	   11 B(4,3,6)        =    109.218452    -0.000081    -0.496998   108.721454
# 	   12 B(5,3,6)        =    108.469965    -0.000086    -0.247860   108.222105
# 	   13 D(2,1,3,4)      =    -62.189170     0.000011     5.510181   -56.678989
# 	   14 D(2,1,3,5)      =    179.405126     0.000005     5.344109   184.749235
# 	   15 D(2,1,3,6)      =     61.366312    -0.000014     4.856937    66.223249
# 	 ---------------------------------------------------------------------------
# 	Successfully symmetrized geometry.
#
#   ==> Convergence Check <==
#
#   Measures of convergence in internal coordinates in au.
#   Criteria marked as inactive (o), active & met (*), and active & unmet ( ).
#   ---------------------------------------------------------------------------------------------
#    Step     Total Energy     Delta E     MAX Force     RMS Force      MAX Disp      RMS Disp
#   ---------------------------------------------------------------------------------------------
#     Convergence Criteria    1.00e-06 *    3.00e-04 *             o    1.20e-03 *             o
#   ---------------------------------------------------------------------------------------------
#       2    -115.65460495   -9.80e-04      4.98e-03      1.74e-03 o    9.62e-02      4.19e-02 o  ~
#   ---------------------------------------------------------------------------------------------
#
# 	Writing optimization data to binary file.
# 	Structure for next step:
# 	Cartesian Geometry (in Angstrom)
# 	    O    -0.1390057319   0.6155589731  -0.2831795248
# 	    H     0.7193924720   1.0385056988  -0.4278477279
# 	    C     0.0922715303  -0.6389059032   0.3281209243
# 	    H     0.7601859015  -1.2756395695  -0.2670002047
# 	    H    -0.8762183994  -1.1370839958   0.4053684642
# 	    H     0.5087857017  -0.5392586586   1.3392875974
# 			--------------------------
# 			 OPTKING Finished Execution
# 			--------------------------
#
#     Structure for next step:
#     Molecular point group: c1
#     Full point group: C1
#
#     Geometry (in Angstrom), charge = 0, multiplicity = 1:
#
#     O           -0.139153167963     0.607737481690    -0.297731407474
#     H            0.719245039273     1.030684209053    -0.442399611144
#     C            0.092124095127    -0.646727399465     0.313569044046
#     H            0.760038468958    -1.283461068273    -0.281552087329
#     H           -0.876365838384    -1.144905494078     0.390816584237
#     H            0.508638268204    -0.547080154556     1.324735721083
#
#
# Scratch directory: /tmp/
#
# Scratch directory: /tmp/
# gradient() will perform analytic gradient computation.
#
# *** tstart() called on 62de2050016d
# *** at Tue Apr 19 09:46:44 2022
#
#    => Loading Basis Set <=
#
#     Name: 6-31G(D)
#     Role: ORBITAL
#     Keyword: BASIS
#     atoms 1      entry O          line   145 file /usr/local/share/psi4/basis/6-31g_d_.gbs
#     atoms 2, 4-6 entry H          line    44 file /usr/local/share/psi4/basis/6-31g_d_.gbs
#     atoms 3      entry C          line   111 file /usr/local/share/psi4/basis/6-31g_d_.gbs
#
#
#          ---------------------------------------------------------
#                                    SCF
#                by Justin Turney, Rob Parrish, Andy Simmonett
#                           and Daniel G. A. Smith
#                               RKS Reference
#                         2 Threads,   9536 MiB Core
#          ---------------------------------------------------------
#
#   ==> Geometry <==
#
#     Molecular point group: c1
#     Full point group: C1
#
#     Geometry (in Angstrom), charge = 0, multiplicity = 1:
#
#        Center              X                  Y                   Z               Mass
#     ------------   -----------------  -----------------  -----------------  -----------------
#          O           -0.139153167963     0.607737481690    -0.297731407474    15.994914619570
#          H            0.719245039273     1.030684209053    -0.442399611144     1.007825032230
#          C            0.092124095127    -0.646727399465     0.313569044046    12.000000000000
#          H            0.760038468958    -1.283461068273    -0.281552087329     1.007825032230
#          H           -0.876365838384    -1.144905494078     0.390816584237     1.007825032230
#          H            0.508638268204    -0.547080154556     1.324735721083     1.007825032230
#
#   Running in c1 symmetry.
#
#   Rotational constants: A =      4.25330  B =      0.83169  C =      0.80188 [cm^-1]
#   Rotational constants: A = 127510.80190  B =  24933.42856  C =  24039.83524 [MHz]
#   Nuclear repulsion =   40.322976858834366
#
#   Charge       = 0
#   Multiplicity = 1
#   Electrons    = 18
#   Nalpha       = 9
#   Nbeta        = 9
#
#   ==> Algorithm <==
#
#   SCF Algorithm Type is DF.
#   DIIS enabled.
#   MOM disabled.
#   Fractional occupation disabled.
#   Guess Type is READ.
#   Energy threshold   = 1.00e-08
#   Density threshold  = 1.00e-08
#   Integral threshold = 1.00e-12
#
#   ==> Primary Basis <==
#
#   Basis Set: 6-31G(D)
#     Blend: 6-31G(D)
#     Number of shells: 20
#     Number of basis functions: 38
#     Number of Cartesian functions: 38
#     Spherical Harmonics?: false
#     Max angular momentum: 2
#
#   ==> DFT Potential <==
#
#    => Composite Functional: M06-2X <=
#
#     Hybrid M06-2X Meta-GGA XC Functional
# (10.1007/s00214-007-0310-x)
#     Y. Zhao and D. G. Truhlar,  Theor. Chem. Acc., 120, 215, 2008
#
#
#     Deriv               =              1
#     GGA                 =           TRUE
#     Meta                =           TRUE
#
#     Exchange Hybrid     =           TRUE
#     MP2 Hybrid          =          FALSE
#
#    => Exchange Functionals <=
#
#     1.0000   XC_HYB_MGGA_X_M06_2X
#
#    => Exact (HF) Exchange <=
#
#     0.5400               HF
#
#    => Correlation Functionals <=
#
#     1.0000   XC_MGGA_C_M06_2X
#
#    => LibXC Density Thresholds  <==
#
#     XC_MGGA_C_M06_2X:  1.00E-12
#     XC_HYB_MGGA_X_M06_2X:  1.00E-15
#
#    => Molecular Quadrature <=
#
#     Radial Scheme          =       TREUTLER
#     Pruning Scheme         =           NONE
#     Nuclear Scheme         =       TREUTLER
#
#     BS radius alpha        =              1
#     Pruning alpha          =              1
#     Radial Points          =             75
#     Spherical Points       =            302
#     Total Points           =         130153
#     Total Blocks           =           1034
#     Max Points             =            255
#     Max Functions          =             38
#     Weights Tolerance      =       1.00E-15
#
#    => Loading Basis Set <=
#
#     Name: (6-31G(D) AUX)
#     Role: JKFIT
#     Keyword: DF_BASIS_SCF
#     atoms 1      entry O          line   221 file /usr/local/share/psi4/basis/cc-pvdz-jkfit.gbs
#     atoms 2, 4-6 entry H          line    51 file /usr/local/share/psi4/basis/cc-pvdz-jkfit.gbs
#     atoms 3      entry C          line   121 file /usr/local/share/psi4/basis/cc-pvdz-jkfit.gbs
#
#    => Loading Basis Set <=
#
#     Name: 6-31G(D)
#     Role: ORBITAL
#     Keyword: BASIS
#     atoms 1      entry O          line   145 file /usr/local/share/psi4/basis/6-31g_d_.gbs
#     atoms 2, 4-6 entry H          line    44 file /usr/local/share/psi4/basis/6-31g_d_.gbs
#     atoms 3      entry C          line   111 file /usr/local/share/psi4/basis/6-31g_d_.gbs
#
#   Reading orbitals from file /tmp/log.default.60.180.npy, no projection.
#
#   ==> Integral Setup <==
#
#   DFHelper Memory: AOs need 0.004 GiB; user supplied 6.639 GiB. Using in-core AOs.
#
#   ==> MemDFJK: Density-Fitted J/K Matrices <==
#
#     J tasked:                   Yes
#     K tasked:                   Yes
#     wK tasked:                   No
#     OpenMP threads:               2
#     Memory [MiB]:              6797
#     Algorithm:                 Core
#     Schwarz Cutoff:           1E-12
#     Mask sparsity (%):       0.0000
#     Fitting Condition:        1E-10
#
#    => Auxiliary Basis Set <=
#
#   Basis Set: (6-31G(D) AUX)
#     Blend: CC-PVDZ-JKFIT
#     Number of shells: 84
#     Number of basis functions: 262
#     Number of Cartesian functions: 262
#     Spherical Harmonics?: false
#     Max angular momentum: 3
#
#   Cached 100.0% of DFT collocation blocks in 0.346 [GiB].
#
#   Minimum eigenvalue in the overlap matrix is 9.6844597442E-03.
#   Reciprocal condition number of the overlap matrix is 1.6134975225E-03.
#     Using symmetric orthogonalization.
#
#   ==> Pre-Iterations <==
#
#   SCF Guess: Orbitals guess was supplied from a previous computation.
#
#    -------------------------------------------------------
#     Irrep   Nso     Nmo     Nalpha   Nbeta   Ndocc  Nsocc
#    -------------------------------------------------------
#      A         38      38       9       9       9       0
#    -------------------------------------------------------
#     Total      38      38       9       9       9       0
#    -------------------------------------------------------
#
#   ==> Iterations <==
#
#                            Total Energy        Delta E     RMS |[F,P]|
#
#    @DF-RKS iter   0:  -115.65280782045859   -1.15653e+02   1.00802e-03
#    @DF-RKS iter   1:  -115.65465918092087   -1.85136e-03   1.63284e-04 DIIS
#    @DF-RKS iter   2:  -115.65470309218182   -4.39113e-05   5.68026e-05 DIIS
#    @DF-RKS iter   3:  -115.65470721578178   -4.12360e-06   4.65425e-05 DIIS
#    @DF-RKS iter   4:  -115.65470866315711   -1.44738e-06   7.32255e-06 DIIS
#    @DF-RKS iter   5:  -115.65470872674996   -6.35929e-08   2.25252e-06 DIIS
#    @DF-RKS iter   6:  -115.65470873304245   -6.29250e-09   7.71579e-07 DIIS
#    @DF-RKS iter   7:  -115.65470873361774   -5.75284e-10   6.57219e-08 DIIS
#    @DF-RKS iter   8:  -115.65470873362537   -7.63123e-12   1.20542e-08 DIIS
#    @DF-RKS iter   9:  -115.65470873362567   -2.98428e-13   1.83606e-09 DIIS
#   Energy and wave function converged.
#
#
#   ==> Post-Iterations <==
#
#    Electrons on quadrature grid:
#       Ntotal   =   17.9999959503 ; deviation = -4.050e-06
#
#     Orbital Energies [Eh]
#     ---------------------
#
#     Doubly Occupied:
#
#        1A    -19.629371     2A    -10.582527     3A     -1.130789
#        4A     -0.769442     5A     -0.576992     6A     -0.508674
#        7A     -0.489966     8A     -0.399555     9A     -0.339735
#
#     Virtual:
#
#       10A      0.124155    11A      0.182635    12A      0.216989
#       13A      0.225405    14A      0.258390    15A      0.599138
#       16A      0.616797    17A      0.625566    18A      0.855125
# ...
#     Spherical Harmonics?: true
#     Max angular momentum: 3
#
#   ==> Integral Setup <==
#
#   Using in-core PK algorithm.
#    Calculation information:
#       Number of atoms:                   6
#       Number of AO shells:              44
#       Number of primitives:             84
#       Number of atomic orbitals:       130
#       Number of basis functions:       116
#
#       Integral cutoff                 1.00e-12
#       Number of threads:                 2
#
#   Performing in-core PK
#   Using 46056582 doubles for integral storage.
#   We computed 512597 shell quartets total.
#   Whereas there are 490545 unique shell quartets.
#      4.50 percent of shell quartets recomputed by reordering.
#
#   ==> DiskJK: Disk-Based J/K Matrices <==
#
#     J tasked:                  Yes
#     K tasked:                  Yes
#     wK tasked:                  No
#     Memory [MiB]:             7152
#     Schwarz Cutoff:          1E-12
#
#     OpenMP threads:              2
#
#   Minimum eigenvalue in the overlap matrix is 1.8647271173E-03.
#   Reciprocal condition number of the overlap matrix is 2.8226372588E-04.
#     Using symmetric orthogonalization.
#
#   ==> Pre-Iterations <==
#
#   SCF Guess: Superposition of Atomic Densities via on-the-fly atomic UHF (no occupation information).
#
#    -------------------------
#     Irrep   Nso     Nmo
#    -------------------------
#      A        116     116
#    -------------------------
#     Total     116     116
#    -------------------------
#
#   ==> Iterations <==
#
#                         Total Energy        Delta E     RMS |[F,P]|
#
#    @RHF iter SAD:  -114.42313674578349   -1.14423e+02   0.00000e+00
#    @RHF iter   1:  -115.01382205632527   -5.90685e-01   3.41819e-03 DIIS
#    @RHF iter   2:  -115.07093772598323   -5.71157e-02   1.96496e-03 DIIS
#    @RHF iter   3:  -115.08798420467900   -1.70465e-02   3.00352e-04 DIIS
#    @RHF iter   4:  -115.08887578812609   -8.91583e-04   8.77187e-05 DIIS
#    @RHF iter   5:  -115.08894935560934   -7.35675e-05   2.16405e-05 DIIS
#    @RHF iter   6:  -115.08895435588369   -5.00027e-06   4.85917e-06 DIIS
#    @RHF iter   7:  -115.08895474702926   -3.91146e-07   1.14185e-06 DIIS
#    @RHF iter   8:  -115.08895477058368   -2.35544e-08   2.35096e-07 DIIS
#    @RHF iter   9:  -115.08895477156999   -9.86304e-10   4.38776e-08 DIIS
#    @RHF iter  10:  -115.08895477160232   -3.23297e-11   1.14035e-08 DIIS
#    @RHF iter  11:  -115.08895477160442   -2.10321e-12   2.27794e-09 DIIS
#   Energy and wave function converged.
#
#
#   ==> Post-Iterations <==
#
#     Orbital Energies [Eh]
#     ---------------------
#
#     Doubly Occupied:
#
#        1A    -20.553389     2A    -11.269911     3A     -1.356179
#        4A     -0.921271     5A     -0.688811     6A     -0.618013
#        7A     -0.592095     8A     -0.499805     9A     -0.447706
#
#     Virtual:
#
#       10A      0.138172    11A      0.178025    12A      0.220528
#       13A      0.223944    14A      0.291529    15A      0.386844
#       16A      0.405117    17A      0.545258    18A      0.584240
#       19A      0.621303    20A      0.624906    21A      0.637608
#       22A      0.689978    23A      0.702307    24A      0.721211
#       25A      0.830841    26A      0.866704    27A      0.869787
#       28A      0.928990    29A      1.067170    30A      1.100681
#       31A      1.177693    32A      1.189535    33A      1.262692
#       34A      1.271381    35A      1.282812    36A      1.367497
#       37A      1.443940    38A      1.491204    39A      1.520483
#       40A      1.544204    41A      1.585064    42A      1.613372
#       43A      1.767646    44A      2.090101    45A      2.180331
#       46A      2.201325    47A      2.305279    48A      2.326129
#       49A      2.494441    50A      2.513469    51A      2.579914
#       52A      2.801092    53A      2.948506    54A      3.056841
#       55A      3.106279    56A      3.116107    57A      3.144924
#       58A      3.227687    59A      3.243373    60A      3.311910
#       61A      3.313650    62A      3.344615    63A      3.388106
#       64A      3.497664    65A      3.612127    66A      3.630724
#       67A      3.695411    68A      3.705442    69A      3.745933
#       70A      3.758629    71A      3.811869    72A      3.832695
#       73A      3.902146    74A      4.002421    75A      4.025305
#       76A      4.115662    77A      4.154088    78A      4.167806
#       79A      4.241489    80A      4.252175    81A      4.284213
#       82A      4.393765    83A      4.433447    84A      4.456679
#       85A      4.550910    86A      4.574034    87A      4.710619
#       88A      4.772442    89A      4.984343    90A      5.014853
#       91A      5.044276    92A      5.195536    93A      5.260189
#       94A      5.300529    95A      5.362957    96A      5.421190
#       97A      5.529859    98A      5.532873    99A      5.549288
#      100A      5.793353   101A      5.942683   102A      6.185958
#      103A      6.204329   104A      6.242775   105A      6.443501
#      106A      6.645588   107A      6.978846   108A      7.119493
#      109A      7.164055   110A      7.234893   111A      7.358973
#      112A      7.425066   113A      7.597785   114A      7.905790
#      115A     12.099557   116A     13.674660
#
#     Final Occupation by Irrep:
#               A
#     DOCC [     9 ]
#
#   @RHF Final Energy:  -115.08895477160442
#
#    => Energetics <=
#
#     Nuclear Repulsion Energy =             40.3890701416880660
#     One-Electron Energy =                -237.0616914652249534
#     Two-Electron Energy =                  81.5836665519324526
#     Total Energy =                       -115.0889547716044206
#
# Computation Completed
#
#
# Properties will be evaluated at   0.000000,   0.000000,   0.000000 [a0]
#
# Properties computed using the SCF density matrix
#
#   Nuclear Dipole Moment: [e a0]
#      X:     1.0067      Y:    -1.7919      Z:     1.0142
#
#   Electronic Dipole Moment: [e a0]
#      X:    -0.3903      Y:     1.5532      Z:    -0.8097
#
#   Dipole Moment: [e a0]
#      X:     0.6164      Y:    -0.2387      Z:     0.2045     Total:     0.6919
#
#   Dipole Moment: [D]
#      X:     1.5667      Y:    -0.6068      Z:     0.5197     Total:     1.7587
#
#
# *** tstop() called on 62de2050016d at Tue Apr 19 09:47:10 2022
# Module time:
# 	user time   =       8.28 seconds =       0.14 minutes
# 	system time =       0.40 seconds =       0.01 minutes
# 	total time  =          5 seconds =       0.08 minutes
# Total time:
# 	user time   =      72.05 seconds =       1.20 minutes
# 	system time =       1.88 seconds =       0.03 minutes
# 	total time  =         39 seconds =       0.65 minutes
#  MINTS: Wrapper to libmints.
#    by Justin Turney
#
#    Calculation information:
#       Number of threads:                 2
#       Number of atoms:                   6
#       Number of AO shells:              44
#       Number of SO shells:              44
#       Number of primitives:             84
#       Number of atomic orbitals:       130
#       Number of basis functions:       116
#
#       Number of irreps:                  1
#       Integral cutoff                 1.00e-12
#       Number of functions per irrep: [ 116 ]
#
#  OEINTS: Overlap, kinetic, potential, dipole, and quadrupole integrals
#          stored in file 35.
#
#       Computing two-electron integrals...done
#       Computed 22806502 non-zero two-electron integrals.
#         Stored in file 33.
#
#
# *** tstart() called on 62de2050016d
# *** at Tue Apr 19 09:47:13 2022
#
#
# 	Wfn Parameters:
# 	--------------------
# 	Wavefunction         = CCSD_T
# 	Number of irreps     = 1
# 	Number of MOs        = 116
# 	Number of active MOs = 116
# 	AO-Basis             = NONE
# 	Semicanonical        = false
# 	Reference            = RHF
# 	Print Level          = 1
#
# 	IRREP	# MOs	# FZDC	# DOCC	# SOCC	# VIRT	# FZVR
# 	-----	-----	------	------	------	------	------
# 	 A	   116	    0	    9	    0	    107	    0
# 	Transforming integrals...
# 	IWL integrals will be deleted.
# 	(OO|OO)...
# 	Presorting SO-basis two-electron integrals.
# 	Sorting File: SO Ints (nn|nn) nbuckets = 1
# 	Constructing frozen core operators
# 	Starting first half-transformation.
# 	Sorting half-transformed integrals.
# 	First half integral transformation complete.
# 	Starting second half-transformation.
# 	Two-electron integral transformation complete.
# 	(OO|OV)...
# 	Starting second half-transformation.
# 	Two-electron integral transformation complete.
# 	(OO|VV)...
# 	Starting second half-transformation.
# 	Two-electron integral transformation complete.
# 	(OV|OO)...
# 	Starting first half-transformation.
# 	Sorting half-transformed integrals.
# 	First half integral transformation complete.
# 	Starting second half-transformation.
# 	Two-electron integral transformation complete.
# 	(OV|OV)...
# 	Starting second half-transformation.
# 	Two-electron integral transformation complete.
# 	(OV|VV)...
# 	Starting second half-transformation.
# 	Two-electron integral transformation complete.
# 	(VV|OO)...
# 	Starting first half-transformation.
# 	Sorting half-transformed integrals.
# 	First half integral transformation complete.
# 	Starting second half-transformation.
# 	Two-electron integral transformation complete.
# 	(VV|OV)...
# 	Starting second half-transformation.
# 	Two-electron integral transformation complete.
# 	(VV|VV)...
# 	Starting second half-transformation.
# 	Two-electron integral transformation complete.
# 	Frozen core energy     =      0.00000000000000
#
# 	Size of irrep 0 of <ab|cd> integrals:    131.080 (MW) /   1048.637 (MB)
# 	Total:                                   131.080 (MW) /   1048.637 (MB)
#
# 	Size of irrep 0 of <ia|bc> integrals:     11.025 (MW) /     88.203 (MB)
# 	Total:                                    11.025 (MW) /     88.203 (MB)
#
# 	Size of irrep 0 of tijab amplitudes:       0.927 (MW) /      7.419 (MB)
# 	Total:                                     0.927 (MW) /      7.419 (MB)
#
# 	Nuclear Rep. energy          =     40.38907014168807
# 	SCF energy                   =   -115.08895477160442
# 	One-electron energy          =   -237.06169164355845
# 	Two-electron energy          =     81.58366673026580
# 	Reference energy             =   -115.08895477160458
#
# *** tstop() called on 62de2050016d at Tue Apr 19 09:47:42 2022
# Module time:
# 	user time   =      15.87 seconds =       0.26 minutes
# 	system time =       7.96 seconds =       0.13 minutes
# 	total time  =         29 seconds =       0.48 minutes
# Total time:
# 	user time   =      90.66 seconds =       1.51 minutes
# 	system time =      10.50 seconds =       0.17 minutes
# 	total time  =         71 seconds =       1.18 minutes
#             **************************
#             *                        *
#             *        CCENERGY        *
#             *                        *
#             **************************
#
#     Nuclear Rep. energy (wfn)     =   40.389070141688066
#     SCF energy          (wfn)     = -115.088954771604421
#     Reference energy    (file100) = -115.088954771604577
#
#     Input parameters:
#     -----------------
#     Wave function   =     CCSD_T
#     Reference wfn   =     RHF
#     Brueckner       =     No
#     Memory (Mbytes) =     10000.0
#     Maxiter         =     50
#     R_Convergence   =     1.0e-07
#     E_Convergence   =     1.0e-06
#     Restart         =     Yes
#     DIIS            =     Yes
#     AO Basis        =     NONE
#     ABCD            =     NEW
#     Cache Level     =     2
#     Cache Type      =     LOW
#     Print Level     =     1
#     Num. of threads =     2
#     # Amps to Print =     10
#     Print MP2 Amps? =     No
#     Analyze T2 Amps =     No
#     Print Pair Ener =     No
#     Local CC        =     No
#     SCS-MP2         =     False
#     SCSN-MP2        =     False
#     SCS-CCSD        =     False
#
# MP2 correlation energy -0.4576605261619222
#                 Solving CC Amplitude Equations
#                 ------------------------------
#   Iter             Energy              RMS        T1Diag      D1Diag    New D1Diag    D2Diag
#   ----     ---------------------    ---------   ----------  ----------  ----------   --------
#      0        -0.457660526161922    0.000e+00    0.000000    0.000000    0.000000    0.127784
#      1        -0.465118443892650    4.789e-02    0.006512    0.014769    0.014769    0.129103
#      2        -0.475140557053521    1.575e-02    0.006619    0.014790    0.014790    0.134698
#      3        -0.476625563951052    5.533e-03    0.007418    0.016954    0.016954    0.136404
#      4        -0.476521898050581    1.218e-03    0.007471    0.017023    0.017023    0.136604
#      5        -0.476561865239466    4.397e-04    0.007503    0.017129    0.017129    0.136672
#      6        -0.476570655138245    1.242e-04    0.007512    0.017146    0.017146    0.136673
#      7        -0.476568441215135    4.592e-05    0.007514    0.017147    0.017147    0.136669
#      8        -0.476568298502530    1.708e-05    0.007516    0.017147    0.017147    0.136669
#      9        -0.476568414929356    4.980e-06    0.007516    0.017147    0.017147    0.136669
#     10        -0.476568165952789    1.589e-06    0.007516    0.017147    0.017147    0.136669
#     11        -0.476568234666982    4.880e-07    0.007516    0.017147    0.017147    0.136669
#     12        -0.476568220001872    1.179e-07    0.007516    0.017147    0.017147    0.136669
#     13        -0.476568223893452    4.221e-08    0.007516    0.017147    0.017147    0.136669
#
#     Iterations converged.
#
#
#     Largest TIA Amplitudes:
#               5   6        -0.0080459383
#               5  14        -0.0077176817
#               5   9         0.0071456835
#               8  14        -0.0063079044
#               6   3        -0.0060464496
#               5   2        -0.0060293252
#               7   8         0.0056488296
#               6   7         0.0054770650
#               8   6        -0.0053179712
#               6   5        -0.0051294376
#
#     Largest TIjAb Amplitudes:
#       5   5   9   9        -0.0227867836
#       8   8  14  14        -0.0211753686
#       7   7  12  12        -0.0203424550
#       4   4   7   7        -0.0200513541
#       6   6   7   7        -0.0188657436
#       6   6   8   8        -0.0179006611
#       7   7   7   7        -0.0156285369
#       5   5  14  14        -0.0151576694
#       5   8   9   9         0.0150759157
#       8   5   9   9         0.0150759157
#
#     SCF energy       (wfn)                    = -115.088954771604421
#     Reference energy (file100)                = -115.088954771604577
#
#     Opposite-spin MP2 correlation energy      =   -0.354031334855896
#     Same-spin MP2 correlation energy          =   -0.103629191306026
#     Singles MP2 correlation energy            =   -0.000000000000000
#     MP2 correlation energy                    =   -0.457660526161922
#       * MP2 total energy                      = -115.546615297766493
#
#     Opposite-spin CCSD correlation energy     =   -0.382061697513118
#     Same-spin CCSD correlation energy         =   -0.094506526380334
#     Singles CCSD correlation energy           =    0.000000000000000
#     CCSD correlation energy                   =   -0.476568223893452
#       * CCSD total energy                     = -115.565522995498029
#
#             **************************
#             *                        *
#             *        CCTRIPLES       *
#             *                        *
#             **************************
#
#
#     Wave function   =    CCSD_T
#     Reference wfn   =      RHF
#
#     Nuclear Rep. energy (wfn)                =   40.389070141688066
#     SCF energy          (wfn)                = -115.088954771604421
#     Reference energy    (file100)            = -115.088954771604577
#     CCSD energy         (file100)            =   -0.476568223893452
#     Total CCSD energy   (file100)            = -115.565522995498029
#
#     Number of ijk index combinations:              165
#     Memory available in words               :      1250000000
#     Approx. words needed per explicit thread:         4900172
#     Number of threads for explicit ijk threading:    2
#
#     MKL num_threads set to 1 for explicit threading.
#
#     (T) energy                                =   -0.015097408405026
#       * CCSD(T) total energy                  = -115.580620403903055
