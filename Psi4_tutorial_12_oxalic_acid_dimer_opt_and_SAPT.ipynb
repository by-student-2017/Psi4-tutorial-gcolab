# %%
# set conda
# !wget -c https://repo.continuum.io/miniconda/Miniconda3-latest-Linux-x86_64.sh
# !chmod +x Miniconda3-latest-Linux-x86_64.sh
# !bash ./Miniconda3-latest-Linux-x86_64.sh -b -f -p /usr/local

# install psi4
# !conda install -y psi4 python=3.7 -c psi4

# set path
import sys
sys.path.append("/usr/local/lib/python3.7/site-packages/")
# Out:
# --2022-04-19 05:39:20--  https://repo.continuum.io/miniconda/Miniconda3-latest-Linux-x86_64.sh
# Resolving repo.continuum.io (repo.continuum.io)... 104.18.200.79, 104.18.201.79, 2606:4700::6812:c94f, ...
# Connecting to repo.continuum.io (repo.continuum.io)|104.18.200.79|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: https://repo.anaconda.com/miniconda/Miniconda3-latest-Linux-x86_64.sh [following]
# --2022-04-19 05:39:20--  https://repo.anaconda.com/miniconda/Miniconda3-latest-Linux-x86_64.sh
# Resolving repo.anaconda.com (repo.anaconda.com)... 104.16.130.3, 104.16.131.3, 2606:4700::6810:8203, ...
# Connecting to repo.anaconda.com (repo.anaconda.com)|104.16.130.3|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 75660608 (72M) [application/x-sh]
# Saving to: ‘Miniconda3-latest-Linux-x86_64.sh’
#
# Miniconda3-latest-L 100%[===================>]  72.16M  57.5MB/s    in 1.3s
#
# ...

# %%
# import Psi4
import psi4
# check Psi4 version
print(psi4.__version__)
# Out:
# 1.5

# %%
psi4.core.set_output_file("log.txt")

# 07c_oxalic_acid_dimBC_3B-69.xyz
mol = psi4.geometry("""
0 1
O 15.3365330000 4.4406980000 11.8388280000
O 16.1792190000 3.3196460000 10.0762000000
C 16.0048700000 3.5551790000 11.3484460000
H 15.7099600000 3.9617090000 9.4837360000
O 17.4604670000 1.6533020000 11.7183720000
O 16.6177810000 2.7743540000 13.4810000000
C 16.7921300000 2.5388210000 12.2087540000
H 17.0870400000 2.1322910000 14.0734640000
--
0 1
O 15.3365330000 10.5346980000 11.8388280000
O 16.1792190000 9.4136460000 10.0762000000
C 16.0048700000 9.6491790000 11.3484460000
H 15.7099600000 10.0557090000 9.4837360000
O 17.4604670000 7.7473020000 11.7183720000
O 16.6177810000 8.8683540000 13.4810000000
C 16.7921300000 8.6328210000 12.2087540000
H 17.0870400000 8.2262910000 14.0734640000
""")

scf_e, wfn = psi4.optimize("B3LYP-D/6-311G(d)", return_wfn = True)
# Out:
# Optimizer: Optimization complete!

# %%
xyz = mol.save_string_xyz()
print (xyz)
# Out:
# 0 1
#  O    0.035490481727   -1.041906946500    1.259070213492
#  O    0.308382660433   -1.607230214873   -0.907149722889
#  C    0.229352790344   -1.854415326250    0.374467970017
#  H    0.186115509094   -0.635591500014   -1.080316569916
#  O    0.602754589795   -4.190243205427   -0.168582486898
#  O    0.336797566944   -3.585362305570    1.989085980377
#  C    0.415493770295   -3.357854526699    0.671767776454
#  H    0.458464108654   -4.537250161562    2.128901072668
#  O   -0.602754589795    4.190243205427    0.168582486898
#  O   -0.336797566944    3.585362305570   -1.989085980377
#  C   -0.415493770295    3.357854526699   -0.671767776454
#  H   -0.458464108654    4.537250161562   -2.128901072668
#  O   -0.035490481727    1.041906946500   -1.259070213492
#  O   -0.308382660433    1.607230214873    0.907149722889
#  C   -0.229352790344    1.854415326250   -0.374467970017
#  H   -0.186115509094    0.635591500014    1.080316569916

# %%
fchk_writer = psi4.core.FCHKWriter(wfn)
fchk_writer.write("test.fchk")

# %%
scf_e, wfn = psi4.energy("SAPT0/jun-cc-pVDZ", return_wfn = True)
#scf_e, wfn = psi4.energy("SAPT2/jun-cc-pVDZ", return_wfn = True)
#scf_e, wfn = psi4.energy("SAPT2+/jun-cc-pVDZ", return_wfn = True)
#scf_e, wfn = psi4.energy("SAPT2+3/jun-cc-pVDZ", return_wfn = True)

# !cat log.txt
# Out:
# ストリーミング出力は最後の 5000 行に切り捨てられました。
# 	   41 D(2,3,7,6)      =    174.373712     0.000000     2.686507   177.060219
# 	   42 D(3,1,13,15)    =    180.000000     0.000000     0.000000   180.000000
# 	   43 D(3,7,6,8)      =    179.607916     0.000001     0.139266   179.747182
# 	   44 D(4,2,3,7)      =    179.660876     0.000000     0.171661   179.832538
# 	   45 D(5,7,6,8)      =     -0.009114    -0.000001    -0.004595    -0.013709
# 	   46 D(7,3,1,13)     =   -179.746576     0.000002    -0.093018  -179.839594
# 	   47 D(9,11,10,12)   =      0.009114     0.000001     0.004595     0.013709
# 	   48 D(9,11,15,13)   =   -173.709796    -0.000002    -2.995196  -176.704992
# 	   49 D(9,11,15,14)   =      6.002218    -0.000002    -2.827642     3.174576
# 	   50 D(10,11,15,13)  =      5.914275     0.000001    -2.854062     3.060213
# 	   51 D(10,11,15,14)  =   -174.373712    -0.000000    -2.686507  -177.060219
# 	   52 D(11,15,14,16)  =   -179.660876    -0.000000    -0.171661  -179.832538
# ...
