# %%
# set conda
# !wget -c https://repo.continuum.io/miniconda/Miniconda3-latest-Linux-x86_64.sh
# !chmod +x Miniconda3-latest-Linux-x86_64.sh
# !bash ./Miniconda3-latest-Linux-x86_64.sh -b -f -p /usr/local

# install psi4
# !conda install -y psi4 python=3.7 -c psi4

# set path
import sys
sys.path.append("/usr/local/lib/python3.7/site-packages/")
# Out:
# --2022-04-19 09:43:13--  https://repo.continuum.io/miniconda/Miniconda3-latest-Linux-x86_64.sh
# Resolving repo.continuum.io (repo.continuum.io)... 104.18.200.79, 104.18.201.79, 2606:4700::6812:c84f, ...
# Connecting to repo.continuum.io (repo.continuum.io)|104.18.200.79|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: https://repo.anaconda.com/miniconda/Miniconda3-latest-Linux-x86_64.sh [following]
# --2022-04-19 09:43:13--  https://repo.anaconda.com/miniconda/Miniconda3-latest-Linux-x86_64.sh
# Resolving repo.anaconda.com (repo.anaconda.com)... 104.16.130.3, 104.16.131.3, 2606:4700::6810:8303, ...
# Connecting to repo.anaconda.com (repo.anaconda.com)|104.16.130.3|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 75660608 (72M) [application/x-sh]
# Saving to: ‘Miniconda3-latest-Linux-x86_64.sh’
#
# Miniconda3-latest-L 100%[===================>]  72.16M   184MB/s    in 0.4s
#
# 2022-04-19 09:43:14 (184 MB/s) - ‘Miniconda3-latest-Linux-x86_64.sh’ saved [75660608/75660608]
#
# PREFIX=/usr/local
# Unpacking payload ...
# done
# done
#
# ## Package Plan ##
#
#   environment location: /usr/local
#
#   added / updated specs:
#     - _libgcc_mutex==0.1=main
#     - _openmp_mutex==4.5=1_gnu
#     - brotlipy==0.7.0=py39h27cfd23_1003
#     - ca-certificates==2021.10.26=h06a4308_2
#     - certifi==2021.10.8=py39h06a4308_2
#     - cffi==1.15.0=py39hd667e15_1
#     - charset-normalizer==2.0.4=pyhd3eb1b0_0
#     - conda-content-trust==0.1.1=pyhd3eb1b0_0
#     - conda-package-handling==1.7.3=py39h27cfd23_1
#     - conda==4.11.0=py39h06a4308_0
#     - cryptography==36.0.0=py39h9ce1e76_0
#     - idna==3.3=pyhd3eb1b0_0
#     - ld_impl_linux-64==2.35.1=h7274673_9
#     - libffi==3.3=he6710b0_2
#     - libgcc-ng==9.3.0=h5101ec6_17
#     - libgomp==9.3.0=h5101ec6_17
#     - libstdcxx-ng==9.3.0=hd4cf53a_17
#     - ncurses==6.3=h7f8727e_2
#     - openssl==1.1.1m=h7f8727e_0
#     - pip==21.2.4=py39h06a4308_0
#     - pycosat==0.6.3=py39h27cfd23_0
#     - pycparser==2.21=pyhd3eb1b0_0
#     - pyopenssl==21.0.0=pyhd3eb1b0_1
#     - pysocks==1.7.1=py39h06a4308_0
#     - python==3.9.7=h12debd9_1
#     - readline==8.1.2=h7f8727e_1
#     - requests==2.27.1=pyhd3eb1b0_0
#     - ruamel_yaml==0.15.100=py39h27cfd23_0
#     - setuptools==58.0.4=py39h06a4308_0
#     - six==1.16.0=pyhd3eb1b0_0
#     - sqlite==3.37.0=hc218d9a_0
#     - tk==8.6.11=h1ccaba5_0
#     - tqdm==4.62.3=pyhd3eb1b0_1
#     - tzdata==2021e=hda174b7_0
#     - urllib3==1.26.7=pyhd3eb1b0_0
#     - wheel==0.37.1=pyhd3eb1b0_0
#     - xz==5.2.5=h7b6447c_0
#     - yaml==0.2.5=h7b6447c_0
#     - zlib==1.2.11=h7f8727e_4
#
#
# The following NEW packages will be INSTALLED:
#
#   _libgcc_mutex      pkgs/main/linux-64::_libgcc_mutex-0.1-main
#   _openmp_mutex      pkgs/main/linux-64::_openmp_mutex-4.5-1_gnu
#   brotlipy           pkgs/main/linux-64::brotlipy-0.7.0-py39h27cfd23_1003
#   ca-certificates    pkgs/main/linux-64::ca-certificates-2021.10.26-h06a4308_2
#   certifi            pkgs/main/linux-64::certifi-2021.10.8-py39h06a4308_2
#   cffi               pkgs/main/linux-64::cffi-1.15.0-py39hd667e15_1
#   charset-normalizer pkgs/main/noarch::charset-normalizer-2.0.4-pyhd3eb1b0_0
#   conda              pkgs/main/linux-64::conda-4.11.0-py39h06a4308_0
#   conda-content-tru~ pkgs/main/noarch::conda-content-trust-0.1.1-pyhd3eb1b0_0
#   conda-package-han~ pkgs/main/linux-64::conda-package-handling-1.7.3-py39h27cfd23_1
#   cryptography       pkgs/main/linux-64::cryptography-36.0.0-py39h9ce1e76_0
#   idna               pkgs/main/noarch::idna-3.3-pyhd3eb1b0_0
#   ld_impl_linux-64   pkgs/main/linux-64::ld_impl_linux-64-2.35.1-h7274673_9
#   libffi             pkgs/main/linux-64::libffi-3.3-he6710b0_2
#   libgcc-ng          pkgs/main/linux-64::libgcc-ng-9.3.0-h5101ec6_17
#   libgomp            pkgs/main/linux-64::libgomp-9.3.0-h5101ec6_17
#   libstdcxx-ng       pkgs/main/linux-64::libstdcxx-ng-9.3.0-hd4cf53a_17
#   ncurses            pkgs/main/linux-64::ncurses-6.3-h7f8727e_2
#   openssl            pkgs/main/linux-64::openssl-1.1.1m-h7f8727e_0
#   pip                pkgs/main/linux-64::pip-21.2.4-py39h06a4308_0
#   pycosat            pkgs/main/linux-64::pycosat-0.6.3-py39h27cfd23_0
#   pycparser          pkgs/main/noarch::pycparser-2.21-pyhd3eb1b0_0
#   pyopenssl          pkgs/main/noarch::pyopenssl-21.0.0-pyhd3eb1b0_1
#   pysocks            pkgs/main/linux-64::pysocks-1.7.1-py39h06a4308_0
#   python             pkgs/main/linux-64::python-3.9.7-h12debd9_1
#   readline           pkgs/main/linux-64::readline-8.1.2-h7f8727e_1
#   requests           pkgs/main/noarch::requests-2.27.1-pyhd3eb1b0_0
#   ruamel_yaml        pkgs/main/linux-64::ruamel_yaml-0.15.100-py39h27cfd23_0
#   setuptools         pkgs/main/linux-64::setuptools-58.0.4-py39h06a4308_0
#   six                pkgs/main/noarch::six-1.16.0-pyhd3eb1b0_0
#   sqlite             pkgs/main/linux-64::sqlite-3.37.0-hc218d9a_0
#   tk                 pkgs/main/linux-64::tk-8.6.11-h1ccaba5_0
#   tqdm               pkgs/main/noarch::tqdm-4.62.3-pyhd3eb1b0_1
#   tzdata             pkgs/main/noarch::tzdata-2021e-hda174b7_0
#   urllib3            pkgs/main/noarch::urllib3-1.26.7-pyhd3eb1b0_0
#   wheel              pkgs/main/noarch::wheel-0.37.1-pyhd3eb1b0_0
#   xz                 pkgs/main/linux-64::xz-5.2.5-h7b6447c_0
#   yaml               pkgs/main/linux-64::yaml-0.2.5-h7b6447c_0
#   zlib               pkgs/main/linux-64::zlib-1.2.11-h7f8727e_4
#
#
# done
# done
# installation finished.
# WARNING:
#     You currently have a PYTHONPATH environment variable set. This may cause
#     unexpected behavior when running the Python interpreter in Miniconda3.
#     For best results, please verify that your PYTHONPATH only points to
#     directories of packages that are compatible with the Python interpreter
#     in Miniconda3: /usr/local
# done
# done
#
# ## Package Plan ##
#
#   environment location: /usr/local
#
#   added / updated specs:
#     - psi4
#     - python=3.7
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     ambit-0.5.1                |       hbe8a562_1         488 KB  psi4
#     attrs-21.4.0               |     pyhd3eb1b0_0          51 KB
#     blas-1.0                   |              mkl           6 KB
#     brotlipy-0.7.0             |py37h27cfd23_1003         320 KB
#     ca-certificates-2022.3.29  |       h06a4308_0         117 KB
#     certifi-2021.10.8          |   py37h06a4308_2         151 KB
#     cffi-1.15.0                |   py37hd667e15_1         222 KB
#     chemps2-1.8.10             |       hbe8a562_0         2.4 MB  psi4
#     conda-4.12.0               |   py37h06a4308_0        14.5 MB
#     conda-package-handling-1.8.1|   py37h7f8727e_0         889 KB
#     cryptography-36.0.0        |   py37h9ce1e76_0         1.3 MB
#     decorator-5.1.1            |     pyhd3eb1b0_0          12 KB
#     dftd3-3.2.1                |       h84218bc_2         2.0 MB  psi4
#     dkh-1.2                    |       h173d85e_2         407 KB  psi4
#     gau2grid-2.0.7             |       hd18ef5c_0         1.2 MB  psi4
#     gcp-2.0.2                  |       he991be0_2         605 KB  psi4
#     gdma-2.2.6                 |       h0e1e685_6         762 KB  psi4
#     hdf5-1.10.6                |       hb1b8bf9_0         3.7 MB
#     importlib-metadata-4.11.3  |   py37h06a4308_0          40 KB
#     importlib_metadata-4.11.3  |       hd3eb1b0_0          12 KB
#     importlib_resources-5.2.0  |     pyhd3eb1b0_1          21 KB
#     iniconfig-1.1.1            |     pyhd3eb1b0_0           8 KB
#     intel-openmp-2021.4.0      |    h06a4308_3561         4.2 MB
#     libgfortran-ng-7.5.0       |      ha8ba4b0_17          22 KB
#     libgfortran4-7.5.0         |      ha8ba4b0_17         995 KB
#     libint2-2.6.0              |       hc9558a2_9       361.9 MB  psi4
#     libxc-5.1.5                |       h84b9e52_1         7.1 MB  psi4
#     mkl-2021.4.0               |     h06a4308_640       142.6 MB
#     mkl-service-2.4.0          |   py37h7f8727e_0          56 KB
#     mkl_fft-1.3.1              |   py37hd3c417c_0         172 KB
#     mkl_random-1.2.2           |   py37h51133e4_0         287 KB
#     networkx-2.2               |           py37_1         1.6 MB
#     numpy-1.21.5               |   py37he7a7128_1          24 KB
#     numpy-base-1.21.5          |   py37hf524024_1         4.8 MB
#     openssl-1.1.1n             |       h7f8727e_0         2.5 MB
#     packaging-21.3             |     pyhd3eb1b0_0          36 KB
#     pcmsolver-1.2.1.1          |   py37h6d17ec8_2         2.3 MB  psi4
#     pint-0.17                  |     pyhd8ed1ab_0         168 KB  psi4
#     pip-21.2.2                 |   py37h06a4308_0         1.8 MB
#     pluggy-1.0.0               |   py37h06a4308_1          29 KB
#     psi4-1.5+e9f4d6d           |   py37hbf93d9d_0        37.7 MB  psi4
#     psutil-5.8.0               |   py37h27cfd23_1         329 KB
#     py-1.11.0                  |     pyhd3eb1b0_0          76 KB
#     py-cpuinfo-8.0.0           |     pyhd3eb1b0_1          23 KB
#     pycosat-0.6.3              |   py37h27cfd23_0          81 KB
#     pydantic-1.9.0             |   py37h7f8727e_0         1.8 MB
#     pyparsing-3.0.4            |     pyhd3eb1b0_0          81 KB
#     pysocks-1.7.1              |           py37_1          27 KB
#     pytest-7.1.1               |   py37h06a4308_0         454 KB
#     python-3.7.11              |       h12debd9_0        45.3 MB
#     pyyaml-6.0                 |   py37h7f8727e_1         168 KB
#     qcelemental-0.24.0         |     pyhd8ed1ab_0         240 KB  psi4
#     qcengine-0.23.0            |     pyhd8ed1ab_0         195 KB  psi4
#     ruamel_yaml-0.15.100       |   py37h27cfd23_0         253 KB
#     setuptools-61.2.0          |   py37h06a4308_0        1007 KB
#     simint-0.7                 |       h642920c_1         9.6 MB  psi4
#     tomli-1.2.2                |     pyhd3eb1b0_0          17 KB
#     typing-extensions-4.1.1    |       hd3eb1b0_0           8 KB
#     typing_extensions-4.1.1    |     pyh06a4308_0          28 KB
#     zipp-3.7.0                 |     pyhd3eb1b0_0          12 KB
#     ------------------------------------------------------------
#                                            Total:       657.0 MB
#
# The following NEW packages will be INSTALLED:
#
#   ambit              psi4/linux-64::ambit-0.5.1-hbe8a562_1
#   attrs              pkgs/main/noarch::attrs-21.4.0-pyhd3eb1b0_0
#   blas               pkgs/main/linux-64::blas-1.0-mkl
#   chemps2            psi4/linux-64::chemps2-1.8.10-hbe8a562_0
#   decorator          pkgs/main/noarch::decorator-5.1.1-pyhd3eb1b0_0
#   dftd3              psi4/linux-64::dftd3-3.2.1-h84218bc_2
#   dkh                psi4/linux-64::dkh-1.2-h173d85e_2
#   gau2grid           psi4/linux-64::gau2grid-2.0.7-hd18ef5c_0
#   gcp                psi4/linux-64::gcp-2.0.2-he991be0_2
#   gdma               psi4/linux-64::gdma-2.2.6-h0e1e685_6
#   hdf5               pkgs/main/linux-64::hdf5-1.10.6-hb1b8bf9_0
#   importlib-metadata pkgs/main/linux-64::importlib-metadata-4.11.3-py37h06a4308_0
#   importlib_metadata pkgs/main/noarch::importlib_metadata-4.11.3-hd3eb1b0_0
#   importlib_resourc~ pkgs/main/noarch::importlib_resources-5.2.0-pyhd3eb1b0_1
#   iniconfig          pkgs/main/noarch::iniconfig-1.1.1-pyhd3eb1b0_0
#   intel-openmp       pkgs/main/linux-64::intel-openmp-2021.4.0-h06a4308_3561
#   libgfortran-ng     pkgs/main/linux-64::libgfortran-ng-7.5.0-ha8ba4b0_17
#   libgfortran4       pkgs/main/linux-64::libgfortran4-7.5.0-ha8ba4b0_17
#   libint2            psi4/linux-64::libint2-2.6.0-hc9558a2_9
#   libxc              psi4/linux-64::libxc-5.1.5-h84b9e52_1
#   mkl                pkgs/main/linux-64::mkl-2021.4.0-h06a4308_640
#   mkl-service        pkgs/main/linux-64::mkl-service-2.4.0-py37h7f8727e_0
#   mkl_fft            pkgs/main/linux-64::mkl_fft-1.3.1-py37hd3c417c_0
#   mkl_random         pkgs/main/linux-64::mkl_random-1.2.2-py37h51133e4_0
#   networkx           pkgs/main/linux-64::networkx-2.2-py37_1
#   numpy              pkgs/main/linux-64::numpy-1.21.5-py37he7a7128_1
#   numpy-base         pkgs/main/linux-64::numpy-base-1.21.5-py37hf524024_1
#   packaging          pkgs/main/noarch::packaging-21.3-pyhd3eb1b0_0
#   pcmsolver          psi4/linux-64::pcmsolver-1.2.1.1-py37h6d17ec8_2
#   pint               psi4/noarch::pint-0.17-pyhd8ed1ab_0
#   pluggy             pkgs/main/linux-64::pluggy-1.0.0-py37h06a4308_1
#   psi4               psi4/linux-64::psi4-1.5+e9f4d6d-py37hbf93d9d_0
#   psutil             pkgs/main/linux-64::psutil-5.8.0-py37h27cfd23_1
#   py                 pkgs/main/noarch::py-1.11.0-pyhd3eb1b0_0
#   py-cpuinfo         pkgs/main/noarch::py-cpuinfo-8.0.0-pyhd3eb1b0_1
#   pydantic           pkgs/main/linux-64::pydantic-1.9.0-py37h7f8727e_0
#   pyparsing          pkgs/main/noarch::pyparsing-3.0.4-pyhd3eb1b0_0
#   pytest             pkgs/main/linux-64::pytest-7.1.1-py37h06a4308_0
#   pyyaml             pkgs/main/linux-64::pyyaml-6.0-py37h7f8727e_1
#   qcelemental        psi4/noarch::qcelemental-0.24.0-pyhd8ed1ab_0
#   qcengine           psi4/noarch::qcengine-0.23.0-pyhd8ed1ab_0
#   simint             psi4/linux-64::simint-0.7-h642920c_1
#   tomli              pkgs/main/noarch::tomli-1.2.2-pyhd3eb1b0_0
#   typing-extensions  pkgs/main/noarch::typing-extensions-4.1.1-hd3eb1b0_0
#   typing_extensions  pkgs/main/noarch::typing_extensions-4.1.1-pyh06a4308_0
#   zipp               pkgs/main/noarch::zipp-3.7.0-pyhd3eb1b0_0
#
# The following packages will be UPDATED:
#
#   ca-certificates                     2021.10.26-h06a4308_2 --> 2022.3.29-h06a4308_0
#   conda                               4.11.0-py39h06a4308_0 --> 4.12.0-py37h06a4308_0
#   conda-package-han~                   1.7.3-py39h27cfd23_1 --> 1.8.1-py37h7f8727e_0
#   openssl                                 1.1.1m-h7f8727e_0 --> 1.1.1n-h7f8727e_0
#   pysocks                              1.7.1-py39h06a4308_0 --> 1.7.1-py37_1
#   setuptools                          58.0.4-py39h06a4308_0 --> 61.2.0-py37h06a4308_0
#
# The following packages will be DOWNGRADED:
#
#   brotlipy                          0.7.0-py39h27cfd23_1003 --> 0.7.0-py37h27cfd23_1003
#   certifi                          2021.10.8-py39h06a4308_2 --> 2021.10.8-py37h06a4308_2
#   cffi                                1.15.0-py39hd667e15_1 --> 1.15.0-py37hd667e15_1
#   cryptography                        36.0.0-py39h9ce1e76_0 --> 36.0.0-py37h9ce1e76_0
#   pip                                 21.2.4-py39h06a4308_0 --> 21.2.2-py37h06a4308_0
#   pycosat                              0.6.3-py39h27cfd23_0 --> 0.6.3-py37h27cfd23_0
#   python                                   3.9.7-h12debd9_1 --> 3.7.11-h12debd9_0
#   ruamel_yaml                       0.15.100-py39h27cfd23_0 --> 0.15.100-py37h27cfd23_0
#
#
#
# Downloading and Extracting Packages
# py-cpuinfo-8.0.0     | 23 KB     | : 100% 1.0/1 [00:00<00:00,  9.02it/s]
# pyparsing-3.0.4      | 81 KB     | : 100% 1.0/1 [00:00<00:00, 11.96it/s]
# pip-21.2.2           | 1.8 MB    | : 100% 1.0/1 [00:00<00:00,  4.07it/s]
# dkh-1.2              | 407 KB    | : 100% 1.0/1 [00:00<00:00,  3.90it/s]
# packaging-21.3       | 36 KB     | : 100% 1.0/1 [00:00<00:00, 17.56it/s]
# libint2-2.6.0        | 361.9 MB  | : 100% 1.0/1 [01:55<00:00, 115.07s/it]
# blas-1.0             | 6 KB      | : 100% 1.0/1 [00:00<00:00, 16.57it/s]
# libxc-5.1.5          | 7.1 MB    | : 100% 1.0/1 [00:01<00:00,  1.95s/it]
# hdf5-1.10.6          | 3.7 MB    | : 100% 1.0/1 [00:00<00:00,  5.51it/s]
# zipp-3.7.0           | 12 KB     | : 100% 1.0/1 [00:00<00:00, 15.69it/s]
# brotlipy-0.7.0       | 320 KB    | : 100% 1.0/1 [00:00<00:00, 16.55it/s]
# typing-extensions-4. | 8 KB      | : 100% 1.0/1 [00:00<00:00, 18.88it/s]
# pint-0.17            | 168 KB    | : 100% 1.0/1 [00:00<00:00,  5.17it/s]
# mkl-service-2.4.0    | 56 KB     | : 100% 1.0/1 [00:00<00:00, 16.88it/s]
# mkl_random-1.2.2     | 287 KB    | : 100% 1.0/1 [00:00<00:00,  7.87it/s]
# chemps2-1.8.10       | 2.4 MB    | : 100% 1.0/1 [00:00<00:00,  1.45it/s]
# setuptools-61.2.0    | 1007 KB   | : 100% 1.0/1 [00:00<00:00,  7.69it/s]
# dftd3-3.2.1          | 2.0 MB    | : 100% 1.0/1 [00:00<00:00,  1.95it/s]
# psutil-5.8.0         | 329 KB    | : 100% 1.0/1 [00:00<00:00, 14.64it/s]
# conda-4.12.0         | 14.5 MB   | : 100% 1.0/1 [00:00<00:00,  1.11it/s]
# gau2grid-2.0.7       | 1.2 MB    | : 100% 1.0/1 [00:00<00:00,  2.30it/s]
# numpy-base-1.21.5    | 4.8 MB    | : 100% 1.0/1 [00:00<00:00,  2.87it/s]
# numpy-1.21.5         | 24 KB     | : 100% 1.0/1 [00:00<00:00, 18.24it/s]
# qcengine-0.23.0      | 195 KB    | : 100% 1.0/1 [00:00<00:00,  4.55it/s]
# pyyaml-6.0           | 168 KB    | : 100% 1.0/1 [00:00<00:00, 14.82it/s]
# libgfortran-ng-7.5.0 | 22 KB     | : 100% 1.0/1 [00:00<00:00, 17.43it/s]
# certifi-2021.10.8    | 151 KB    | : 100% 1.0/1 [00:00<00:00, 15.82it/s]
# ruamel_yaml-0.15.100 | 253 KB    | : 100% 1.0/1 [00:00<00:00, 13.05it/s]
# pycosat-0.6.3        | 81 KB     | : 100% 1.0/1 [00:00<00:00, 15.68it/s]
# simint-0.7           | 9.6 MB    | : 100% 1.0/1 [00:03<00:00,  3.31s/it]
# pcmsolver-1.2.1.1    | 2.3 MB    | : 100% 1.0/1 [00:00<00:00,  1.36it/s]
# importlib_resources- | 21 KB     | : 100% 1.0/1 [00:00<00:00, 13.96it/s]
# gcp-2.0.2            | 605 KB    | : 100% 1.0/1 [00:00<00:00,  3.85it/s]
# decorator-5.1.1      | 12 KB     | : 100% 1.0/1 [00:00<00:00, 13.39it/s]
# pluggy-1.0.0         | 29 KB     | : 100% 1.0/1 [00:00<00:00, 15.99it/s]
# mkl-2021.4.0         | 142.6 MB  | : 100% 1.0/1 [00:06<00:00,  6.30s/it]
# attrs-21.4.0         | 51 KB     | : 100% 1.0/1 [00:00<00:00, 14.64it/s]
# ambit-0.5.1          | 488 KB    | : 100% 1.0/1 [00:00<00:00,  5.43it/s]
# python-3.7.11        | 45.3 MB   | : 100% 1.0/1 [00:02<00:00,  2.10s/it]
# cffi-1.15.0          | 222 KB    | : 100% 1.0/1 [00:00<00:00, 12.38it/s]
# cryptography-36.0.0  | 1.3 MB    | : 100% 1.0/1 [00:00<00:00,  7.31it/s]
# py-1.11.0            | 76 KB     | : 100% 1.0/1 [00:00<00:00, 13.65it/s]
# importlib_metadata-4 | 12 KB     | : 100% 1.0/1 [00:00<00:00, 15.79it/s]
# pysocks-1.7.1        | 27 KB     | : 100% 1.0/1 [00:00<00:00, 15.15it/s]
# mkl_fft-1.3.1        | 172 KB    | : 100% 1.0/1 [00:00<00:00, 15.28it/s]
# pytest-7.1.1         | 454 KB    | : 100% 1.0/1 [00:00<00:00, 11.42it/s]
# tomli-1.2.2          | 17 KB     | : 100% 1.0/1 [00:00<00:00, 14.16it/s]
# iniconfig-1.1.1      | 8 KB      | : 100% 1.0/1 [00:00<00:00, 28.05it/s]
# importlib-metadata-4 | 40 KB     | : 100% 1.0/1 [00:00<00:00, 16.54it/s]
# qcelemental-0.24.0   | 240 KB    | : 100% 1.0/1 [00:00<00:00,  4.89it/s]
# libgfortran4-7.5.0   | 995 KB    | : 100% 1.0/1 [00:00<00:00, 10.82it/s]
# intel-openmp-2021.4. | 4.2 MB    | : 100% 1.0/1 [00:00<00:00,  4.62it/s]
# psi4-1.5+e9f4d6d     | 37.7 MB   | : 100% 1.0/1 [00:13<00:00, 13.59s/it]
# ca-certificates-2022 | 117 KB    | : 100% 1.0/1 [00:00<00:00, 14.25it/s]
# conda-package-handli | 889 KB    | : 100% 1.0/1 [00:00<00:00, 11.87it/s]
# networkx-2.2         | 1.6 MB    | : 100% 1.0/1 [00:00<00:00,  4.30it/s]
# openssl-1.1.1n       | 2.5 MB    | : 100% 1.0/1 [00:00<00:00,  6.19it/s]
# gdma-2.2.6           | 762 KB    | : 100% 1.0/1 [00:00<00:00,  2.77it/s]
# pydantic-1.9.0       | 1.8 MB    | : 100% 1.0/1 [00:00<00:00,  7.12it/s]
# typing_extensions-4. | 28 KB     | : 100% 1.0/1 [00:00<00:00, 14.84it/s]
# done
# done
# done

# %%
# import Psi4
import psi4
# check Psi4 version
print(psi4.__version__)
# Out:
# 1.5

# %%
psi4.core.set_output_file("log.txt")
psi4.set_memory('10GB')
psi4.set_num_threads(2)

mol = psi4.geometry("""
0 1
C       -2.5295313491      0.8991429598     -1.1765163169                 
N       -1.0778562090      0.8875055463     -1.2031327754                 
H       -2.9347230162      0.4921632690     -2.1073005088                 
H       -2.8967971229      1.9215233630     -1.0514664294                 
H       -2.8967966135      0.2967453514     -0.3410424119                 
H       -0.7494018831      1.4269630147     -2.0030136831                 
H       -0.7494013965     -0.0660083151     -1.3502207467                           
""")

#scf_e, wfn = psi4.optimize("B97-D/6-31G(d)", return_wfn = True)
#scf_e, wfn = psi4.optimize("wB97X-D/6-31G(d)", return_wfn = True)
#scf_e, wfn = psi4.optimize("B3LYP-D/6-311G(d)", return_wfn = True)
#scf_e, wfn = psi4.optimize("B3LYP-D2/6-311G(d)", return_wfn = True)
#scf_e, wfn = psi4.optimize("M06/6-31G(d)", return_wfn = True) # metal
scf_e, wfn = psi4.optimize("M06-2X/6-31G(d)", return_wfn = True) # non-metal
# Out:
# Optimizer: Optimization complete!

# %%
#scf_e, wfn = psi4.energy("CCSD/6-31G(d)", return_wfn = True)
scf_e, wfn = psi4.energy("CCSD(T)/cc-pVTZ", return_wfn = True)
# !cat log.txt
# Out:
#   Memory set to   9.313 GiB by Python driver.
#   Threads set to 2 by Python driver.
#
# Scratch directory: /tmp/
#
# Scratch directory: /tmp/
# gradient() will perform analytic gradient computation.
#
# *** tstart() called on 62de2050016d
# *** at Tue Apr 19 10:05:35 2022
#
#    => Loading Basis Set <=
#
#     Name: 6-31G(D)
#     Role: ORBITAL
#     Keyword: BASIS
#     atoms 1   entry C          line   111 file /usr/local/share/psi4/basis/6-31g_d_.gbs
#     atoms 2   entry N          line   128 file /usr/local/share/psi4/basis/6-31g_d_.gbs
#     atoms 3-7 entry H          line    44 file /usr/local/share/psi4/basis/6-31g_d_.gbs
#
#
#          ---------------------------------------------------------
#                                    SCF
#                by Justin Turney, Rob Parrish, Andy Simmonett
#                           and Daniel G. A. Smith
#                               RKS Reference
#                         2 Threads,   9536 MiB Core
#          ---------------------------------------------------------
#
#   ==> Geometry <==
#
#     Molecular point group: c1
#     Full point group: C1
#
#     Geometry (in Angstrom), charge = 0, multiplicity = 1:
#
#        Center              X                  Y                   Z               Mass
#     ------------   -----------------  -----------------  -----------------  -----------------
#          C           -0.733433600721     0.019025973530     0.043513938051    12.000000000000
#          N            0.718241539379     0.007388560030     0.016897479551    14.003074004430
#          H           -1.138625267821    -0.387953717270    -0.887270253849     1.007825032230
#          H           -1.100699374521     1.041406376730     0.168563825551     1.007825032230
#          H           -1.100698865121    -0.583371634870     0.878987843051     1.007825032230
#          H            1.046695865279     0.546846028430    -0.782983428149     1.007825032230
#          H            1.046696351879    -0.946125301370    -0.130190491749     1.007825032230
#
#   Running in c1 symmetry.
#
#   Rotational constants: A =      3.41188  B =      0.77428  C =      0.74341 [cm^-1]
#   Rotational constants: A = 102285.69551  B =  23212.36208  C =  22286.74892 [MHz]
#   Nuclear repulsion =   42.168225200750932
#
#   Charge       = 0
#   Multiplicity = 1
#   Electrons    = 18
#   Nalpha       = 9
#   Nbeta        = 9
#
#   ==> Algorithm <==
#
#   SCF Algorithm Type is DF.
#   DIIS enabled.
#   MOM disabled.
#   Fractional occupation disabled.
#   Guess Type is SAD.
#   Energy threshold   = 1.00e-08
#   Density threshold  = 1.00e-08
#   Integral threshold = 1.00e-12
#
#   ==> Primary Basis <==
#
#   Basis Set: 6-31G(D)
#     Blend: 6-31G(D)
#     Number of shells: 22
#     Number of basis functions: 40
#     Number of Cartesian functions: 40
#     Spherical Harmonics?: false
#     Max angular momentum: 2
#
#   ==> DFT Potential <==
#
#    => Composite Functional: M06-2X <=
#
#     Hybrid M06-2X Meta-GGA XC Functional
# (10.1007/s00214-007-0310-x)
#     Y. Zhao and D. G. Truhlar,  Theor. Chem. Acc., 120, 215, 2008
#
#
#     Deriv               =              1
#     GGA                 =           TRUE
#     Meta                =           TRUE
#
#     Exchange Hybrid     =           TRUE
#     MP2 Hybrid          =          FALSE
#
#    => Exchange Functionals <=
#
#     1.0000   XC_HYB_MGGA_X_M06_2X
#
#    => Exact (HF) Exchange <=
#
#     0.5400               HF
#
#    => Correlation Functionals <=
#
#     1.0000   XC_MGGA_C_M06_2X
#
#    => LibXC Density Thresholds  <==
#
#     XC_MGGA_C_M06_2X:  1.00E-12
#     XC_HYB_MGGA_X_M06_2X:  1.00E-15
#
#    => Molecular Quadrature <=
#
#     Radial Scheme          =       TREUTLER
#     Pruning Scheme         =           NONE
#     Nuclear Scheme         =       TREUTLER
#
#     BS radius alpha        =              1
#     Pruning alpha          =              1
#     Radial Points          =             75
#     Spherical Points       =            302
#     Total Points           =         151391
#     Total Blocks           =           1190
#     Max Points             =            256
#     Max Functions          =             40
#     Weights Tolerance      =       1.00E-15
#
#    => Loading Basis Set <=
#
#     Name: (6-31G(D) AUX)
#     Role: JKFIT
#     Keyword: DF_BASIS_SCF
#     atoms 1   entry C          line   121 file /usr/local/share/psi4/basis/cc-pvdz-jkfit.gbs
#     atoms 2   entry N          line   171 file /usr/local/share/psi4/basis/cc-pvdz-jkfit.gbs
#     atoms 3-7 entry H          line    51 file /usr/local/share/psi4/basis/cc-pvdz-jkfit.gbs
#
#   ==> Integral Setup <==
#
#   DFHelper Memory: AOs need 0.004 GiB; user supplied 6.560 GiB. Using in-core AOs.
#
#   ==> MemDFJK: Density-Fitted J/K Matrices <==
#
#     J tasked:                   Yes
#     K tasked:                   Yes
#     wK tasked:                   No
#     OpenMP threads:               2
#     Memory [MiB]:              6717
#     Algorithm:                 Core
#     Schwarz Cutoff:           1E-12
#     Mask sparsity (%):       0.0000
#     Fitting Condition:        1E-10
#
#    => Auxiliary Basis Set <=
#
#   Basis Set: (6-31G(D) AUX)
#     Blend: CC-PVDZ-JKFIT
#     Number of shells: 93
#     Number of basis functions: 287
#     Number of Cartesian functions: 287
#     Spherical Harmonics?: false
#     Max angular momentum: 3
#
#   Cached 100.0% of DFT collocation blocks in 0.425 [GiB].
#
#   Minimum eigenvalue in the overlap matrix is 8.8496634098E-03.
#   Reciprocal condition number of the overlap matrix is 1.4023542148E-03.
#     Using symmetric orthogonalization.
#
#   ==> Pre-Iterations <==
#
#   SCF Guess: Superposition of Atomic Densities via on-the-fly atomic UHF (no occupation information).
#
#    -------------------------
#     Irrep   Nso     Nmo
#    -------------------------
#      A         40      40
#    -------------------------
#     Total      40      40
#    -------------------------
#
#   ==> Iterations <==
#
#                            Total Energy        Delta E     RMS |[F,P]|
#
#    @DF-RKS iter SAD:   -95.34685681202767   -9.53469e+01   0.00000e+00
#    @DF-RKS iter   1:   -95.64226447179425   -2.95408e-01   1.41378e-02 DIIS
#    @DF-RKS iter   2:   -95.66574405263572   -2.34796e-02   1.34363e-02 DIIS
#    @DF-RKS iter   3:   -95.79392634368186   -1.28182e-01   8.19088e-04 DIIS
#    @DF-RKS iter   4:   -95.79432420678793   -3.97863e-04   3.60331e-04 DIIS
#    @DF-RKS iter   5:   -95.79441915832824   -9.49515e-05   6.91052e-05 DIIS
#    @DF-RKS iter   6:   -95.79442297483261   -3.81650e-06   8.45308e-06 DIIS
#    @DF-RKS iter   7:   -95.79442306326061   -8.84280e-08   1.18718e-06 DIIS
#    @DF-RKS iter   8:   -95.79442306664298   -3.38237e-09   2.80296e-07 DIIS
#    @DF-RKS iter   9:   -95.79442306687601   -2.33030e-10   7.73079e-08 DIIS
#    @DF-RKS iter  10:   -95.79442306688888   -1.28750e-11   8.47916e-09 DIIS
#   Energy and wave function converged.
#
#
#   ==> Post-Iterations <==
#
#    Electrons on quadrature grid:
#       Ntotal   =   18.0000110658 ; deviation = 1.107e-05
#
#     Orbital Energies [Eh]
#     ---------------------
#
#     Doubly Occupied:
#
#        1A    -14.729042     2A    -10.554626     3A     -0.975207
#        4A     -0.741315     5A     -0.556509     6A     -0.501203
#        7A     -0.466318     8A     -0.426014     9A     -0.291909
#
#     Virtual:
#
#       10A      0.130622    11A      0.193227    12A      0.202284
#       13A      0.226724    14A      0.234075    15A      0.289666
#       16A      0.606387    17A      0.615782    18A      0.635279
#       19A      0.801773    20A      0.803421    21A      0.853441
#       22A      0.935700    23A      0.987350    24A      0.993964
#       25A      0.996405    26A      1.045383    27A      1.109889
#       28A      1.415981    29A      1.584605    30A      1.601399
#       31A      1.973585    32A      2.101374    33A      2.109987
#       34A      2.263468    35A      2.381072    36A      2.397669
#       37A      2.505565    38A      2.693617    39A      3.799438
#       40A      4.284101
#
#     Final Occupation by Irrep:
#               A
#     DOCC [     9 ]
#
#   @DF-RKS Final Energy:   -95.79442306688888
#
#    => Energetics <=
#
#     Nuclear Repulsion Energy =             42.1682252007509319
#     One-Electron Energy =                -211.8209315839549447
#     Two-Electron Energy =                  80.6880499612977076
#     DFT Exchange-Correlation Energy =      -6.8297666449825698
#     Empirical Dispersion Energy =           0.0000000000000000
#     VV10 Nonlocal Energy =                  0.0000000000000000
#     Total Energy =                        -95.7944230668888821
#
# Computation Completed
#
#
# Properties will be evaluated at   0.000000,   0.000000,   0.000000 [a0]
#
# Properties computed using the SCF density matrix
#
#   Nuclear Dipole Moment: [e a0]
#      X:    -1.1708      Y:    -0.3086      Z:    -0.7059
#
#   Electronic Dipole Moment: [e a0]
#      X:     0.9983      Y:     0.0746      Z:     0.1707
#
#   Dipole Moment: [e a0]
#      X:    -0.1725      Y:    -0.2340      Z:    -0.5352     Total:     0.6091
#
#   Dipole Moment: [D]
#      X:    -0.4385      Y:    -0.5948      Z:    -1.3603     Total:     1.5481
#
#
# *** tstop() called on 62de2050016d at Tue Apr 19 10:05:42 2022
# Module time:
# 	user time   =      12.05 seconds =       0.20 minutes
# 	system time =       1.42 seconds =       0.02 minutes
# 	total time  =          7 seconds =       0.12 minutes
# Total time:
# 	user time   =     206.70 seconds =       3.44 minutes
# 	system time =      45.74 seconds =       0.76 minutes
# 	total time  =       1151 seconds =      19.18 minutes
#
# *** tstart() called on 62de2050016d
# *** at Tue Apr 19 10:05:42 2022
#
#
#          ------------------------------------------------------------
#                                    SCF GRAD
#                           Rob Parrish, Justin Turney,
#                        Andy Simmonett, and Alex Sokolov
#          ------------------------------------------------------------
#
#   ==> Geometry <==
#
#     Molecular point group: c1
#     Full point group: C1
#
#     Geometry (in Angstrom), charge = 0, multiplicity = 1:
#
#        Center              X                  Y                   Z               Mass
#     ------------   -----------------  -----------------  -----------------  -----------------
#          C           -0.733433600721     0.019025973530     0.043513938051    12.000000000000
#          N            0.718241539379     0.007388560030     0.016897479551    14.003074004430
#          H           -1.138625267821    -0.387953717270    -0.887270253849     1.007825032230
#          H           -1.100699374521     1.041406376730     0.168563825551     1.007825032230
#          H           -1.100698865121    -0.583371634870     0.878987843051     1.007825032230
#          H            1.046695865279     0.546846028430    -0.782983428149     1.007825032230
#          H            1.046696351879    -0.946125301370    -0.130190491749     1.007825032230
#
#   Nuclear repulsion =   42.168225200750932
#
#   ==> Basis Set <==
#
#   Basis Set: 6-31G(D)
#     Blend: 6-31G(D)
#     Number of shells: 22
#     Number of basis functions: 40
#     Number of Cartesian functions: 40
#     Spherical Harmonics?: false
#     Max angular momentum: 2
#
#   ==> DFJKGrad: Density-Fitted SCF Gradients <==
#
#     Gradient:                    1
#     J tasked:                  Yes
#     K tasked:                  Yes
#     wK tasked:                  No
#     OpenMP threads:              2
#     Integrals threads:           2
#     Memory [MiB]:             7152
#     Schwarz Cutoff:          1E-12
#     Fitting Condition:       1E-10
#
#    => Auxiliary Basis Set <=
#
#   Basis Set: (6-31G(D) AUX)
#     Blend: CC-PVDZ-JKFIT
#     Number of shells: 93
#     Number of basis functions: 287
#     Number of Cartesian functions: 287
#     Spherical Harmonics?: false
#     Max angular momentum: 3
#
#   ==> DFT Potential <==
#
#    => Composite Functional: M06-2X <=
#
#     Hybrid M06-2X Meta-GGA XC Functional
# (10.1007/s00214-007-0310-x)
#     Y. Zhao and D. G. Truhlar,  Theor. Chem. Acc., 120, 215, 2008
#
#
#     Deriv               =              1
#     GGA                 =           TRUE
#     Meta                =           TRUE
#
#     Exchange Hybrid     =           TRUE
#     MP2 Hybrid          =          FALSE
#
#    => Exchange Functionals <=
#
#     1.0000   XC_HYB_MGGA_X_M06_2X
#
#    => Exact (HF) Exchange <=
#
#     0.5400               HF
#
#    => Correlation Functionals <=
#
#     1.0000   XC_MGGA_C_M06_2X
#
#    => LibXC Density Thresholds  <==
#
#     XC_MGGA_C_M06_2X:  1.00E-12
#     XC_HYB_MGGA_X_M06_2X:  1.00E-15
#
#    => Molecular Quadrature <=
#
#     Radial Scheme          =       TREUTLER
#     Pruning Scheme         =           NONE
#     Nuclear Scheme         =       TREUTLER
#
#     BS radius alpha        =              1
#     Pruning alpha          =              1
#     Radial Points          =             75
#     Spherical Points       =            302
#     Total Points           =         151391
#     Total Blocks           =           1190
#     Max Points             =            256
#     Max Functions          =             40
#     Weights Tolerance      =       1.00E-15
#
#
#   -Total Gradient:
#      Atom            X                  Y                   Z
#     ------   -----------------  -----------------  -----------------
#        1        0.000205870065     0.002864125724     0.006550420961
#        2       -0.010115106544    -0.001955446333    -0.004472253709
#        3        0.010522473344     0.000447577665     0.001023622420
#        4       -0.000636603793     0.000534233058    -0.000746608728
#        5       -0.000636605022    -0.000910856280    -0.000114754425
#        6        0.000448571677     0.001503623317    -0.001903907675
#        7        0.000448578760    -0.002418709175    -0.000188899106
#
#
# *** tstop() called on 62de2050016d at Tue Apr 19 10:05:43 2022
# Module time:
# 	user time   =       2.02 seconds =       0.03 minutes
# 	system time =       0.05 seconds =       0.00 minutes
# 	total time  =          1 seconds =       0.02 minutes
# Total time:
# 	user time   =     208.73 seconds =       3.48 minutes
# 	system time =      45.79 seconds =       0.76 minutes
# 	total time  =       1152 seconds =      19.20 minutes
#
# 			-----------------------------------------
# 			 OPTKING 2.0: for geometry optimizations
# 			  - R.A. King,  Bethel University
# 			-----------------------------------------
#
# 	Internal coordinates to be generated automatically.
# 	Detected frag 1 with atoms:  1 2 3 4 5 6 7
# 	---Fragment 1 Bond Connectivity---
# 	 1 : 2 3 4 5
# 	 2 : 1 6 7
# 	 3 : 1
# 	 4 : 1
# 	 5 : 1
# 	 6 : 2
# 	 7 : 2
#
# 	---Fragment 1 Geometry and Gradient---
# 	 C          -1.3859886366        0.0359538792        0.0822294256
# 	 N           1.3572798014        0.0139623549        0.0319316086
# 	 H          -2.1516899157       -0.7331262750       -1.6766977790
# 	 H          -2.0800203643        1.9679728373        0.3185394650
# 	 H          -2.0800194017       -1.1024126193        1.6610462910
# 	 H           1.9779685220        1.0333892265       -1.4796242400
# 	 H           1.9779694416       -1.7879177000       -0.2460243735
# 	             0.0002058701        0.0028641257        0.0065504210
# 	            -0.0101151065       -0.0019554463       -0.0044722537
# 	             0.0105224733        0.0004475777        0.0010236224
# 	            -0.0006366038        0.0005342331       -0.0007466087
# 	            -0.0006366050       -0.0009108563       -0.0001147544
# 	             0.0004485717        0.0015036233       -0.0019039077
# 	             0.0004485788       -0.0024187092       -0.0001888991
#
# 	Previous optimization step data not found.  Starting new optimization.
#
# 	---Fragment 1 Intrafragment Coordinates---
# 	 - Coordinate -           - BOHR/RAD -       - ANG/DEG -
# 	 R(1,2)           =         2.743818	       1.451966
# 	 R(1,3)           =         2.066787	       1.093696
# 	 R(1,4)           =         2.066451	       1.093519
# 	 R(1,5)           =         2.066451	       1.093519
# 	 R(2,6)           =         1.925951	       1.019169
# 	 R(2,7)           =         1.925951	       1.019169
# 	 B(1,2,6)         =         1.909598	     109.411880
# 	 B(1,2,7)         =         1.909598	     109.411879
# 	 B(2,1,3)         =         1.930313	     110.598778
# 	 B(2,1,4)         =         1.923439	     110.204960
# 	 B(2,1,5)         =         1.923439	     110.204961
# 	 B(3,1,4)         =         1.897370	     108.711306
# 	 B(3,1,5)         =         1.897370	     108.711306
# 	 B(4,1,5)         =         1.891119	     108.353135
# 	 B(6,2,7)         =         1.852593	     106.145734
# 	 D(3,1,2,6)       =         1.011412	      57.949630
# 	 D(3,1,2,7)       =        -1.011413	     -57.949668
# 	 D(4,1,2,6)       =        -1.087036	     -62.282580
# 	 D(4,1,2,7)       =        -3.109860	    -178.181878
# 	 D(5,1,2,6)       =         3.109860	     178.181841
# 	 D(5,1,2,7)       =         1.087035	      62.282543
#
# 	Current energy   :       -95.7944230669
#
# 	Generating empirical Hessian (Schlegel '84) for each fragment.
# 	Taking RFO optimization step.
# 	Going to follow RFO solution 1.
# 	Using RFO vector 1.
# 	Norm of target step-size    0.13283
# 	Projected energy change by RFO approximation:        -0.0059850602
#
# 	Back-transformation to cartesian coordinates...
# 	Successfully converged to displaced geometry.
#
# 	--- Internal Coordinate Step in ANG or DEG, aJ/ANG or AJ/DEG ---
# 	 ---------------------------------------------------------------------------
# 	   Coordinate                Previous        Force       Change         New
# 	   ----------                --------       ------       ------       ------
# 	    1 R(1,2)          =      1.451966     0.075666     0.012711     1.464677
# 	    2 R(1,3)          =      1.093696     0.040477     0.007507     1.101203
# 	    3 R(1,4)          =      1.093519    -0.005210    -0.000966     1.092553
# 	    4 R(1,5)          =      1.093519    -0.005210    -0.000966     1.092553
# 	    5 R(2,6)          =      1.019169    -0.020143    -0.002893     1.016276
# 	    6 R(2,7)          =      1.019169    -0.020144    -0.002893     1.016276
# 	    7 B(1,2,6)        =    109.411880     0.000043     0.222864   109.634744
# 	    8 B(1,2,7)        =    109.411879     0.000043     0.222864   109.634744
# 	    9 B(2,1,3)        =    110.598778     0.001138     6.080291   116.679069
# 	   10 B(2,1,4)        =    110.204960    -0.000251    -1.303937   108.901023
# 	   11 B(2,1,5)        =    110.204961    -0.000251    -1.303939   108.901022
# 	   12 B(3,1,4)        =    108.711306    -0.000316    -1.104870   107.606435
# 	   13 B(3,1,5)        =    108.711306    -0.000316    -1.104870   107.606435
# 	   14 B(4,1,5)        =    108.353135    -0.000028    -1.641899   106.711235
# 	   15 B(6,2,7)        =    106.145734    -0.000035    -0.134540   106.011193
# 	   16 D(3,1,2,6)      =     57.949630     0.000001     0.045412    57.995042
# 	   17 D(3,1,2,7)      =    -57.949668    -0.000001    -0.045399   -57.995067
# 	   18 D(4,1,2,6)      =    -62.282580    -0.000040    -1.718446   -64.001026
# 	   19 D(4,1,2,7)      =   -178.181878    -0.000041    -1.809257  -179.991135
# 	   20 D(5,1,2,6)      =    178.181841     0.000041     1.809269   179.991110
# 	   21 D(5,1,2,7)      =     62.282543     0.000040     1.718458    64.001001
# 	 ---------------------------------------------------------------------------
# 	Successfully symmetrized geometry.
#
#   ==> Convergence Check <==
#
#   Measures of convergence in internal coordinates in au.
#   Criteria marked as inactive (o), active & met (*), and active & unmet ( ).
#   --------------------------------------------------------------------------------------------- ~
#    Step     Total Energy     Delta E     MAX Force     RMS Force      MAX Disp      RMS Disp    ~
#   --------------------------------------------------------------------------------------------- ~
#     Convergence Criteria    1.00e-06 *    3.00e-04 *             o    1.20e-03 *             o  ~
#   --------------------------------------------------------------------------------------------- ~
#       1     -95.79442307   -9.58e+01      1.50e-02      4.49e-03 o    1.06e-01      2.97e-02 o  ~
#   ---------------------------------------------------------------------------------------------
#
# 	Writing optimization data to binary file.
# 	Structure for next step:
# 	Cartesian Geometry (in Angstrom)
# 	    C    -0.7243463668   0.0225992007   0.0516861326
# 	    N     0.7372951484  -0.0151597991  -0.0346717942
# 	    H    -1.2810717484  -0.3580348649  -0.8188441092
# 	    H    -1.0422849106   1.0538772224   0.2221361410
# 	    H    -1.0422843868  -0.5525101651   0.9245189384
# 	    H     1.0454342138   0.5169314432  -0.8438355245
# 	    H     1.0454347037  -0.9704867509  -0.1934708689
# 			--------------------------
# 			 OPTKING Finished Execution
# 			--------------------------
#
#     Structure for next step:
#     Molecular point group: c1
#     Full point group: C1
#
#     Geometry (in Angstrom), charge = 0, multiplicity = 1:
#
#     C           -0.735540643016     0.030773364002     0.070380857225
#     N            0.726100877864    -0.006985635950    -0.015977069925
#     H           -1.292266026897    -0.349860703096    -0.800149387931
#     H           -1.053479188094     1.062051389754     0.240830866293
#     H           -1.053478664302    -0.544336004057     0.943213666463
#     H            1.034239944448     0.525105608464    -0.825140803328
#     H            1.034240434420    -0.962312591480    -0.174776145193
#
#
# Scratch directory: /tmp/
#
# Scratch directory: /tmp/
# gradient() will perform analytic gradient computation.
#
# *** tstart() called on 62de2050016d
# *** at Tue Apr 19 10:05:44 2022
#
#    => Loading Basis Set <=
#
#     Name: 6-31G(D)
#     Role: ORBITAL
#     Keyword: BASIS
#     atoms 1   entry C          line   111 file /usr/local/share/psi4/basis/6-31g_d_.gbs
#     atoms 2   entry N          line   128 file /usr/local/share/psi4/basis/6-31g_d_.gbs
#     atoms 3-7 entry H          line    44 file /usr/local/share/psi4/basis/6-31g_d_.gbs
#
#
#          ---------------------------------------------------------
#                                    SCF
#                by Justin Turney, Rob Parrish, Andy Simmonett
#                           and Daniel G. A. Smith
#                               RKS Reference
#                         2 Threads,   9536 MiB Core
#          ---------------------------------------------------------
#
#   ==> Geometry <==
#
#     Molecular point group: c1
#     Full point group: C1
#
#     Geometry (in Angstrom), charge = 0, multiplicity = 1:
#
#        Center              X                  Y                   Z               Mass
#     ------------   -----------------  -----------------  -----------------  -----------------
#          C           -0.735540643016     0.030773364002     0.070380857225    12.000000000000
#          N            0.726100877864    -0.006985635950    -0.015977069925    14.003074004430
#          H           -1.292266026897    -0.349860703096    -0.800149387931     1.007825032230
#          H           -1.053479188094     1.062051389754     0.240830866293     1.007825032230
#          H           -1.053478664302    -0.544336004057     0.943213666463     1.007825032230
#          H            1.034239944448     0.525105608464    -0.825140803328     1.007825032230
#          H            1.034240434420    -0.962312591480    -0.174776145193     1.007825032230
#
#   Running in c1 symmetry.
#
#   Rotational constants: A =      3.45036  B =      0.75811  C =      0.72962 [cm^-1]
#   Rotational constants: A = 103439.32527  B =  22727.55677  C =  21873.59041 [MHz]
#   Nuclear repulsion =   41.949170718525259
#
#   Charge       = 0
#   Multiplicity = 1
#   Electrons    = 18
#   Nalpha       = 9
#   Nbeta        = 9
#
#   ==> Algorithm <==
#
#   SCF Algorithm Type is DF.
#   DIIS enabled.
#   MOM disabled.
#   Fractional occupation disabled.
#   Guess Type is READ.
#   Energy threshold   = 1.00e-08
#   Density threshold  = 1.00e-08
#   Integral threshold = 1.00e-12
#
#   ==> Primary Basis <==
#
#   Basis Set: 6-31G(D)
#     Blend: 6-31G(D)
#     Number of shells: 22
#     Number of basis functions: 40
#     Number of Cartesian functions: 40
#     Spherical Harmonics?: false
#     Max angular momentum: 2
#
#   ==> DFT Potential <==
#
#    => Composite Functional: M06-2X <=
#
#     Hybrid M06-2X Meta-GGA XC Functional
# (10.1007/s00214-007-0310-x)
#     Y. Zhao and D. G. Truhlar,  Theor. Chem. Acc., 120, 215, 2008
#
#
#     Deriv               =              1
#     GGA                 =           TRUE
#     Meta                =           TRUE
#
#     Exchange Hybrid     =           TRUE
#     MP2 Hybrid          =          FALSE
#
#    => Exchange Functionals <=
#
#     1.0000   XC_HYB_MGGA_X_M06_2X
#
#    => Exact (HF) Exchange <=
#
#     0.5400               HF
#
#    => Correlation Functionals <=
#
#     1.0000   XC_MGGA_C_M06_2X
#
#    => LibXC Density Thresholds  <==
#
#     XC_MGGA_C_M06_2X:  1.00E-12
#     XC_HYB_MGGA_X_M06_2X:  1.00E-15
#
#    => Molecular Quadrature <=
#
#     Radial Scheme          =       TREUTLER
#     Pruning Scheme         =           NONE
#     Nuclear Scheme         =       TREUTLER
#
#     BS radius alpha        =              1
#     Pruning alpha          =              1
#     Radial Points          =             75
#     Spherical Points       =            302
#     Total Points           =         151417
#     Total Blocks           =           1196
#     Max Points             =            256
#     Max Functions          =             40
#     Weights Tolerance      =       1.00E-15
#
#    => Loading Basis Set <=
#
#     Name: (6-31G(D) AUX)
#     Role: JKFIT
#     Keyword: DF_BASIS_SCF
#     atoms 1   entry C          line   121 file /usr/local/share/psi4/basis/cc-pvdz-jkfit.gbs
#     atoms 2   entry N          line   171 file /usr/local/share/psi4/basis/cc-pvdz-jkfit.gbs
#     atoms 3-7 entry H          line    51 file /usr/local/share/psi4/basis/cc-pvdz-jkfit.gbs
#
#    => Loading Basis Set <=
#
#     Name: 6-31G(D)
#     Role: ORBITAL
#     Keyword: BASIS
#     atoms 1   entry C          line   111 file /usr/local/share/psi4/basis/6-31g_d_.gbs
#     atoms 2   entry N          line   128 file /usr/local/share/psi4/basis/6-31g_d_.gbs
#     atoms 3-7 entry H          line    44 file /usr/local/share/psi4/basis/6-31g_d_.gbs
#
#   Reading orbitals from file /tmp/log.default.60.180.npy, no projection.
#
#   ==> Integral Setup <==
#
#   DFHelper Memory: AOs need 0.004 GiB; user supplied 6.560 GiB. Using in-core AOs.
#
#   ==> MemDFJK: Density-Fitted J/K Matrices <==
#
#     J tasked:                   Yes
#     K tasked:                   Yes
#     wK tasked:                   No
#     OpenMP threads:               2
#     Memory [MiB]:              6717
#     Algorithm:                 Core
#     Schwarz Cutoff:           1E-12
#     Mask sparsity (%):       0.0000
#     Fitting Condition:        1E-10
#
#    => Auxiliary Basis Set <=
#
#   Basis Set: (6-31G(D) AUX)
#     Blend: CC-PVDZ-JKFIT
#     Number of shells: 93
#     Number of basis functions: 287
#     Number of Cartesian functions: 287
#     Spherical Harmonics?: false
#     Max angular momentum: 3
#
#   Cached 100.0% of DFT collocation blocks in 0.425 [GiB].
#
#   Minimum eigenvalue in the overlap matrix is 9.2841506833E-03.
#   Reciprocal condition number of the overlap matrix is 1.4810612048E-03.
#     Using symmetric orthogonalization.
#
#   ==> Pre-Iterations <==
#
#   SCF Guess: Orbitals guess was supplied from a previous computation.
#
#    -------------------------------------------------------
#     Irrep   Nso     Nmo     Nalpha   Nbeta   Ndocc  Nsocc
#    -------------------------------------------------------
#      A         40      40       9       9       9       0
#    -------------------------------------------------------
#     Total      40      40       9       9       9       0
#    -------------------------------------------------------
#
#   ==> Iterations <==
#
#                            Total Energy        Delta E     RMS |[F,P]|
#
#    @DF-RKS iter   0:   -95.78774112643659   -9.57877e+01   1.81719e-03
#    @DF-RKS iter   1:   -95.79518737659922   -7.44625e-03   3.30433e-04 DIIS
#    @DF-RKS iter   2:   -95.79530534499602   -1.17968e-04   2.08865e-04 DIIS
#    @DF-RKS iter   3:   -95.79533609689301   -3.07519e-05   6.59853e-05 DIIS
#    @DF-RKS iter   4:   -95.79533989065980   -3.79377e-06   1.53961e-05 DIIS
#    @DF-RKS iter   5:   -95.79534008306294   -1.92403e-07   4.58763e-06 DIIS
#    @DF-RKS iter   6:   -95.79534010073529   -1.76723e-08   6.93516e-07 DIIS
#    @DF-RKS iter   7:   -95.79534010203089   -1.29560e-09   1.27960e-07 DIIS
#    @DF-RKS iter   8:   -95.79534010207990   -4.90132e-11   1.69301e-08 DIIS
#    @DF-RKS iter   9:   -95.79534010208056   -6.53699e-13   3.53205e-09 DIIS
#   Energy and wave function converged.
#
#
#   ==> Post-Iterations <==
#
#    Electrons on quadrature grid:
#       Ntotal   =   18.0000160825 ; deviation = 1.608e-05
#
#     Orbital Energies [Eh]
#     ---------------------
#
#     Doubly Occupied:
#
#        1A    -14.731835     2A    -10.555700     3A     -0.972724
#        4A     -0.743630     5A     -0.555522     6A     -0.502753
#        7A     -0.459745     8A     -0.424818     9A     -0.296557
#
#     Virtual:
#
#       10A      0.132604    11A      0.190559    12A      0.204491
#       13A      0.225800    14A      0.232534    15A      0.288138
#       16A      0.604827    17A      0.611502    18A      0.637530
#       19A      0.798763    20A      0.803523    21A      0.862688
#       22A      0.930383    23A      0.984629    24A      0.997183
#       25A      0.998500    26A      1.043083    27A      1.104765
#       28A      1.425189    29A      1.577546    30A      1.609201
#       31A      1.933701    32A      2.088815    33A      2.125001
#       34A      2.225754    35A      2.367962    36A      2.419595
#       37A      2.508716    38A      2.686895    39A      3.793880
#       40A      4.281680
#
#     Final Occupation by Irrep:
#               A
#     DOCC [     9 ]
#
#   @DF-RKS Final Energy:   -95.79534010208056
#
#    => Energetics <=
#
#     Nuclear Repulsion Energy =             41.9491707185252594
#     One-Electron Energy =                -211.3851672952365561
#     Two-Electron Energy =                  80.4670252463160551
#     DFT Exchange-Correlation Energy =      -6.8263687716853250
#     Empirical Dispersion Energy =           0.0000000000000000
#     VV10 Nonlocal Energy =                  0.0000000000000000
#     Total Energy =                        -95.7953401020805586
#
# Computation Completed
#
#
# Properties will be evaluated at   0.000000,   0.000000,   0.000000 [a0]
#
# Properties computed using the SCF density matrix
#
#   Nuclear Dipole Moment: [e a0]
#      X:    -1.2496      Y:    -0.2525      Z:    -0.5775
#
#   Electronic Dipole Moment: [e a0]
#      X:     1.0646      Y:     0.0260      Z:     0.0596
#
#   Dipole Moment: [e a0]
#      X:    -0.1850      Y:    -0.2264      Z:    -0.5179     Total:     0.5947
#
#   Dipole Moment: [D]
#      X:    -0.4703      Y:    -0.5756      Z:    -1.3164     Total:     1.5117
#
#
# *** tstop() called on 62de2050016d at Tue Apr 19 10:05:49 2022
# Module time:
# 	user time   =      10.90 seconds =       0.18 minutes
# 	system time =       0.22 seconds =       0.00 minutes
# 	total time  =          5 seconds =       0.08 minutes
# Total time:
# 	user time   =     219.69 seconds =       3.66 minutes
# 	system time =      46.01 seconds =       0.77 minutes
# 	total time  =       1158 seconds =      19.30 minutes
#
# *** tstart() called on 62de2050016d
# *** at Tue Apr 19 10:05:49 2022
#
#
#          ------------------------------------------------------------
#                                    SCF GRAD
#                           Rob Parrish, Justin Turney,
#                        Andy Simmonett, and Alex Sokolov
#          ------------------------------------------------------------
#
#   ==> Geometry <==
#
#     Molecular point group: c1
#     Full point group: C1
#
#     Geometry (in Angstrom), charge = 0, multiplicity = 1:
#
#        Center              X                  Y                   Z               Mass
#     ------------   -----------------  -----------------  -----------------  -----------------
#          C           -0.735540643016     0.030773364002     0.070380857225    12.000000000000
#          N            0.726100877864    -0.006985635950    -0.015977069925    14.003074004430
#          H           -1.292266026897    -0.349860703096    -0.800149387931     1.007825032230
#          H           -1.053479188094     1.062051389754     0.240830866293     1.007825032230
#          H           -1.053478664302    -0.544336004057     0.943213666463     1.007825032230
#          H            1.034239944448     0.525105608464    -0.825140803328     1.007825032230
#          H            1.034240434420    -0.962312591480    -0.174776145193     1.007825032230
#
#   Nuclear repulsion =   41.949170718525259
#
#   ==> Basis Set <==
#
#   Basis Set: 6-31G(D)
#     Blend: 6-31G(D)
#     Number of shells: 22
#     Number of basis functions: 40
#     Number of Cartesian functions: 40
#     Spherical Harmonics?: false
#     Max angular momentum: 2
#
#   ==> DFJKGrad: Density-Fitted SCF Gradients <==
#
#     Gradient:                    1
#     J tasked:                  Yes
#     K tasked:                  Yes
#     wK tasked:                  No
#     OpenMP threads:              2
#     Integrals threads:           2
#     Memory [MiB]:             7152
#     Schwarz Cutoff:          1E-12
#     Fitting Condition:       1E-10
#
#    => Auxiliary Basis Set <=
#
#   Basis Set: (6-31G(D) AUX)
#     Blend: CC-PVDZ-JKFIT
#     Number of shells: 93
#     Number of basis functions: 287
#     Number of Cartesian functions: 287
#     Spherical Harmonics?: false
#     Max angular momentum: 3
#
#   ==> DFT Potential <==
#
#    => Composite Functional: M06-2X <=
#
#     Hybrid M06-2X Meta-GGA XC Functional
# (10.1007/s00214-007-0310-x)
#     Y. Zhao and D. G. Truhlar,  Theor. Chem. Acc., 120, 215, 2008
#
#
#     Deriv               =              1
#     GGA                 =           TRUE
#     Meta                =           TRUE
#
#     Exchange Hybrid     =           TRUE
#     MP2 Hybrid          =          FALSE
#
#    => Exchange Functionals <=
#
#     1.0000   XC_HYB_MGGA_X_M06_2X
#
#    => Exact (HF) Exchange <=
#
#     0.5400               HF
#
#    => Correlation Functionals <=
#
#     1.0000   XC_MGGA_C_M06_2X
#
#    => LibXC Density Thresholds  <==
#
#     XC_MGGA_C_M06_2X:  1.00E-12
#     XC_HYB_MGGA_X_M06_2X:  1.00E-15
#
#    => Molecular Quadrature <=
#
#     Radial Scheme          =       TREUTLER
#     Pruning Scheme         =           NONE
#     Nuclear Scheme         =       TREUTLER
#
#     BS radius alpha        =              1
#     Pruning alpha          =              1
#     Radial Points          =             75
#     Spherical Points       =            302
#     Total Points           =         151417
#     Total Blocks           =           1196
#     Max Points             =            256
#     Max Functions          =             40
#     Weights Tolerance      =       1.00E-15
#
#
#   -Total Gradient:
#      Atom            X                  Y                   Z
#     ------   -----------------  -----------------  -----------------
#        1       -0.001061969731    -0.000755197895    -0.001727176969
#        2        0.003667878096     0.000332906234     0.000761370384
#        3       -0.002126467677     0.000380911635     0.000871165554
#        4       -0.000169970528    -0.000813245092     0.000191734716
#        5       -0.000169970102     0.000692956012    -0.000466843917
#        6        0.000005478766    -0.000251958180     0.000416057306
#        7        0.000005479418     0.000476522135     0.000097535383
#
#
# *** tstop() called on 62de2050016d at Tue Apr 19 10:05:50 2022
# Module time:
# 	user time   =       2.03 seconds =       0.03 minutes
# 	system time =       0.02 seconds =       0.00 minutes
# 	total time  =          1 seconds =       0.02 minutes
# Total time:
# 	user time   =     221.73 seconds =       3.70 minutes
# 	system time =      46.03 seconds =       0.77 minutes
# 	total time  =       1159 seconds =      19.32 minutes
#
# 			-----------------------------------------
# 			 OPTKING 2.0: for geometry optimizations
# 			  - R.A. King,  Bethel University
# 			-----------------------------------------
#
# 	Previous internal coordinate definitions found.
# 	---Fragment 1 Geometry and Gradient---
# 	 C          -1.3899703694        0.0581532299        0.1330005446
# 	 N           1.3721317986       -0.0132009388       -0.0301922864
# 	 H          -2.4420288721       -0.6611409109       -1.5120632026
# 	 H          -1.9907871444        2.0069862578        0.4551043799
# 	 H          -1.9907861545       -1.0286459679        1.7824155074
# 	 H           1.9544302430        0.9923057869       -1.5592901332
# 	 H           1.9544311689       -1.8185072450       -0.3302790477
# 	            -0.0010619697       -0.0007551979       -0.0017271770
# 	             0.0036678781        0.0003329062        0.0007613704
# 	            -0.0021264677        0.0003809116        0.0008711656
# 	            -0.0001699705       -0.0008132451        0.0001917347
# 	            -0.0001699701        0.0006929560       -0.0004668439
# 	             0.0000054788       -0.0002519582        0.0004160573
# 	             0.0000054794        0.0004765221        0.0000975354
#
# 	---Fragment 1 Intrafragment Coordinates---
# 	 - Coordinate -           - BOHR/RAD -       - ANG/DEG -
# 	 R(1,2)           =         2.767839	       1.464677
# 	 R(1,3)           =         2.080972	       1.101203
# 	 R(1,4)           =         2.064626	       1.092553
# 	 R(1,5)           =         2.064626	       1.092553
# 	 R(2,6)           =         1.920483	       1.016276
# 	 R(2,7)           =         1.920483	       1.016276
# 	 B(1,2,6)         =         1.913487	     109.634744
# 	 B(1,2,7)         =         1.913487	     109.634744
# 	 B(2,1,3)         =         2.036434	     116.679069
# 	 B(2,1,4)         =         1.900681	     108.901023
# 	 B(2,1,5)         =         1.900681	     108.901022
# 	 B(3,1,4)         =         1.878087	     107.606435
# 	 B(3,1,5)         =         1.878087	     107.606435
# 	 B(4,1,5)         =         1.862462	     106.711235
# 	 B(6,2,7)         =         1.850244	     106.011193
# 	 D(3,1,2,6)       =         1.012204	      57.995042
# 	 D(3,1,2,7)       =        -1.012205	     -57.995067
# 	 D(4,1,2,6)       =        -1.117029	     -64.001026
# 	 D(4,1,2,7)       =        -3.141438	    -179.991135
# 	 D(5,1,2,6)       =         3.141437	     179.991110
# 	 D(5,1,2,7)       =         1.117028	      64.001001
#
# 	Current energy   :       -95.7953401021
#
# 	Energy change for the previous step:
# 		Projected    :        -0.0059850602
# 		Actual       :        -0.0009170352
# 	Energy ratio indicates iffy step: Trust radius decreased to 1.250e-01.
#
#
# 	Performing BFGS update.
# 	Previous computed or guess Hessian on step 1.
# 	Steps to be used in Hessian update: 1
# 	Taking RFO optimization step.
# 	Going to follow RFO solution 1.
# 	Using RFO vector 1.
# 	Norm of target step-size    0.02635
# 	Projected energy change by RFO approximation:        -0.0001554100
#
# 	Back-transformation to cartesian coordinates...
# 	Successfully converged to displaced geometry.
#
# 	--- Internal Coordinate Step in ANG or DEG, aJ/ANG or AJ/DEG ---
# 	 ---------------------------------------------------------------------------
# 	   Coordinate                Previous        Force       Change         New
# 	   ----------                --------       ------       ------       ------
# 	    1 R(1,2)          =      1.464677    -0.028906    -0.003902     1.460775
# 	    2 R(1,3)          =      1.101203    -0.002252    -0.000318     1.100885
# 	    3 R(1,4)          =      1.092553     0.005674     0.000850     1.093403
# 	    4 R(1,5)          =      1.092553     0.005674     0.000850     1.093403
# 	    5 R(2,6)          =      1.016276     0.003674     0.000420     1.016696
# 	    6 R(2,7)          =      1.016276     0.003674     0.000420     1.016696
# 	    7 B(1,2,6)        =    109.634744    -0.000013    -0.057219   109.577525
# 	    8 B(1,2,7)        =    109.634744    -0.000013    -0.057220   109.577524
# 	    9 B(2,1,3)        =    116.679069    -0.000263    -1.113882   115.565187
# 	   10 B(2,1,4)        =    108.901023     0.000019     0.090820   108.991843
# 	   11 B(2,1,5)        =    108.901022     0.000019     0.090820   108.991842
# 	   12 B(3,1,4)        =    107.606435     0.000101     0.304387   107.910822
# 	   13 B(3,1,5)        =    107.606435     0.000101     0.304387   107.910822
# 	   14 B(4,1,5)        =    106.711235     0.000049     0.445019   107.156255
# 	   15 B(6,2,7)        =    106.011193     0.000009     0.016418   106.027612
# 	   16 D(3,1,2,6)      =     57.995042    -0.000000    -0.022701    57.972341
# 	   17 D(3,1,2,7)      =    -57.995067     0.000000     0.022713   -57.972354
# 	   18 D(4,1,2,6)      =    -64.001026     0.000009     0.292983   -63.708043
# 	   19 D(4,1,2,7)      =   -179.991135     0.000009     0.338397  -179.652738
# 	   20 D(5,1,2,6)      =    179.991110    -0.000009    -0.338385   179.652725
# 	   21 D(5,1,2,7)      =     64.001001    -0.000009    -0.292971    63.708030
# 	 ---------------------------------------------------------------------------
# 	Successfully symmetrized geometry.
#
#   ==> Convergence Check <==
#
#   Measures of convergence in internal coordinates in au.
#   Criteria marked as inactive (o), active & met (*), and active & unmet ( ).
#   ---------------------------------------------------------------------------------------------
#    Step     Total Energy     Delta E     MAX Force     RMS Force      MAX Disp      RMS Disp
#   ---------------------------------------------------------------------------------------------
#     Convergence Criteria    1.00e-06 *    3.00e-04 *             o    1.20e-03 *             o
#   ---------------------------------------------------------------------------------------------
#       2     -95.79534010   -9.17e-04      3.51e-03      1.21e-03 o    1.94e-02      5.71e-03 o  ~
#   ---------------------------------------------------------------------------------------------
#
# 	Writing optimization data to binary file.
# 	Structure for next step:
# 	Cartesian Geometry (in Angstrom)
# 	    C    -0.7371104536   0.0300148486   0.0686461304
# 	    N     0.7214030170  -0.0025380858  -0.0058052436
# 	    H    -1.2666905442  -0.3566408205  -0.8156558576
# 	    H    -1.0621863729   1.0612701287   0.2310318615
# 	    H    -1.0621858527  -0.5509993340   0.9359865673
# 	    H     1.0332932381   0.5307613460  -0.8132625818
# 	    H     1.0332937080  -0.9574326545  -0.1625588904
# 			--------------------------
# 			 OPTKING Finished Execution
# 			--------------------------
#
#     Structure for next step:
#     Molecular point group: c1
#     Full point group: C1
#
#     Geometry (in Angstrom), charge = 0, multiplicity = 1:
#
#     C           -0.734587906536     0.028421556641     0.065002155705
#     N            0.723925569852    -0.004131377808    -0.009449218633
#     H           -1.264167999152    -0.358234113902    -0.819299835840
#     H           -1.059663827108     1.059676840884     0.227387887435
#     H           -1.059663306867    -0.552592628190     0.932342596025
#     H            1.035815792095     0.529168056010    -0.816906560024
#     H            1.035816262005    -0.959025950251    -0.166202866091
#
#
# Scratch directory: /tmp/
#
# Scratch directory: /tmp/
# gradient() will perform analytic gradient computation.
#
# *** tstart() called on 62de2050016d
# *** at Tue Apr 19 10:05:50 2022
#
#    => Loading Basis Set <=
#
#     Name: 6-31G(D)
#     Role: ORBITAL
#     Keyword: BASIS
#     atoms 1   entry C          line   111 file /usr/local/share/psi4/basis/6-31g_d_.gbs
#     atoms 2   entry N          line   128 file /usr/local/share/psi4/basis/6-31g_d_.gbs
#     atoms 3-7 entry H          line    44 file /usr/local/share/psi4/basis/6-31g_d_.gbs
#
#
#          ---------------------------------------------------------
#                                    SCF
#                by Justin Turney, Rob Parrish, Andy Simmonett
#                           and Daniel G. A. Smith
#                               RKS Reference
#                         2 Threads,   9536 MiB Core
#          ---------------------------------------------------------
#
#   ==> Geometry <==
#
#     Molecular point group: c1
#     Full point group: C1
#
#     Geometry (in Angstrom), charge = 0, multiplicity = 1:
#
#        Center              X                  Y                   Z               Mass
#     ------------   -----------------  -----------------  -----------------  -----------------
#          C           -0.734587906536     0.028421556641     0.065002155705    12.000000000000
#          N            0.723925569852    -0.004131377808    -0.009449218633    14.003074004430
#          H           -1.264167999152    -0.358234113902    -0.819299835840     1.007825032230
#          H           -1.059663827108     1.059676840884     0.227387887435     1.007825032230
#          H           -1.059663306867    -0.552592628190     0.932342596025     1.007825032230
#          H            1.035815792095     0.529168056010    -0.816906560024     1.007825032230
#          H            1.035816262005    -0.959025950251    -0.166202866091     1.007825032230
#
#   Running in c1 symmetry.
#
#   Rotational constants: A =      3.43588  B =      0.76259  C =      0.73362 [cm^-1]
#   Rotational constants: A = 103005.04531  B =  22861.84103  C =  21993.25395 [MHz]
#   Nuclear repulsion =   42.006348211773066
#
#   Charge       = 0
#   Multiplicity = 1
#   Electrons    = 18
#   Nalpha       = 9
#   Nbeta        = 9
#
#   ==> Algorithm <==
#
#   SCF Algorithm Type is DF.
#   DIIS enabled.
#   MOM disabled.
#   Fractional occupation disabled.
#   Guess Type is READ.
#   Energy threshold   = 1.00e-08
#   Density threshold  = 1.00e-08
#   Integral threshold = 1.00e-12
#
#   ==> Primary Basis <==
#
#   Basis Set: 6-31G(D)
#     Blend: 6-31G(D)
#     Number of shells: 22
#     Number of basis functions: 40
#     Number of Cartesian functions: 40
#     Spherical Harmonics?: false
#     Max angular momentum: 2
#
#   ==> DFT Potential <==
#
#    => Composite Functional: M06-2X <=
#
#     Hybrid M06-2X Meta-GGA XC Functional
# (10.1007/s00214-007-0310-x)
#     Y. Zhao and D. G. Truhlar,  Theor. Chem. Acc., 120, 215, 2008
#
#
#     Deriv               =              1
#     GGA                 =           TRUE
#     Meta                =           TRUE
#
#     Exchange Hybrid     =           TRUE
#     MP2 Hybrid          =          FALSE
#
#    => Exchange Functionals <=
#
#     1.0000   XC_HYB_MGGA_X_M06_2X
#
#    => Exact (HF) Exchange <=
#
#     0.5400               HF
#
#    => Correlation Functionals <=
#
#     1.0000   XC_MGGA_C_M06_2X
#
#    => LibXC Density Thresholds  <==
#
#     XC_MGGA_C_M06_2X:  1.00E-12
#     XC_HYB_MGGA_X_M06_2X:  1.00E-15
#
#    => Molecular Quadrature <=
#
#     Radial Scheme          =       TREUTLER
#     Pruning Scheme         =           NONE
#     Nuclear Scheme         =       TREUTLER
#
#     BS radius alpha        =              1
#     Pruning alpha          =              1
#     Radial Points          =             75
#     Spherical Points       =            302
#     Total Points           =         151416
#     Total Blocks           =           1204
#     Max Points             =            256
#     Max Functions          =             40
#     Weights Tolerance      =       1.00E-15
#
#    => Loading Basis Set <=
#
#     Name: (6-31G(D) AUX)
#     Role: JKFIT
#     Keyword: DF_BASIS_SCF
#     atoms 1   entry C          line   121 file /usr/local/share/psi4/basis/cc-pvdz-jkfit.gbs
#     atoms 2   entry N          line   171 file /usr/local/share/psi4/basis/cc-pvdz-jkfit.gbs
#     atoms 3-7 entry H          line    51 file /usr/local/share/psi4/basis/cc-pvdz-jkfit.gbs
#
#    => Loading Basis Set <=
#
#     Name: 6-31G(D)
#     Role: ORBITAL
#     Keyword: BASIS
#     atoms 1   entry C          line   111 file /usr/local/share/psi4/basis/6-31g_d_.gbs
#     atoms 2   entry N          line   128 file /usr/local/share/psi4/basis/6-31g_d_.gbs
#     atoms 3-7 entry H          line    44 file /usr/local/share/psi4/basis/6-31g_d_.gbs
#
#   Reading orbitals from file /tmp/log.default.60.180.npy, no projection.
#
#   ==> Integral Setup <==
#
#   DFHelper Memory: AOs need 0.004 GiB; user supplied 6.560 GiB. Using in-core AOs.
#
#   ==> MemDFJK: Density-Fitted J/K Matrices <==
#
#     J tasked:                   Yes
#     K tasked:                   Yes
#     wK tasked:                   No
#     OpenMP threads:               2
#     Memory [MiB]:              6716
# ...
#       Number of basis functions:       130
#
#       Integral cutoff                 1.00e-12
#       Number of threads:                 2
#
#   Performing in-core PK
#   Using 72513740 doubles for integral storage.
#   We computed 852768 shell quartets total.
#   Whereas there are 813450 unique shell quartets.
#      4.83 percent of shell quartets recomputed by reordering.
#
#   ==> DiskJK: Disk-Based J/K Matrices <==
#
#     J tasked:                  Yes
#     K tasked:                  Yes
#     wK tasked:                  No
#     Memory [MiB]:             7152
#     Schwarz Cutoff:          1E-12
#
#     OpenMP threads:              2
#
#   Minimum eigenvalue in the overlap matrix is 1.4071273041E-03.
#   Reciprocal condition number of the overlap matrix is 1.9769294373E-04.
#     Using symmetric orthogonalization.
#
#   ==> Pre-Iterations <==
#
#   SCF Guess: Superposition of Atomic Densities via on-the-fly atomic UHF (no occupation information).
#
#    -------------------------
#     Irrep   Nso     Nmo
#    -------------------------
#      A        130     130
#    -------------------------
#     Total     130     130
#    -------------------------
#
#   ==> Iterations <==
#
#                         Total Energy        Delta E     RMS |[F,P]|
#
#    @RHF iter SAD:   -94.65239040064606   -9.46524e+01   0.00000e+00
#    @RHF iter   1:   -95.15587724121352   -5.03487e-01   3.27771e-03 DIIS
#    @RHF iter   2:   -95.23087501477119   -7.49978e-02   1.72325e-03 DIIS
#    @RHF iter   3:   -95.25165810268186   -2.07831e-02   2.63101e-04 DIIS
#    @RHF iter   4:   -95.25274727162493   -1.08917e-03   6.89073e-05 DIIS
#    @RHF iter   5:   -95.25280469375758   -5.74221e-05   1.80014e-05 DIIS
#    @RHF iter   6:   -95.25280917281654   -4.47906e-06   3.59240e-06 DIIS
#    @RHF iter   7:   -95.25280945666236   -2.83846e-07   8.48230e-07 DIIS
#    @RHF iter   8:   -95.25280947637476   -1.97124e-08   2.19841e-07 DIIS
#    @RHF iter   9:   -95.25280947804762   -1.67286e-09   5.36176e-08 DIIS
#    @RHF iter  10:   -95.25280947814541   -9.77849e-11   1.38575e-08 DIIS
#    @RHF iter  11:   -95.25280947815098   -5.57066e-12   2.61585e-09 DIIS
#   Energy and wave function converged.
#
#
#   ==> Post-Iterations <==
#
#     Orbital Energies [Eh]
#     ---------------------
#
#     Doubly Occupied:
#
#        1A    -15.535654     2A    -11.240568     3A     -1.167162
#        4A     -0.891674     5A     -0.658157     6A     -0.601277
#        7A     -0.552630     8A     -0.512937     9A     -0.390910
#
#     Virtual:
#
#       10A      0.139111    11A      0.178150    12A      0.198309
#       13A      0.223048    14A      0.242144    15A      0.313732
#       16A      0.404804    17A      0.413425    18A      0.501751
#       19A      0.506752    20A      0.594623    21A      0.624320
#       22A      0.631083    23A      0.638379    24A      0.655690
#       25A      0.707670    26A      0.728322    27A      0.755516
#       28A      0.771944    29A      0.791648    30A      0.916676
#       31A      1.025565    32A      1.050907    33A      1.063865
#       34A      1.168717    35A      1.172039    36A      1.208523
#       37A      1.227150    38A      1.335490    39A      1.364555
#       40A      1.376065    41A      1.414767    42A      1.449315
#       43A      1.478378    44A      1.536675    45A      1.542524
#       46A      1.611495    47A      1.627563    48A      1.756525
#       49A      1.792355    50A      1.874456    51A      1.908206
#       52A      2.003056    53A      2.055782    54A      2.476790
#       55A      2.483550    56A      2.609226    57A      2.771129
#       58A      2.830844    59A      2.870475    60A      3.050706
#       61A      3.073282    62A      3.118613    63A      3.138230
#       64A      3.195519    65A      3.199086    66A      3.239582
#       67A      3.300899    68A      3.315759    69A      3.326650
#       70A      3.391277    71A      3.516668    72A      3.574339
#       73A      3.624816    74A      3.638936    75A      3.651870
#       76A      3.696938    77A      3.714336    78A      3.732272
#       79A      3.743144    80A      3.765752    81A      3.829054
#       82A      3.860673    83A      3.902707    84A      3.971942
#       85A      3.999168    86A      4.012544    87A      4.135557
#       88A      4.181235    89A      4.194995    90A      4.210657
#       91A      4.240263    92A      4.247514    93A      4.273915
#       94A      4.366215    95A      4.420176    96A      4.456608
#       97A      4.479685    98A      4.574636    99A      4.610891
#      100A      4.673574   101A      4.676337   102A      4.792447
#      103A      4.819892   104A      4.914237   105A      4.943350
#      106A      5.162400   107A      5.214489   108A      5.278434
#      109A      5.336355   110A      5.380972   111A      5.380973
#      112A      5.460581   113A      5.534541   114A      5.573875
#      115A      5.666590   116A      5.671894   117A      5.791534
#      118A      5.797130   119A      5.929988   120A      6.079877
#      121A      6.149876   122A      6.159990   123A      6.256020
#      124A      6.300926   125A      6.458526   126A      6.511962
#      127A      6.585395   128A      7.278824   129A     12.885556
#      130A     13.843359
#
#     Final Occupation by Irrep:
#               A
#     DOCC [     9 ]
#
#   @RHF Final Energy:   -95.25280947815098
#
#    => Energetics <=
#
#     Nuclear Repulsion Energy =             42.0062778716315961
#     One-Electron Energy =                -211.4162389668510116
#     Two-Electron Energy =                  74.1571516170684362
#     Total Energy =                        -95.2528094781509793
#
# Computation Completed
#
#
# Properties will be evaluated at   0.000000,   0.000000,   0.000000 [a0]
#
# Properties computed using the SCF density matrix
#
#   Nuclear Dipole Moment: [e a0]
#      X:    -1.2303      Y:    -0.2636      Z:    -0.6029
#
#   Electronic Dipole Moment: [e a0]
#      X:     1.0487      Y:     0.0563      Z:     0.1288
#
#   Dipole Moment: [e a0]
#      X:    -0.1815      Y:    -0.2073      Z:    -0.4741     Total:     0.5483
#
#   Dipole Moment: [D]
#      X:    -0.4614      Y:    -0.5269      Z:    -1.2050     Total:     1.3938
#
#
# *** tstop() called on 62de2050016d at Tue Apr 19 10:06:19 2022
# Module time:
# 	user time   =      13.66 seconds =       0.23 minutes
# 	system time =       1.17 seconds =       0.02 minutes
# 	total time  =          8 seconds =       0.13 minutes
# Total time:
# 	user time   =     258.95 seconds =       4.32 minutes
# 	system time =      47.67 seconds =       0.79 minutes
# 	total time  =       1188 seconds =      19.80 minutes
#  MINTS: Wrapper to libmints.
#    by Justin Turney
#
#    Calculation information:
#       Number of threads:                 2
#       Number of atoms:                   7
#       Number of AO shells:              50
#       Number of SO shells:              50
#       Number of primitives:             92
#       Number of atomic orbitals:       145
#       Number of basis functions:       130
#
#       Number of irreps:                  1
#       Integral cutoff                 1.00e-12
#       Number of functions per irrep: [ 130 ]
#
#  OEINTS: Overlap, kinetic, potential, dipole, and quadrupole integrals
#          stored in file 35.
#
#       Computing two-electron integrals...done
#       Computed 35976771 non-zero two-electron integrals.
#         Stored in file 33.
#
#
# *** tstart() called on 62de2050016d
# *** at Tue Apr 19 10:06:25 2022
#
#
# 	Wfn Parameters:
# 	--------------------
# 	Wavefunction         = CCSD_T
# 	Number of irreps     = 1
# 	Number of MOs        = 130
# 	Number of active MOs = 130
# 	AO-Basis             = NONE
# 	Semicanonical        = false
# 	Reference            = RHF
# 	Print Level          = 1
#
# 	IRREP	# MOs	# FZDC	# DOCC	# SOCC	# VIRT	# FZVR
# 	-----	-----	------	------	------	------	------
# 	 A	   130	    0	    9	    0	    121	    0
# 	Transforming integrals...
# 	IWL integrals will be deleted.
# 	(OO|OO)...
# 	Presorting SO-basis two-electron integrals.
# 	Sorting File: SO Ints (nn|nn) nbuckets = 1
# 	Constructing frozen core operators
# 	Starting first half-transformation.
# 	Sorting half-transformed integrals.
# 	First half integral transformation complete.
# 	Starting second half-transformation.
# 	Two-electron integral transformation complete.
# 	(OO|OV)...
# 	Starting second half-transformation.
# 	Two-electron integral transformation complete.
# 	(OO|VV)...
# 	Starting second half-transformation.
# 	Two-electron integral transformation complete.
# 	(OV|OO)...
# 	Starting first half-transformation.
# 	Sorting half-transformed integrals.
# 	First half integral transformation complete.
# 	Starting second half-transformation.
# 	Two-electron integral transformation complete.
# 	(OV|OV)...
# 	Starting second half-transformation.
# 	Two-electron integral transformation complete.
# 	(OV|VV)...
# 	Starting second half-transformation.
# 	Two-electron integral transformation complete.
# 	(VV|OO)...
# 	Starting first half-transformation.
# 	Sorting half-transformed integrals.
# 	First half integral transformation complete.
# 	Starting second half-transformation.
# 	Two-electron integral transformation complete.
# 	(VV|OV)...
# 	Starting second half-transformation.
# 	Two-electron integral transformation complete.
# 	(VV|VV)...
# 	Starting second half-transformation.
# 	Two-electron integral transformation complete.
# 	Frozen core energy     =      0.00000000000000
#
# 	Size of irrep 0 of <ab|cd> integrals:    214.359 (MW) /   1714.871 (MB)
# 	Total:                                   214.359 (MW) /   1714.871 (MB)
#
# 	Size of irrep 0 of <ia|bc> integrals:     15.944 (MW) /    127.552 (MB)
# 	Total:                                    15.944 (MW) /    127.552 (MB)
#
# 	Size of irrep 0 of tijab amplitudes:       1.186 (MW) /      9.487 (MB)
# 	Total:                                     1.186 (MW) /      9.487 (MB)
#
# 	Nuclear Rep. energy          =     42.00627787163160
# 	SCF energy                   =    -95.25280947815098
# 	One-electron energy          =   -211.41623919182359
# 	Two-electron energy          =     74.15715184204078
# 	Reference energy             =    -95.25280947815122
#
# *** tstop() called on 62de2050016d at Tue Apr 19 10:07:19 2022
# Module time:
# 	user time   =      28.05 seconds =       0.47 minutes
# 	system time =      17.41 seconds =       0.29 minutes
# 	total time  =         54 seconds =       0.90 minutes
# Total time:
# 	user time   =     291.28 seconds =       4.85 minutes
# 	system time =      67.02 seconds =       1.12 minutes
# 	total time  =       1248 seconds =      20.80 minutes
#             **************************
#             *                        *
#             *        CCENERGY        *
#             *                        *
#             **************************
#
#     Nuclear Rep. energy (wfn)     =   42.006277871631596
#     SCF energy          (wfn)     =  -95.252809478150979
#     Reference energy    (file100) =  -95.252809478151221
#
#     Input parameters:
#     -----------------
#     Wave function   =     CCSD_T
#     Reference wfn   =     RHF
#     Brueckner       =     No
#     Memory (Mbytes) =     10000.0
#     Maxiter         =     50
#     R_Convergence   =     1.0e-07
#     E_Convergence   =     1.0e-06
#     Restart         =     Yes
#     DIIS            =     Yes
#     AO Basis        =     NONE
#     ABCD            =     NEW
#     Cache Level     =     2
#     Cache Type      =     LOW
#     Print Level     =     1
#     Num. of threads =     2
#     # Amps to Print =     10
#     Print MP2 Amps? =     No
#     Analyze T2 Amps =     No
#     Print Pair Ener =     No
#     Local CC        =     No
#     SCS-MP2         =     False
#     SCSN-MP2        =     False
#     SCS-CCSD        =     False
#
# MP2 correlation energy -0.4352386291565553
#                 Solving CC Amplitude Equations
#                 ------------------------------
#   Iter             Energy              RMS        T1Diag      D1Diag    New D1Diag    D2Diag
#   ----     ---------------------    ---------   ----------  ----------  ----------   --------
#      0        -0.435238629156555    0.000e+00    0.000000    0.000000    0.000000    0.128754
#      1        -0.449131365413528    4.728e-02    0.005721    0.012332    0.012332    0.132286
#      2        -0.459114536450731    1.533e-02    0.006090    0.013281    0.013281    0.137622
#      3        -0.460033946558622    4.542e-03    0.006657    0.014807    0.014807    0.138664
#      4        -0.460033696158753    1.106e-03    0.006706    0.014925    0.014925    0.138877
#      5        -0.460061596765982    3.499e-04    0.006723    0.015008    0.015008    0.138922
#      6        -0.460066373721482    1.245e-04    0.006730    0.015031    0.015031    0.138922
#      7        -0.460065233946551    4.861e-05    0.006732    0.015039    0.015039    0.138920
#      8        -0.460065278857920    2.190e-05    0.006733    0.015044    0.015044    0.138920
#      9        -0.460065125266832    5.914e-06    0.006734    0.015044    0.015044    0.138919
#     10        -0.460065030582805    1.776e-06    0.006734    0.015044    0.015044    0.138919
#     11        -0.460065088878737    5.316e-07    0.006734    0.015044    0.015044    0.138919
#     12        -0.460065091131098    1.704e-07    0.006734    0.015044    0.015044    0.138919
#     13        -0.460065097510645    6.360e-08    0.006734    0.015044    0.015044    0.138919
#
#     Iterations converged.
#
#
#     Largest TIA Amplitudes:
#               5  14        -0.0056375779
#               7  12         0.0049815109
#               4   9         0.0048365201
#               7  16         0.0046834546
#               6   3        -0.0045212900
#               6  14        -0.0045108906
#               5  10        -0.0041808092
#               4  12         0.0040947765
#               6   7        -0.0040447809
#               5   7        -0.0039403904
#
#     Largest TIjAb Amplitudes:
#       4   4  16  16        -0.0199657542
#       8   8  14  14        -0.0198802426
#       7   7  12  12        -0.0193675323
#       6   6   8   8        -0.0193166807
#       5   5  14  14        -0.0173315782
#       8   8  10  10        -0.0170813226
#       4   4   9   9        -0.0170558858
#       5   5  10  10        -0.0166792296
#       7   7   9   9        -0.0151798066
#       7   7   6   6        -0.0142379593
#
#     SCF energy       (wfn)                    =  -95.252809478150979
#     Reference energy (file100)                =  -95.252809478151221
#
#     Opposite-spin MP2 correlation energy      =   -0.341580250006141
#     Same-spin MP2 correlation energy          =   -0.093658379150414
#     Singles MP2 correlation energy            =   -0.000000000000000
#     MP2 correlation energy                    =   -0.435238629156555
#       * MP2 total energy                      =  -95.688048107307779
#
#     Opposite-spin CCSD correlation energy     =   -0.373302773392034
#     Same-spin CCSD correlation energy         =   -0.086762324118612
#     Singles CCSD correlation energy           =    0.000000000000000
#     CCSD correlation energy                   =   -0.460065097510645
#       * CCSD total energy                     =  -95.712874575661871
#
#             **************************
#             *                        *
#             *        CCTRIPLES       *
#             *                        *
#             **************************
#
#
#     Wave function   =    CCSD_T
#     Reference wfn   =      RHF
#
#     Nuclear Rep. energy (wfn)                =   42.006277871631596
#     SCF energy          (wfn)                =  -95.252809478150979
#     Reference energy    (file100)            =  -95.252809478151221
#     CCSD energy         (file100)            =   -0.460065097510645
#     Total CCSD energy   (file100)            =  -95.712874575661871
#
#     Number of ijk index combinations:              165
#     Memory available in words               :      1250000000
#     Approx. words needed per explicit thread:         7086244
#     Number of threads for explicit ijk threading:    2
#
#     MKL num_threads set to 1 for explicit threading.
#
#     (T) energy                                =   -0.015169212411338
#       * CCSD(T) total energy                  =  -95.728043788073208
